# %% [markdown]
# # Stock

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Double Exopnential:

# %% [markdown]
# - import dataset

# %%
data = pd.read_csv('data/AMD.csv', index_col=['Date'], parse_dates=['Date'])
#file can be changed to another one
data.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-22  20.480000  20.920000  19.700001  19.760000  19.760000   78513700
# 2019-01-23  20.030001  20.480000  19.549999  19.799999  19.799999   77811300
# 2019-01-24  20.059999  21.010000  20.040001  20.850000  20.850000   97433400
# 2019-01-25  20.990000  22.030001  20.790001  21.930000  21.930000  110239500
# 2019-01-28  20.320000  21.010000  20.020000  20.180000  20.180000  135164100
# 2019-01-29  20.260000  20.389999  19.049999  19.250000  19.250000  131202500
# 2019-01-30  21.490000  23.129999  21.370001  23.090000  23.090000  211421200
# 2019-01-31  23.020000  25.139999  22.830000  24.410000  24.410000  182575600
# 2019-02-01  24.610001  24.840000  24.070000  24.510000  24.510000  105356200
# 2019-02-04  24.430000  24.660000  24.070000  24.129999  24.129999   70843800
# 2019-02-05  23.420000  23.860001  22.980000  23.309999  23.309999  122226000
# 2019-02-06  23.629999  24.139999  23.219999  23.260000  23.260000   78684300
# 2019-02-07  22.990000  23.219999  22.320000  22.670000  22.670000   86723900
# 2019-02-08  22.330000  23.280001  22.270000  23.049999  23.049999   78129300
# 2019-02-11  23.049999  23.280001  22.660000  22.959999  22.959999   60578700
# 2019-02-12  23.430000  23.559999  22.750000  22.820000  22.820000   67595400
# 2019-02-13  22.980000  23.240000  22.709999  22.850000  22.850000   57544200
# 2019-02-14  22.740000  23.370001  22.590000  23.129999  23.129999   64441200
# 2019-02-15  23.580000  24.049999  23.200001  23.680000  23.680000   78644100
# 2019-02-19  23.629999  24.410000  23.610001  23.950001  23.950001   57517900

# %% [markdown]
# - Data cleaning

# %%
drop_cols = ['Adj Close','Volume' ]

data.drop(drop_cols, axis=1, inplace=True)
data.head()
# Out:
#                  Open       High        Low      Close
# Date
# 2019-01-22  20.480000  20.920000  19.700001  19.760000
# 2019-01-23  20.030001  20.480000  19.549999  19.799999
# 2019-01-24  20.059999  21.010000  20.040001  20.850000
# 2019-01-25  20.990000  22.030001  20.790001  21.930000
# 2019-01-28  20.320000  21.010000  20.020000  20.180000

# %% [markdown]
# - Plot the closing price

# %%
plt.figure(figsize=(17, 8))
plt.plot(data.Close)
plt.title('Closing price of HPQ')
plt.ylabel('Closing price ($)')
plt.xlabel('Trading day')
plt.grid(False)
plt.show()

# %% [markdown]
# - Double Exponential Smoothing

# %%
def double_exponential_smoothing(series, alpha, beta):
    result = [series[0]]
    
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

plot_double_exponential_smoothing(data.Close, alphas=[0.9, 0.04], betas=[0.9, 0.04])

# %%
- Stationary

# %% [markdown]
# - Random Forests

# %%
data.head()
# Out:
#                  Open       High        Low      Close
# Date
# 2019-01-22  20.480000  20.920000  19.700001  19.760000
# 2019-01-23  20.030001  20.480000  19.549999  19.799999
# 2019-01-24  20.059999  21.010000  20.040001  20.850000
# 2019-01-25  20.990000  22.030001  20.790001  21.930000
# 2019-01-28  20.320000  21.010000  20.020000  20.180000

# %%
### Data transformations
data.columns = [x.strip() for x in data.columns]
data.columns = [x.replace(' ', '_') for x in data.columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
pd.concat([data.Close, data.Close.shift(-1)], axis=1)
# Out:
#                 Close      Close
# Date
# 2019-01-22  19.760000  19.799999
# 2019-01-23  19.799999  20.850000
# 2019-01-24  20.850000  21.930000
# 2019-01-25  21.930000  20.180000
# 2019-01-28  20.180000  19.250000
# ...               ...        ...
# 2020-01-13  48.750000  48.209999
# 2020-01-14  48.209999  48.549999
# 2020-01-15  48.549999  49.770000
# 2020-01-16  49.770000  50.930000
# 2020-01-17  50.930000        NaN
#
# [251 rows x 2 columns]

# %%
def valid(col):
    return col
data = data.dropna()
X = data[[x for x in data.columns if valid(x)]].iloc[1:]
y = data.Close.shift(-1).dropna()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X.T
# Out:
# Date   2019-01-23  2019-01-24  2019-01-25  2019-01-28  2019-01-29  2019-01-30  \
# Open    20.030001   20.059999   20.990000       20.32   20.260000   21.490000
# High    20.480000   21.010000   22.030001       21.01   20.389999   23.129999
# Low     19.549999   20.040001   20.790001       20.02   19.049999   21.370001
# Close   19.799999   20.850000   21.930000       20.18   19.250000   23.090000
#
# Date   2019-01-31  2019-02-01  2019-02-04  2019-02-05  ...  2020-01-06  \
# Open    23.020000   24.610001   24.430000   23.420000  ...   48.020000
# High    25.139999   24.840000   24.660000   23.860001  ...   48.860001
# Low     22.830000   24.070000   24.070000   22.980000  ...   47.860001
# Close   24.410000   24.510000   24.129999   23.309999  ...   48.389999
#
# Date   2020-01-07  2020-01-08  2020-01-09  2020-01-10  2020-01-13  2020-01-14  \
# Open    49.349998   47.849998   48.939999   49.259998   48.660000   48.639999
# High    49.389999   48.299999   49.959999   49.290001   48.860001   49.040001
# Low     48.040001   47.139999   48.389999   48.000000   48.240002   47.910000
# Close   48.250000   47.830002   48.970001   48.169998   48.750000   48.209999
#
# Date   2020-01-15  2020-01-16  2020-01-17
# Open    48.230000   49.169998   50.200001
# High    49.080002   50.310001   51.049999
# Low     48.119999   48.990002   49.900002
# Close   48.549999   49.770000   50.930000
#
# [4 rows x 250 columns]

# %%
rf_model = RandomForestRegressor()

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.9970516802591938

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
pd.concat([pd.Series(rf_model.predict(X_test)), y_test.reset_index(
drop=True)], axis=1)
# Out:
#             0      Close
# 0   29.774000  29.670000
# 1   23.841000  24.410000
# 2   32.203000  32.180000
# 3   27.613000  27.680000
# 4   31.157000  31.190001
# ..        ...        ...
# 58  30.688001  30.639999
# 59  42.710000  42.299999
# 60  46.256000  46.540001
# 61  31.473000  31.500000
# 62  33.172000  33.060001
#
# [63 rows x 2 columns]

# %%
sorted(zip(X.columns, rf_model.feature_importances_),
        key=lambda x: x[1], reverse=True)
# Out:
# [('High', 0.40778547747087746),
#  ('Close', 0.27184491909815706),
#  ('Low', 0.16605721060937356),
#  ('Open', 0.15431239282159198)]
