# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 6 Day 2</div>
# <div style="text-align: right">Dino Konstantopoulos, 12 February 2020, with material by Ankur Ankan and Abinash Panda</div>
#
# Some people have this to say about advantages of the **German** language:
#
# <br />
# <center>
# <img src="images2/german-flag.jpg" width=300 />
# </center>
#
# - It is better to keep the most important piece of information at the end, to keep people’s attention. In German, the main verb in conjugation is at the end of a sentence: *Sie (You) haben (have) bestimmt (definitely) noch (still) nicht (not) viele (many) anständige (respectable) Zauberer (wizard) **kennen gelernt** (met)*. In Spanish and English, we say all the important information first and, for this reason, we tend to interrupt each other in the middle of a sentence.
#
#
# - The purpose of words is to transmit **knowledge**, so they should be easily understood. Some people seem to use words no one knows just to look smart. In German, it is almost impossible to do this as names for objects describe those objects. I really love this about German: Glutenunverträglichkeit means gluten-not-compatible (celiac). It helped a lot while reading Harry Potter: Zauberer (wizard), Zauberwort (Magic word), Zaubererschule (School of Magic), Zauberstab (magic wand), Zaubererwelt (wizarding world), etc
#
# # POS tagging with Hidden Markov Models
#
# In this notebook you will witness how you can *cheat* Science by relying on data probabilities instead of trying to figure out the rules or laws of Science. I don't know the internals of [Universal Dependencies](https://universaldependencies.org/), but I suspect they do not worry about analyzing the structure of the German language, figuring out that the verb is at the end of a sentence, and accomodating for this in the German Tree Bank. Instead, their algorithms probably read in a lot of german text, and just by looking at the probabilities of where the verb lands in a sentence they can correctly figure out that it's at the end. Probabilities powers **statistics**, and having lots of data means your probabilities can be very *exact*.
#
# Not too many weeks ago, you called R libraries to do POS tagging for you. Now that you know everything about probabilities, *you* can do the same thing *on your own*!
#
# We'll use the [Brown]() corpus to build a [POS tagger](https://en.wikipedia.org/wiki/Part-of-speech_tagging), first using a simple [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model) model (***most probable POS by count***), then using a **Hidden Markov Model** (HMM) that gets *transition* and *emission* probabilities from [POS bigrams](https://en.wikipedia.org/wiki/Bigram) (given a POS, what's the most probable ***next*** POS in the sentence?).
#
# We'll divide the Brown corpus into training and test sets, and compare accuraces for BOW and HMM models.
#
# We'll use some advanced python structures that are often used in Natural Language Processing (NLP).
#
# # Reading in the Brown corpus efficiently

# %% [markdown]
# # Homework
#
# Use the methodology in this notebook to build a statistical language translator, *from your language to english*. So, from Hindi or Chinese to English. Teams of **3** students. You *have* to use a Hidden Markov Model and `pomegranate` as your HMM library, to ensure all student teams start from the same baseline. Start from a Most Frequent Word (BOW) translation baseline, then move on to a Hidden Markov Model to improve translation. How much can you improve it by? The translation engine with the best accuracy, per language, will be presented in class.

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# Some advanced python-fu:
#
# Library `itertools` is a library of efficient iterators. `chain` makes an iterator that returns elements from the first iterable until it is exhausted, then proceeds to the next iterable, until all of the iterables are exhausted. It is used for treating consecutive sequences as a single sequence
#
# In python, a single star `*` unpacks the sequence/collection into positional arguments, so you can do this:
# ```(python)
# def sum(a, b):
#     return a + b
#
# values = (1, 2)
#
# s = sum(*values)
# ```
#
# This will unpack the tuple so that it actually executes as:
# ```(python)
# s = sum(1, 2)
# ```
#
# The double star `**` does the same, only using a dictionary and thus named arguments:
# ```(python)
# values = { 'a': 1, 'b': 2 }
# s = sum(**values)
# ```
#
# A python `frozenset` is just an immutable version of a Python set object.
#
# While elements of a set can be modified at any time, elements of frozen set remains the same after creation.
#
# So, frozen sets can be used as keys in a sictionary or as element of another set.
#
# `read_data` below reads files page by page (`\n\n`), then line by line (`\n`), uses the first line of a page as a key to an ordered dictionary, with the values being a zipper made out of words and POS tags. It accomodates the syntax of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus), pictured here below.
#
# <br />
# <center>
# <img src="images/brown.png" width=300 />
#     Header of Brown corpus
# </center>

# %%
# read our file
#filename = "./test.txt"
# tags_file = "./pos-tagging-brown/tags-universal.txt"
tags_file = "./tags.txt"
# txt_file = "./pos-tagging-brown/brown-universal.txt"
txt_file = "./newfile.txt"

# %% [markdown]
# ### seperate each 20 words as a sentence, newfile.txt is the seperated file

# %%
with open(filename,'r') as test:
    a = list(test.read().split("\n"))
    with open('./newfile.txt','w') as w_f:
        index = 0
        id = 0
        for str_file in a:
            if not str_file.split("\t")[0]==' ':
                if index == 20:
                    w_f.write(str_file+"\n\n")
                    w_f.write(str(id)+'\n')
                    index=0
                else:
                    w_f.write(str_file+"\n")
                index+=1
                id+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b5f687a70943> in <module>
# ----> 1 with open(filename,'r') as test:
#       2     a = list(test.read().split("\n"))
#       3     with open('./newfile.txt','w') as w_f:
#       4         index = 0
#       5         id = 0
#
# NameError: name 'filename' is not defined

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r', encoding = 'UTF-8') as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t") for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r', encoding = 'UTF-8') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %% [markdown]
# Let's read in the Brown corpus to see if our python code works out:

# %%
tagset = read_tags(tags_file)
sentences = read_data(txt_file)
sentences
# Out:
# OrderedDict([('10',
#               Sentence(words=('半个', '小时', '不到', '钟', '就', '敲响', '五点', '散课', '大家', '都', '进', '饭厅', '去', '吃', '茶点', '我', '这', '才', '大', '着', '胆'), tags=('Half', 'Hours', 'Less than', 'Minutes', 'Just.', 'Ring', 'Five', 'Breakout class', 'Everyone', 'All', 'Into', 'Dining room', 'To', 'Eat', 'Refreshment', 'I', 'This', "It's just", 'Big', 'On the', 'Bile'))),
#              ('20',
#               Sentence(words=('走', '下', '凳子', '这时', '暮色', '正浓', '我', '躲进', '一个', '角落', '在', '地板', '上', '坐下', '来', '一直', '支撑', '着', '我', '的'), tags=('Go', 'Next', 'Stool', 'Then', 'Twilight', 'Positive', 'I', 'Hide in.', 'One', 'Corner', 'In', 'Floor', 'On', 'Sit down', 'To', 'Always', 'Support', 'On the', 'I', 'The'))),
#              ('40',
#               Sentence(words=('魔力', '消失', '被', '不良反应', '所', '取代', '我', '伤心', '不已', '脸朝', '下', '扑倒在', '地', '嚎啕大哭', '起来', '海伦', '·', '彭斯', '不', '在'), tags=('Magic', 'Disappear', 'Be', 'Adverse reactions', 'The', 'Replace', 'I', 'Sad', 'Unceasingly', 'Face to face', 'Next', 'Slumped', 'Ground', 'Crying', 'Get up', 'Helen', '·', 'Burns', 'No', 'In'))),
#              ('60',
#               Sentence(words=('没有', '东西', '支撑', '我', '孤身', '独处', '我', '难以', '自制', '眼泪', '洒到', '地板', '上', '我', '曾', '打算', '在', '罗沃德', '表现', '那么出色'), tags=('No', 'Things', 'Support', 'I', 'Alone', 'Alone', 'I', "Can't", 'Homemade', 'Tears', 'Sprinkle on', 'Floor', 'On', 'I', 'Had', 'Planning', 'In', 'Lowood', 'Performance', "That's great."))),
#              ('80',
#               Sentence(words=('做', '那么', '多', '事情', '交', '那么', '多', '朋友', '博得', '别人', '的', '尊敬', '赢得', '大家', '的', '爱护', '而且', '已经', '取得', '明显'), tags=('Do', 'So', 'Many', 'Things', 'Make', 'So', 'Many', 'Friends', 'Win', 'Others', 'The', 'Respect', 'Win', 'Everyone', 'The', 'Love', 'And', 'Have', 'Made', 'Obvious'))),
#              ('100',
#               Sentence(words=('的', '进步', '就', '在', '那天', '早上', '我', '在', '班上', '己', '经', '名列前矛', '米勒', '小姐', '热情', '夸奖', '我', '坦普尔', '小姐', '微笑'), tags=('The', 'Progress', 'Just.', 'In', 'That', 'Morning', 'I', 'In', 'In class', "I've got your", 'By', 'Top Spear', 'Miller', 'Miss', 'Enthusiasm', 'Praise', 'I', 'Temple', 'Miss', 'Smile'))),
#              ('120',
#               Sentence(words=('着', '表示', '赞许', '还', '答应', '教', '我', '绘画', '让我学', '法文', '只要', '我', '在', '两个', '月', '之内', '继续', '取得', '同样', '的'), tags=('On the', 'Said', 'Approbation', 'Also', 'Promise', 'Teach', 'I', 'Painting', 'Let me learn.', 'French', 'Just', 'I', 'In', 'Two', 'Month', 'Within', 'Go on', 'Made', 'Same', 'The'))),
#              ('140',
#               Sentence(words=('进步', '此外', '我', '也', '深受', '同学', '们', '的', '欢迎', '同', '我', '年龄', '相仿', '的', '人', '也', '对', '我', '平等', '相待'), tags=('Progress', 'In addition,', 'I', 'Also', 'By', 'Classmates', 'We', 'The', 'Welcome', 'With', 'I', 'Age', 'Similar', 'The', 'People', 'Also', 'Right', 'I', 'Equal', 'Wait inge'))),
#              ('160',
#               Sentence(words=('我', '已', '不再', '受', '人', '欺悔', '然而', '此刻', '我', '又', '被', '打倒', '在', '地', '遭', '人', '践踏', '我', '还有', '翻身'), tags=('I', 'Has', 'No longer', 'By', 'People', 'Bullying', 'However', 'Now', 'I', 'And again', 'Be', 'Down', 'In', 'Ground', 'Was', 'People', 'Trample', 'I', 'And also', 'Turn'))),
#              ('180',
#               Sentence(words=('之日', '吗', '“', '永远', '没有', '”', '我', '想', '满心', '希望', '自己', '死', '掉', '正当', '我', '泣不成声', '地', '吐出', '这个', '心愿'), tags=('The date', 'Do you?', '"', 'Forever', 'No', '"', 'I', 'Think', 'Full', 'Hope', 'Myself', 'Die', 'Off', 'Legitimate', 'I', 'Sobbing', 'Ground', 'Spit', 'This one', 'Wish'))),
#              ('200',
#               Sentence(words=('时', '有人', '走近', '我', '我', '惊跳', '起来', '又', '是', '海伦', '·', '彭斯', '靠近', '我', '渐暗', '的', '炉火', '恰好', '照亮', '她'), tags=('When', 'Someone', 'Get close', 'I', 'I', 'Jumping', 'Get up', 'And again', 'Is', 'Helen', '·', 'Burns', 'Near', 'I', 'Fading', 'The', 'Fire', 'Just', 'Light', 'She'))),
#              ('220',
#               Sentence(words=('走过', '空空荡荡', '的', '长', '房间', '她', '给', '我', '端', '来', '咖啡', '和', '面包', '“', '来', '吃', '点', '东西', '”', '她'), tags=('Walked', 'Empty', 'The', 'Long', 'Room', 'She', 'To give', 'I', 'End', 'To', 'Coffee', 'And', 'Bread', '"', 'To', 'Eat', 'Point', 'Things', '"', 'She'))),
#              ('240',
#               Sentence(words=('说', '可是', '我们', '把', '咖啡', '和', '面包', '都', '从', '我', '面前', '推开', '只', '觉得', '仿佛', '眼下', '一滴', '咖啡', '或', '一口'), tags=('Said', 'But', 'We', 'Put', 'Coffee', 'And', 'Bread', 'All', 'From', 'I', 'Front', 'Pushed', 'Only', 'Think', 'Seems', 'Now', 'One drop.', 'Coffee', 'Or', 'One bite.'))),
#              ('260',
#               Sentence(words=('面包', '就', '会', '把', '我', '噎住', '似的', '海伦', '凝视着', '我', '也许', '很', '惊奇', '这时', '我', '虽', '已', '竭尽全力', '却', '仍'), tags=('Bread', 'Just.', 'Yes', 'Put', 'I', 'Hold on.', "It's like.", 'Helen', 'Staring', 'I', 'Maybe', 'Is', 'Surprise', 'Then', 'I', 'Although', 'Has', 'Tried', 'But', 'Still'))),
#              ('280',
#               Sentence(words=('无法', '抑制', '内心', '的', '激动', '仍然', '一个劲儿', '号啕', '着', '她', '在', '我', '身旁', '的', '地上', '坐下', '胳膊', '抱', '着', '双'), tags=("Can't", 'Suppression', 'Heart', 'The', 'Excited', 'Still', 'A force.', 'No.', 'On the', 'She', 'In', 'I', 'Side', 'The', 'Ground', 'Sit down', 'Arm', 'Hold', 'On the', 'Double'))),
#              ('300',
#               Sentence(words=('膝', '把头', '靠', '在', '膝头', '上', '她', '就', '那么', '坐', '着', '不言不语', '像', '一个', '印度人', '倒', '是', '我', '第一个', '开腔'), tags=('Knee', 'Head', 'By', 'In', 'Knees', 'On', 'She', 'Just.', 'So', 'Sit', 'On the', 'No words.', 'Like', 'One', 'Indian', 'Pour down', 'Is', 'I', 'First', 'Open cavity'))),
#              ('320',
#               Sentence(words=('“', '海伦', '你', '怎么', '会', '跟', '一个', '人人', '都', '相信', '她', '会', '说谎', '的', '人', '呆', '在', '一起', '呢', '”'), tags=('"', 'Helen', 'You', 'How', 'Yes', 'With', 'One', 'Everyone', 'All', 'Believe', 'She', 'Yes', 'Lie', 'The', 'People', 'Stay', 'In', 'Together.', 'What about?', '"'))),
#              ('340',
#               Sentence(words=('“', '是', '人人', '吗', '简', '瞧', '只有', '八十个', '人', '听见', '叫', '你', '撒谎', '者', '而', '世界', '上', '有', '千千万万', '的'), tags=('"', 'Is', 'Everyone', 'Do you?', 'Jane', 'Look', 'Only', 'Eighty.', 'People', 'Hear', 'Call', 'You', 'Lie', 'The', 'And', 'World', 'On', 'Yes', 'Thousands', 'The'))),
#              ('360',
#               Sentence(words=('人', '呢', '”', '“', '可是', '我', '跟', '那', '千千万万', '的', '人', '有', '什么', '关系', '呢', '我', '认识', '的', '八十个', '人'), tags=('People', 'What about?', '"', '"', 'But', 'I', 'With', 'That', 'Thousands', 'The', 'People', 'Yes', 'What the', 'Relationship', 'What about?', 'I', 'Know', 'The', 'Eighty.', 'People'))),
#              ('380',
#               Sentence(words=('瞧不起', '我', '”', '“', '简', '你', '错', '啦', '也许', '学校', '里', '没有', '一个', '人会', '瞧不起', '你', '或者', '讨厌', '你', '我'), tags=('Despise', 'I', '"', '"', 'Jane', 'You', 'Wrong', "That's it.", 'Maybe', 'School', 'Inside', 'No', 'One', "People's club", 'Despise', 'You', 'Or', 'Hate', 'You', 'I'))),
#              ('400',
#               Sentence(words=('敢肯定', '很多', '人', '都', '那么', '同情', '你', '”', '“', '布罗克', '赫斯特', '先生', '说话', '以后', '她们', '怎么', '可能', '同情', '我', '呢'), tags=('Be sure.', 'A lot', 'People', 'All', 'So', 'Sympathy', 'You', '"', '"', 'Brock', 'Hurst', 'Mr', 'Speak', 'later', 'They', 'How', 'possible', 'Sympathy', 'I', 'What about?'))),
#              ('420',
#               Sentence(words=('”', '“', '布罗克', '赫斯特', '先生', '不是', '神', '也', '不是', '一个', '值得', '钦佩', '的', '伟人', '这里', '人', '不', '喜欢', '他', '他'), tags=('"', '"', 'Brock', 'Hurst', 'Mr', 'No', 'God', 'Also', 'No', 'One', 'Worth', 'Admire', 'The', 'Great', 'Over here', 'People', 'No', 'Like', 'He', 'He'))),
#              ('440',
#               Sentence(words=('也', '不', '想法', '让', '人', '喜欢', '他', '要是', '他', '把', '你', '看成', '他', '的', '宠儿', '你', '倒', '会', '处处', '树敌'), tags=('Also', 'No', 'Idea', 'Let', 'People', 'Like', 'He', 'If', 'He', 'Put', 'You', 'As', 'He', 'The', 'Darling', 'You', 'Pour down', 'Yes', 'Everywhere', 'Enemies'))),
#              ('460',
#               Sentence(words=('公开', '的', '或者', '暗地里', '的', '都', '会', '有', '而', '现在', '这样', '大多数', '胆子', '大', '一点', '的', '人', '是', '会', '同情'), tags=('Public', 'The', 'Or', 'Secretly', 'The', 'All', 'Yes', 'Yes', 'And', 'Right now', 'This way,', 'Most', 'Courage', 'Big', 'A little.', 'The', 'People', 'Is', 'Yes', 'Sympathy'))),
#              ('480',
#               Sentence(words=('你', '的', '而', '要是', '你', '继续', '努力', '好好', '表现', '这些', '感情', '正', '因为', '暂时', '的', '压抑', '不久', '就', '会', '更加'), tags=('You', 'The', 'And', 'If', 'You', 'Go on', 'Efforts', 'Good', 'Performance', 'These', 'Feelings', 'Is', 'Because', 'Temporary', 'The', 'Depressed', 'Soon', 'Just.', 'Yes', 'More'))),
#              ('500',
#               Sentence(words=('明显', '地', '表露', '出来', '此外', '简', '”', '她', '刹住', '话头', '“', '怎样', '海伦', '”', '我', '说', '着', '把', '自己', '手塞'), tags=('Obvious', 'Ground', 'Show', 'Come out', 'In addition,', 'Jane', '"', 'She', 'Stop it.', 'The head of the conversation', '"', 'How', 'Helen', '"', 'I', 'Said', 'On the', 'Put', 'Myself', 'Hand plugs'))),
#              ('520',
#               Sentence(words=('到', '她', '手里', '她', '轻轻地', '揉', '着', '我', '的', '手指', '使', '它们', '暖和', '过来', '随后', '又', '说', '下去', '“', '即使'), tags=('To', 'She', 'Hands', 'She', 'Gently', 'Rubbing', 'On the', 'I', 'The', 'Fingers', 'Make', 'They', 'Warm', 'Come here', 'Then', 'And again', 'Said', 'Go down.', '"', 'Even'))),
#              ('540',
#               Sentence(words=('整个', '世界', '恨', '你', '并且', '相信', '你', '很', '坏', '只要', '你', '自己', '问心无愧', '知道', '你', '是', '清白', '的', '你', '就'), tags=('Whole', 'World', 'Hate', 'You', 'And', 'Believe', 'You', 'Is', 'Bad', 'Just', 'You', 'Myself', 'Clear conscience', 'Know', 'You', 'Is', 'Innocent', 'The', 'You', 'Just.'))),
#              ('560',
#               Sentence(words=('不会', '没有', '朋友', '”', '“', '不', '我', '明白', '我', '觉得', '自己', '不错', '但', '这', '还', '不够', '要是', '别人', '不', '爱'), tags=('No', 'No', 'Friends', '"', '"', 'No', 'I', 'Got it', 'I', 'Think', 'Myself', 'Not bad', 'But', 'This', 'Also', 'Enough', 'If', 'Others', 'No', 'Love'))),
#              ('580',
#               Sentence(words=('我', '那么', '与其', '活着', '还', '不如', '死去', '—', '—', '我', '受', '不', '孤独', '和', '别人', '的', '厌恶', '海伦', '瞧为', '从'), tags=('I', 'So', 'With its', 'Live.', 'Also', 'As', 'Die', '—', '—', 'I', 'By', 'No', 'Lonely', 'And', 'Others', 'The', 'Disgust', 'Helen', 'Look for it.', 'From'))),
#              ('600',
#               Sentence(words=('你', '那儿', '或者', '坦普尔', '小姐', '或是', '任何', '一个', '我', '确实', '所爱', '的', '人', '那儿', '得到', '真正', '的', '爱', '我会', '心甘情愿'), tags=('You', 'There', 'Or', 'Temple', 'Miss', 'Or', 'Any', 'One', 'I', 'Do', 'Love', 'The', 'People', 'There', 'Get', 'Real', 'The', 'Love', 'I will', 'Willing'))),
#              ('620',
#               Sentence(words=('忍受', '胳膊', '骨', '被', '折断', '或者', '愿让', '一头', '公牛', '把', '我', '悬空', '抛起', '或者', '站', '在', '一匹', '蹶', '腿', '的'), tags=('Stand', 'Arm', 'Bone', 'Be', 'Break', 'Or', 'Would you like to let', 'A', 'Bull', 'Put', 'I', 'Dangling', 'Throw it up.', 'Or', 'Stand', 'In', 'One horse.', 'The', 'Leg', 'The'))),
#              ('640',
#               Sentence(words=('马', '后面', '任', '马蹄', '踢', '向', '我', '胸膛', '—', '—', '”', '“', '嘘', '简', '！', '你', '太', '看重', '人', '的'), tags=('Horse', 'Behind', 'Any', 'Horseshoe', 'Play', 'To', 'I', 'Chest', '—', '—', '"', '"', 'Hush', 'Jane', '!', 'You', 'Too', 'Value', 'People', 'The'))),
#              ('660',
#               Sentence(words=('爱', '你', '的', '感情', '太', '冲动', '你', '的', '情绪', '太', '激烈', '一只', '至高无上', '的', '手', '创造', '你', '的', '躯体', '又'), tags=('Love', 'You', 'The', 'Feelings', 'Too', 'Impulse', 'You', 'The', 'Emotions', 'Too', 'Fierce', 'One', 'Supreme', 'The', 'Hand', 'Create', 'You', 'The', 'Body', 'And again'))),
#              ('680',
#               Sentence(words=('往里面', '注入', '生命', '这', '只', '手除', '造就', '你', '脆弱', '的', '自身', '或者', '同', '你', '一样', '脆弱', '的', '创造物', '之外', '还给'), tags=('Go inside.', 'Injection', 'Life', 'This', 'Only', 'Hand-off', 'Created', 'You', 'Fragile', 'The', 'Their own', 'Or', 'With', 'You', 'The same', 'Fragile', 'The', 'Creations', 'Outside', 'Back'))),
#              ('700',
#               Sentence(words=('你', '提供', '别的', '财富', '在', '地球', '和', '人类', '之外', '还有', '一个', '看不见', '的', '世界', '一个', '精灵', '王国', '这个', '世界', '包围'), tags=('You', 'Provide', 'Other', 'Wealth', 'In', 'Earth', 'And', 'Human', 'Outside', 'And also', 'One', 'Unseen', 'The', 'World', 'One', 'Elves', 'Kingdom', 'This one', 'World', 'Surrounded'))),
#              ('720',
#               Sentence(words=('着', '我们', '无所不在', '那些', '精灵', '们', '注视', '着', '我们', '奉命', '守护', '我们', '要是', '我们', '在', '痛苦', '和', '耻辱', '中', '死去'), tags=('On the', 'We', 'Ubiquitous', 'Those', 'Elves', 'We', 'Watching', 'On the', 'We', 'Ordered', 'Guardian', 'We', 'If', 'We', 'In', 'Pain', 'And', 'Shame', 'In', 'Die'))),
#              ('740',
#               Sentence(words=('；', '要是', '来自', '四面八方', '的', '鄙视', '刺伤', '我们', '；', '要是', '仇恨', '压垮', '我们', '天使', '们', '会', '看到', '我们', '遭受', '折磨'), tags=(';', 'If', 'From', 'Far', 'The', 'Despise', 'Stabbed', 'We', ';', 'If', 'Hatred', 'Overwhelmed', 'We', 'Angel', 'We', 'Yes', 'See', 'We', 'Suffered', 'Torture'))),
#              ('760',
#               Sentence(words=('会', '承认', '我们', '清白', '无辜', '如果', '我们', '确实', '清白', '无辜', '我', '知道', '你', '受到', '布罗克', '赫斯特', '先生', '指控', '但', '这种'), tags=('Yes', 'Admit', 'We', 'Innocent', 'Innocent', 'If', 'We', 'Do', 'Innocent', 'Innocent', 'I', 'Know', 'You', 'Be', 'Brock', 'Hurst', 'Mr', 'Charges', 'But', 'This'))),
#              ('780',
#               Sentence(words=('指控', '软弱无力', '夸大其词', '不过', '是从', '里德', '太太', '那儿', '转手', '得来', '的', '因为', '我', '从', '你', '热情', '的', '眼睛', '里', '从'), tags=('Charges', 'Weak', 'Exaggerating', 'But', 'It is from', 'Reed', 'Wife', 'There', 'Turn hands', 'Got to come.', 'The', 'Because', 'I', 'From', 'You', 'Enthusiasm', 'The', 'Eyes', 'Inside', 'From'))),
#              ('800',
#               Sentence(words=('你', '明净', '的', '前额', '上', '看到', '诚实', '的', '本性', '上帝', '只不过', '等待', '灵魂', '与', '肉体', '分离', '以', '赐予', '我们', '充分'), tags=('You', 'Clear', 'The', 'Forehead', 'On', 'See', 'Honest', 'The', 'Nature', 'Oh, God', 'Just', 'Wait', 'Soul', 'And', 'Body', 'Separation', 'To', 'Give', 'We', 'Fully'))),
#              ('820',
#               Sentence(words=('酬报', '当', '生命', '很快', '结束', '死亡', '必定', '成为', '幸福', '与', '荣耀', '的', '入口', '时', '我们', '为什么', '还要', '因为', '忧伤', '而'), tags=('Rewards', 'When', 'Life', 'Soon', 'End', 'Death', 'Must', 'Become', 'Happiness', 'And', 'Glory', 'The', 'Entrance', 'When', 'We', 'Why', 'And also', 'Because', 'Sad', 'And'))),
#              ('840',
#               Sentence(words=('沉沦', '呢', '”', '我', '默不作声', '海伦', '已经', '使', '我', '平静下来', '但', '在', '她', '所', '传递', '的', '宁静', '里', '混杂着', '一种'), tags=('Sink', 'What about?', '"', 'I', 'Silent', 'Helen', 'Have', 'Make', 'I', 'Calm down.', 'But', 'In', 'She', 'The', 'Passed', 'The', 'Quiet', 'Inside', 'Mixed up', 'A'))),
#              ('860',
#               Sentence(words=('难以', '言传', '的', '悲哀', '她', '说话', '时', '我', '感受', '到', '这种', '悲哀', '但', '不', '知道', '它', '从何而来', '话', '一', '讲完'), tags=("Can't", 'Words', 'The', 'Sad', 'She', 'Speak', 'When', 'I', 'Feel', 'To', 'This', 'Sad', 'But', 'No', 'Know', 'It', 'Where did it come from?', 'Words', 'One', 'Finished.'))),
#              ('880',
#               Sentence(words=('她', '开始', '有点', '气急', '短短', '地', '咳', '几声', '我', '立刻', '忘掉', '自己', '的', '苦恼', '隐隐约约', '地', '为', '她', '担起', '心来'), tags=('She', 'Begin', 'A little bit.', 'Flustered', 'Just', 'Ground', 'Cough', 'A few sounds.', 'I', 'Immediately', 'Forget', 'Myself', 'The', 'Distress', 'Vague', 'Ground', 'For', 'She', 'Take up', 'Heart to come'))),
#              ('900',
#               Sentence(words=('我', '把头', '靠', '在', '海伦', '的', '肩上', '双手', '抱住', '她', '的', '腰', '她', '紧紧', '搂住', '我', '两', '人', '默默地', '偎依'), tags=('I', 'Head', 'By', 'In', 'Helen', 'The', 'Shoulder', 'Hands', 'Hold on.', 'She', 'The', 'Lumbar', 'She', 'Tightly', 'Hold on.', 'I', 'Two', 'People', 'Silently', 'Nestling'))),
#              ('920',
#               Sentence(words=('着', '我们', '没', '坐', '多久', '另外', '一个', '人', '进来', '这时', '一阵', '刚', '起', '的', '风吹', '开', '沉重', '的', '云块', '露出'), tags=('On the', 'We', "Didn't", 'Sit', 'How long', 'Other than that', 'One', 'People', 'In', 'Then', 'A', 'Just', 'From', 'The', 'The wind blows', 'Open', 'Heavy', 'The', 'Cloud Block', 'Show'))),
#              ('940',
#               Sentence(words=('月亮', '月光', '泻', '进', '近旁', '的', '窗户', '清晰', '地', '照亮', '我们', '两', '人', '和', '那个', '走近', '的', '身影', '我们', '立刻'), tags=('Moon', 'Moonlight', 'Diarrhea', 'Into', 'Near', 'The', 'Window', 'Clear', 'Ground', 'Light', 'We', 'Two', 'People', 'And', 'That one', 'Get close', 'The', 'Figure', 'We', 'Immediately'))),
#              ('960',
#               Sentence(words=('认出来', '那', '是', '坦普尔', '小姐', '“', '我', '是', '特地来', '找', '你', '的', '简', '·', '爱', '”', '她', '说', '“', '我'), tags=('Recognize it.', 'That', 'Is', 'Temple', 'Miss', '"', 'I', 'Is', 'Come on.', 'Find', 'You', 'The', 'Jane', '·', 'Love', '"', 'She', 'Said', '"', 'I'))),
#              ('980',
#               Sentence(words=('要', '你', '到', '我', '房间', '里', '去', '既然', '海伦', '·', '彭斯', '也', '在', '那', '她', '也', '一', '起来', '吧', '”'), tags=('To', 'You', 'To', 'I', 'Room', 'Inside', 'To', 'Since', 'Helen', '·', 'Burns', 'Also', 'In', 'That', 'She', 'Also', 'One', 'Get up', "Let's do it", '"'))),
#              ('1000',
#               Sentence(words=('我们', '去在', '这位', '校长', '的', '带领', '下', '我们', '穿过', '一条条', '复杂', '的', '过道', '登上', '一座', '楼梯', '才', '到', '她', '的'), tags=('We', 'Go in', 'The', 'Principal', 'The', 'Lead', 'Next', 'We', 'Through', 'One bar', 'Complex', 'The', 'Aisle', 'Boarded', 'One', 'Stairs', "It's just", 'To', 'She', 'The'))),
#              ('1020',
#               Sentence(words=('寓所', '房间', '里', '炉火', '正旺', '显得', '很', '惬意', '坦普尔', '小姐', '叫', '海伦', '·', '彭斯', '坐在', '火炉', '一边', '的', '低', '靠手'), tags=('Apartments', 'Room', 'Inside', 'Fire', 'Zhengwang', 'Look', 'Is', 'Comfortable', 'Temple', 'Miss', 'Call', 'Helen', '·', 'Burns', 'Sitting in the', 'Furnace', 'Side', 'The', 'Low', 'Hands on it.'))),
#              ('1040',
#               Sentence(words=('椅', '里', '她', '自己', '在', '另', '一条', '靠手', '椅', '上', '坐下', '把', '我', '叫', '到', '她', '身边', '“', '全都', '过去'), tags=('Chair', 'Inside', 'She', 'Myself', 'In', 'Other', 'One', 'Hands on it.', 'Chair', 'On', 'Sit down', 'Put', 'I', 'Call', 'To', 'She', 'Side', '"', 'All', 'Past'))),
#              ('1060',
#               Sentence(words=('吗', '”', '她', '俯身', '瞧', '着', '我', '的', '脸', '问', '“', '把', '伤心', '都', '哭', '光', '”', '“', '恐怕', '我'), tags=('Do you?', '"', 'She', 'Leaned', 'Look', 'On the', 'I', 'The', 'Face', 'Ask', '"', 'Put', 'Sad', 'All', 'Cry', 'Light', '"', '"', "'m afraid", 'I'))),
#              ('1080',
#               Sentence(words=('永远', '做', '不到', '”', '“', '为什么', '”', '“', '因为', '我', '被', '冤枉', '小姐', '你', '还有', '所有', '其他人', '都', '会', '认为'), tags=('Forever', 'Do', 'Less than', '"', '"', 'Why', '"', '"', 'Because', 'I', 'Be', 'Wronged', 'Miss', 'You', 'And also', 'All', 'The others.', 'All', 'Yes', 'Think'))),
#              ('1100',
#               Sentence(words=('我', '很', '坏', '”', '“', '孩子', '我们', '会', '根据', '你', '的', '表现', '来', '看待', '你', '的', '继续', '做', '个', '好'), tags=('I', 'Is', 'Bad', '"', '"', 'Children', 'We', 'Yes', 'Under', 'You', 'The', 'Performance', 'To', 'Look at', 'You', 'The', 'Go on', 'Do', 'A', 'Good'))),
#              ('1120',
#               Sentence(words=('姑娘', '你', '会', '使', '我', '满意', '的', '”', '“', '我会', '吗', '坦普尔', '小姐', '”', '“', '你', '会', '的', '”', '她'), tags=('Girl', 'You', 'Yes', 'Make', 'I', 'Satisfaction', 'The', '"', '"', 'I will', 'Do you?', 'Temple', 'Miss', '"', '"', 'You', 'Yes', 'The', '"', 'She'))),
#              ('1140',
#               Sentence(words=('说', '着', '用', '胳膊', '搂住', '我', '“', '现在', '你', '告诉', '我', '被', '布罗克', '赫斯特', '称为', '你', '的', '恩人', '的', '那位'), tags=('Said', 'On the', 'Use', 'Arm', 'Hold on.', 'I', '"', 'Right now', 'You', 'Tell', 'I', 'Be', 'Brock', 'Hurst', 'Called', 'You', 'The', 'Benefactor', 'The', 'The one.'))),
#              ('1160',
#               Sentence(words=('太太', '是', '谁', '”', '“', '里德', '太太', '我', '舅舅', '的', '妻子', '我', '舅舅', '去世', '他', '把', '我', '交给', '她', '照顾'), tags=('Wife', 'Is', 'Who', '"', '"', 'Reed', 'Wife', 'I', 'Uncle', 'The', 'Wife', 'I', 'Uncle', 'Died', 'He', 'Put', 'I', 'To', 'She', 'Care'))),
#              ('1180',
#               Sentence(words=('”', '“', '那他', '不是', '自己', '主动', '要', '抚养', '你', '”', '“', '不是', '小姐', '她', '感到', '很', '遗憾', '不得不', '抚养', '我'), tags=('"', '"', 'Then he', 'No', 'Myself', 'Active', 'To', 'Raise', 'You', '"', '"', 'No', 'Miss', 'She', 'Feel', 'Is', 'Regret', 'Had', 'Raise', 'I'))),
#              ('1200',
#               Sentence(words=('但', '我', '常', '听', '仆人', '们', '说', '我', '舅舅', '临终前', '要', '她', '答应', '永远', '抚养', '我', '”', '“', '好', '吧'), tags=('But', 'I', 'Often', 'Listen', 'Servant', 'We', 'Said', 'I', 'Uncle', 'Before he died.', 'To', 'She', 'Promise', 'Forever', 'Raise', 'I', '"', '"', 'Good', "Let's do it"))),
#              ('1220',
#               Sentence(words=('简', '你', '知道', '或者', '至少', '我', '要', '让', '你', '知道', '罪犯', '在', '被', '起诉', '时', '往往', '允许', '为', '自己', '辩护'), tags=('Jane', 'You', 'Know', 'Or', 'At least', 'I', 'To', 'Let', 'You', 'Know', 'Criminal', 'In', 'Be', 'Sue', 'When', 'Often', 'Allow', 'For', 'Myself', 'Defense'))),
#              ('1240',
#               Sentence(words=('你', '被', '指责', '为', '说谎', '那', '你', '就', '在', '我', '面前', '尽力', '为', '自己', '辩护', '吧', '凡是', '你', '记得', '的'), tags=('You', 'Be', 'Accused', 'For', 'Lie', 'That', 'You', 'Just.', 'In', 'I', 'Front', 'Try', 'For', 'Myself', 'Defense', "Let's do it", 'All', 'You', 'Remember', 'The'))),
#              ('1260',
#               Sentence(words=('事实', '你', '都', '说', '可别', '加油添醋', '夸大其词', '”', '我', '暗', '下决心', '要', '把', '话', '说', '得', '恰如其分', '准确无误', '我', '思考'), tags=('Fact', 'You', 'All', 'Said', "But don't.", 'Add vinegar to the refueling', 'Exaggerating', '"', 'I', 'Dark', 'Determined', 'To', 'Put', 'Words', 'Said', 'Get it.', 'Appropriate', 'Accurate', 'I', 'Thinking'))),
#              ('1280',
#               Sentence(words=('几分钟', '把', '该', '说', '的话', '理出', '个', '头绪', '便', '一五一十', '地向', '她', '诉说', '我', '悲苦', '的', '童年', '我己', '激动', '得'), tags=('A few minutes.', 'Put', 'The', 'Said', 'Words', 'Make a sense', 'A', 'Clue', 'Poe', 'One fifty, fifty.', 'To', 'She', 'Tell', 'I', 'Misery', 'The', 'Childhood', "I'm my own.", 'Excited', 'Get it.'))),
#              ('1300',
#               Sentence(words=('精疲力尽', '所以', '谈到', '这个', '伤心', '的', '话题', '时', '说话', '比', '平时', '要', '克制', '我', '还', '记住', '海伦', '的', '告诫', '不'), tags=('Exhausted', 'So', 'Talked about', 'This one', 'Sad', 'The', 'Topic', 'When', 'Speak', 'Than', 'Usually', 'To', 'Restraint', 'I', 'Also', 'Remember', 'Helen', 'The', 'Warned', 'No'))),
#              ('1320',
#               Sentence(words=('一味', '沉溺于', '怨词', '叙述', '时所', '掺杂', '的', '刻薄', '与', '恼恨', '比', '往日', '少', '得', '多', '而且', '态度', '收敛', '内容', '简明'), tags=('Blindly', 'Indulge in', 'Complaints', 'Narrative', 'When', 'Doped', 'The', 'Mean', 'And', 'Hate', 'Than', 'Past', 'Less', 'Get it.', 'Many', 'And', 'Attitude', 'Convergence', 'Content', 'Concise'))),
#              ('1340',
#               Sentence(words=('听', '来', '更加', '可信', '我', '觉得', '我', '往下', '说', '时', '坦普尔', '小姐', '完全', '相信', '我', '的话', '我', '在', '叙述', '自己'), tags=('Listen', 'To', 'More', 'Credible', 'I', 'Think', 'I', 'Down', 'Said', 'When', 'Temple', 'Miss', 'Completely', 'Believe', 'I', 'Words', 'I', 'In', 'Narrative', 'Myself'))),
#              ('1360',
#               Sentence(words=('的', '经历', '时', '还', '提到', '劳埃德', '先生', '说', '他', '在', '我', '昏厥', '后来', '看过', '我', '我', '永远', '忘', '不', '可怕'), tags=('The', 'Experience', 'When', 'Also', 'Mentioned', 'Lloyd', 'Mr', 'Said', 'He', 'In', 'I', 'Fainting', 'Later', "I've seen it", 'I', 'I', 'Forever', 'Forget', 'No', 'Terrible'))),
#              ('1380',
#               Sentence(words=('的', '红房子', '事件', '有', '详细', '诉说', '时', '我', '的', '情绪', '有点', '失态', '因为', '当', '里德', '太太', '断然拒绝', '我', '发疯', '似的'), tags=('The', 'Red House', 'Event', 'Yes', 'With', 'Tell', 'When', 'I', 'The', 'Emotions', 'A little bit.', 'Loss', 'Because', 'When', 'Reed', 'Wife', 'Categorically refused.', 'I', 'Crazy', "It's like."))),
#              ('1400',
#               Sentence(words=('求饶', '把', '我', '第二次', '关进', '黑洞洞', '闹鬼', '的', '房子', '时', '那种', '阵阵', '揪心', '的', '痛苦', '在', '记忆', '中', '是', '什么'), tags=('Beg', 'Put', 'I', 'Second time', 'Close in', 'Dark', 'Haunted', 'The', 'House', 'When', 'That', 'Bursts', 'Anxious', 'The', 'Pain', 'In', 'Memory', 'In', 'Is', 'What the'))),
#              ('1420',
#               Sentence(words=('也', '抚慰', '不', '的', '我', '讲完', '坦普尔', '小姐', '默默地', '看', '我', '几分钟', '随后', '说', '“', '劳埃德', '先生', '我', '有些', '认识'), tags=('Also', 'Comfort', 'No', 'The', 'I', 'Finished.', 'Temple', 'Miss', 'Silently', 'See', 'I', 'A few minutes.', 'Then', 'Said', '"', 'Lloyd', 'Mr', 'I', 'Some', 'Know'))),
#              ('1440',
#               Sentence(words=('我会', '写信给', '他', '的', '要是', '他', '的', '答复', '同', '你', '说', '的', '相符', '我们', '会', '公开', '澄清', '对', '你', '的'), tags=('I will', 'Write to', 'He', 'The', 'If', 'He', 'The', 'Reply', 'With', 'You', 'Said', 'The', 'Match', 'We', 'Yes', 'Public', 'Clarify', 'Right', 'You', 'The'))),
#              ('1460',
#               Sentence(words=('诋毁', '对', '我', '来说', '简', '现在', '你', '说', '的', '相符', '我们', '会', '公开', '澄清', '对', '你', '的', '诋毁', '对', '我'), tags=('Slander', 'Right', 'I', 'Say,', 'Jane', 'Right now', 'You', 'Said', 'The', 'Match', 'We', 'Yes', 'Public', 'Clarify', 'Right', 'You', 'The', 'Slander', 'Right', 'I'))),
#              ('1480',
#               Sentence(words=('来说', '简', '现在', '你', '已经', '清白', '”', '她', '吻吻', '我', '仍旧', '让', '我', '呆', '在', '她', '身边', '我', '很', '乐意'), tags=('Say,', 'Jane', 'Right now', 'You', 'Have', 'Innocent', '"', 'She', 'Kiss', 'I', 'Still', 'Let', 'I', 'Stay', 'In', 'She', 'Side', 'I', 'Is', 'Happy'))),
#              ('1500',
#               Sentence(words=('站', '在', '那里', '因为', '我', '端详', '着', '她', '的', '面容', '她', '的', '装束', '她', '的', '一二件', '饰品', '她', '那', '白皙'), tags=('Stand', 'In', 'There', 'Because', 'I', 'Detailed', 'On the', 'She', 'The', 'Countenance', 'She', 'The', 'Attire', 'She', 'The', 'One or two pieces', 'Jewelry', 'She', 'That', 'White'))),
#              ('1520',
#               Sentence(words=('的', '额头', '她', '那一', '团团', '闪光', '的', '卷发', '和', '乌黑', '发亮', '的', '眼睛', '时', '得到', '一种', '孩子', '般的', '喜悦', '她'), tags=('The', 'Forehead', 'She', 'That one.', 'Round', 'Flash', 'The', 'Curls', 'And', 'Black', 'Shiny', 'The', 'Eyes', 'When', 'Get', 'A', 'Children', 'Like', 'Joy', 'She'))),
#              ('1540',
#               Sentence(words=('开始', '同', '海伦', '·', '彭斯', '说话', '“', '今晚', '你', '感觉', '怎么样', '海伦', '你', '今天', '咳得', '厉害', '吗', '”', '“', '我'), tags=('Begin', 'With', 'Helen', '·', 'Burns', 'Speak', '"', 'Tonight', 'You', 'Feel', 'What do you think', 'Helen', 'You', 'Today', "I can've got a cough.", "It's awesome.", 'Do you?', '"', '"', 'I'))),
#              ('1560',
#               Sentence(words=('想', '不', '太', '厉害', '小姐', '”', '“', '胸部', '的', '疼痛', '呢', '”', '“', '好', '一点', '”', '坦普尔', '小姐', '站', '起来'), tags=('Think', 'No', 'Too', "It's awesome.", 'Miss', '"', '"', 'Chest', 'The', 'Pain', 'What about?', '"', '"', 'Good', 'A little.', '"', 'Temple', 'Miss', 'Stand', 'Get up'))),
#              ('1580',
#               Sentence(words=('拉', '过', '她', '的', '手', '按', '按', '脉搏', '随后', '回到', '自己', '的', '座位', '上', '坐定', '以后', '我', '听', '她', '轻声'), tags=('Pull', 'Too much', 'She', 'The', 'Hand', 'By', 'By', 'Pulse', 'Then', 'Back', 'Myself', 'The', 'Seat', 'On', 'Sit down.', 'later', 'I', 'Listen', 'She', 'Softly'))),
#              ('1600',
#               Sentence(words=('叹口气', '她', '沉思', '一会', '随后', '回过', '神', '来', '高兴', '地', '说', '“', '不过', '今晚', '你们', '俩', '是', '我', '的', '客人'), tags=('Sigh', 'She', 'Meditation', 'For a moment.', 'Then', 'Back in.', 'God', 'To', 'Happy', 'Ground', 'Said', '"', 'But', 'Tonight', 'You guys', 'Two', 'Is', 'I', 'The', 'Guests'))),
#              ('1620',
#               Sentence(words=('我', '必须', '按', '客人', '相待', '”', '她', '按', '下', '铃', '“', '巴巴拉', '”', '她', '对', '应召', '而来', '的', '佣人', '说'), tags=('I', 'Have to', 'By', 'Guests', 'Wait inge', '"', 'She', 'By', 'Next', 'Bell', '"', 'Barbara', '"', 'She', 'Right', 'Call', 'And to come', 'The', 'Servant', 'Said'))),
#              ('1640',
#               Sentence(words=('“', '我', '还', '没有', '用', '茶', '呢', '你', '把', '盘子', '端来', '给', '两位', '小姐', '也', '放上', '杯子', '”', '盘子', '很快'), tags=('"', 'I', 'Also', 'No', 'Use', 'Tea', 'What about?', 'You', 'Put', 'Plate', 'End', 'To give', 'Two', 'Miss', 'Also', 'Put it on.', 'Cup', '"', 'Plate', 'Soon'))),
#              ('1660',
#               Sentence(words=('就', '端', '来', '在', '我', '的', '目光', '中', '这些', '放在', '火炉', '旁', '小园', '桌上', '的', '瓷杯', '和', '亮晃晃', '的', '茶壶'), tags=('Just.', 'End', 'To', 'In', 'I', 'The', 'Eyes', 'In', 'These', 'Put in', 'Furnace', 'Side', 'Small Garden', 'On the table.', 'The', 'Porcelain cup', 'And', 'Flashing', 'The', 'Teapot'))),
#              ('1680',
#               Sentence(words=('多么', '漂亮', '！', '那', '饮料', '的', '热气', '和', '烤面包', '的', '味儿', '多', '香', '！', '但使', '我', '失望', '的', '是因为', '我'), tags=('How', 'Pretty', '!', 'That', 'Drink', 'The', 'Heat', 'And', 'Toast', 'The', 'Smell', 'Many', 'Aroma', '!', 'But make', 'I', 'Disappointed', 'The', "It's because", 'I'))),
#              ('1700',
#               Sentence(words=('已', '开始', '觉得', '饿', '我', '发现', '那', '份儿', '很小', '坦普尔', '小姐', '也', '同样', '注意', '到', '“', '巴巴拉', '”', '她', '说'), tags=('Has', 'Begin', 'Think', 'Hungry', 'I', 'Found', 'That', 'A serving.', "It's small.", 'Temple', 'Miss', 'Also', 'Same', 'Attention', 'To', '"', 'Barbara', '"', 'She', 'Said'))),
#              ('1720',
#               Sentence(words=('“', '不能', '再', '拿', '点', '面包', '和', '黄油', '来', '吗', '这', '不够', '三个', '人', '吃', '呀', '”', '巴巴拉', '走', '出去'), tags=('"', 'No', 'And again', 'Take', 'Point', 'Bread', 'And', 'Butter', 'To', 'Do you?', 'This', 'Enough', 'Three', 'People', 'Eat', 'Oh, yes.', '"', 'Barbara', 'Go', 'Get out'))),
#              ('1740',
#               Sentence(words=('但', '很快', '又', '回来', '“', '小姐', '哈登', '太太', '说', '已经', '按', '平时', '的', '份量', '送来', '”', '得', '说明', '一下', '哈登'), tags=('But', 'Soon', 'And again', 'Come back', '"', 'Miss', 'Harden', 'Wife', 'Said', 'Have', 'By', 'Usually', 'The', 'Weight', "It's coming.", '"', 'Get it.', 'Description', 'One moment.', 'Harden'))),
#              ('1760',
#               Sentence(words=('太太', '是', '个', '管家', '这个', '女人', '很', '合', '布罗克', '赫斯特', '先生', '的', '心意', '两', '人', '的', '心', '一样', '都', '是'), tags=('Wife', 'Is', 'A', 'Housekeeper', 'This one', 'Woman', 'Is', 'The combination', 'Brock', 'Hurst', 'Mr', 'The', 'Mind', 'Two', 'People', 'The', 'Heart', 'The same', 'All', 'Is'))),
#              ('1780',
#               Sentence(words=('铁', '铸', '的', '“', '啊', '好', '吧', '”', '坦普尔', '小姐', '回答', '“', '我', '想', '我们', '只好', '将', '就', '巴巴拉', '”'), tags=('Iron', 'Casting', 'The', '"', 'Ah, yes.', 'Good', "Let's do it", '"', 'Temple', 'Miss', 'Reply', '"', 'I', 'Think', 'We', 'Had', 'Will', 'Just.', 'Barbara', '"'))),
#              ('1800',
#               Sentence(words=('等', '这位', '姑娘', '一', '走', '她', '便', '笑', '着', '补充', '说', '“', '幸好', '我', '自己', '还', '能够', '弥补', '这次', '的'), tags=('Wait, wait, wait', 'The', 'Girl', 'One', 'Go', 'She', 'Poe', 'Laugh', 'On the', 'Add', 'Said', '"', 'Fortunately', 'I', 'Myself', 'Also', 'Can', 'Make', 'This', 'The'))),
#              ('1820',
#               Sentence(words=('欠缺', '”', '她', '邀', '海伦', '与', '我', '凑近', '桌子', '在', '我们', '俩', '面前', '各', '放', '一杯', '茶', '和', '一小片', '可口'), tags=('Lack', '"', 'She', 'Invited', 'Helen', 'And', 'I', 'Closer', 'Table', 'In', 'We', 'Two', 'Front', 'Each', 'Put', 'One cup.', 'Tea', 'And', 'A small piece.', 'Delicious'))),
#              ('1840',
#               Sentence(words=('却', '很薄', '的', '烤面包', '随后', '打开', '抽屉', '从', '里面', '抽出', '一个', '纸包', '我们', '眼前', '立刻', '出现', '一个', '大', '果子', '饼'), tags=('But', "It's thin.", 'The', 'Toast', 'Then', 'Open it', 'Drawer', 'From', 'Inside', 'Take', 'One', 'Paper bag', 'We', 'Eyes', 'Immediately', 'Appear', 'One', 'Big', 'Fruit', 'Cake'))),
#              ('1860',
#               Sentence(words=('“', '我', '本', '想', '让', '你们', '各自', '带', '一点儿', '回去', '”', '她', '说', '“', '但是', '因为', '烤面包', '这么', '少', '你们'), tags=('"', 'I', 'This', 'Think', 'Let', 'You guys', 'Their', 'Take', 'A little', 'Get back', '"', 'She', 'Said', '"', 'But', 'Because', 'Toast', 'So', 'Less', 'You guys'))),
#              ('1880',
#               Sentence(words=('现在', '就', '得', '吃掉', '”', '她', '很大', '方地', '把', '饼', '切成', '厚片', '那天', '夜晚', '我们', '吃', '香甜', '的', '饮料', '和'), tags=('Right now', 'Just.', 'Get it.', 'Eat', '"', 'She', "It's big.", 'Square', 'Put', 'Cake', 'Cut', 'Thick slices', 'That', 'Night', 'We', 'Eat', 'Sweet', 'The', 'Drink', 'And'))),
#              ('1900',
#               Sentence(words=('食品', '享受', '一次', '盛宴', '当', '她', '慷慨', '提供', '的', '美食', '满足', '我们', '的', '辘辘', '饥肠', '时', '我们', '的', '女主人', '面'), tags=('Food', 'Enjoy', 'A', 'Feast', 'When', 'She', 'Generous', 'Provide', 'The', 'Food', 'Meet', 'We', 'The', "It's a no-one.", 'Hungry', 'When', 'We', 'The', 'Hostess', 'Surface'))),
#              ('1920',
#               Sentence(words=('带', '满意', '的', '微笑', '望', '着', '我们', '那', '笑容', '也', '一样', '令人', '愉快', '吃', '完', '茶点', '端', '走', '托盘', '后'), tags=('Take', 'Satisfaction', 'The', 'Smile', 'Look', 'On the', 'We', 'That', 'Smile', 'Also', 'The same', 'Is', 'Happy', 'Eat', 'Finish', 'Refreshment', 'End', 'Go', 'Tray', 'After'))),
#              ('1940',
#               Sentence(words=('她', '又', '招呼', '我们', '到', '火炉', '边', '去', '我们', '两', '人', '一边', '一个', '坐在', '她', '身旁', '这时', '她', '与', '海伦'), tags=('She', 'And again', 'Say hello', 'We', 'To', 'Furnace', 'Side', 'To', 'We', 'Two', 'People', 'Side', 'One', 'Sitting in the', 'She', 'Side', 'Then', 'She', 'And', 'Helen'))),
#              ('1960',
#               Sentence(words=('开始', '谈话', '而', '我', '能', '被', '允许', '旁听', '实在', '也', '是', '有幸', '坦普尔', '小姐', '向来', '神态', '安详', '风度', '庄重', '谈吐'), tags=('Begin', 'Talk', 'And', 'I', 'Yes', 'Be', 'Allow', 'Audit', 'Really', 'Also', 'Is', 'Fortunate enough', 'Temple', 'Miss', 'Always', 'Look', 'Serene', 'Manners', 'Solemn', 'Talk'))),
#              ('1980',
#               Sentence(words=('文雅', '得体', '这', '使', '她', '不至于', '陷入', '狂热', '激奋', '和', '浮躁', '同样', '也', '使', '看着', '她', '和', '倾听', '她', '的'), tags=('Gentle', 'Decent', 'This', 'Make', 'She', 'Not', 'Into', 'Fanatical', 'Exciting', 'And', 'Impetuous', 'Same', 'Also', 'Make', 'Look at it.', 'She', 'And', 'Listening', 'She', 'The'))),
#              ('2000',
#               Sentence(words=('人', '出于', '一种', '敬畏', '心情', '不会', '露出', '过份', '的', '喜悦', '这', '就是', '我', '此刻', '的', '情感', '但', '海伦', '的', '情况'), tags=('People', 'For', 'A', 'Fear', 'Mood', 'No', 'Show', 'Too much', 'The', 'Joy', 'This', 'It is', 'I', 'Now', 'The', 'Emotion', 'But', 'Helen', 'The', 'Situation'))),
#              ('2020',
#               Sentence(words=('却', '使', '我', '十分', '吃惊', '因为', '茶点', '振奋精神', '炉火', '在', '熊熊燃烧', '因为', '亲爱', '的', '导师', '在场', '并待', '她', '很', '好'), tags=('But', 'Make', 'I', 'Very', 'Surprised', 'Because', 'Refreshment', 'Invigorating spirits', 'Fire', 'In', 'Burning', 'Because', 'Dear', 'The', 'Mentor', 'Present', 'And wait', 'She', 'Is', 'Good'))),
#              ('2040',
#               Sentence(words=('也许', '不止', '这', '一切', '而是', '她', '独一无二', '的', '头脑', '中', '的', '某种', '东西', '激发', '她', '内在', '的', '种种', '力量', '这些'), tags=('Maybe', 'More than', 'This', 'All', 'But', 'She', 'Unique', 'The', 'Mind', 'In', 'The', 'Some kind of', 'Things', 'Stimulate', 'She', 'Inner', 'The', 'Various', 'Power', 'These'))),
#              ('2060',
#               Sentence(words=('力量', '被', '唤醒', '被', '点燃', '起初', '闪烁', '在', '一向', '苍白', '而', '没有', '血色', '现在', '却', '容光焕发', '的', '脸上', '随后', '显露'), tags=('Power', 'Be', 'Awaken', 'Be', 'Lit', 'Initially', 'Flashing', 'In', 'Always', 'Pale', 'And', 'No', 'Scarlet', 'Right now', 'But', 'Radiant', 'The', 'Face', 'Then', 'Revealed'))),
#              ('2080',
#               Sentence(words=('在', '她', '水灵灵', '炯炯有神', '的', '眼睛', '里', '这双', '眼睛', '突然', '之间', '获得', '一种', '比', '坦普尔', '小姐', '的', '眼睛', '更为', '独特'), tags=('In', 'She', 'Water Spirit', 'Sparkle', 'The', 'Eyes', 'Inside', 'This pair of', 'Eyes', 'Suddenly', 'Between', 'Get', 'A', 'Than', 'Temple', 'Miss', 'The', 'Eyes', 'More', 'Unique'))),
#              ('2100',
#               Sentence(words=('的', '美', '它', '没有', '好看', '的', '色彩', '没有', '长长的', '睫毛', '没有', '用', '眉笔', '描过', '的', '眉毛', '却', '那么', '意味深长', '那么'), tags=('The', 'Beauty', 'It', 'No', 'Nice', 'The', 'Color', 'No', 'Long', 'Lashes', 'No', 'Use', 'Eyebrow pen', 'Stroke', 'The', 'Eyebrows', 'But', 'So', 'Meaningful', 'So'))),
#              ('2120',
#               Sentence(words=('流动', '不息', '那么', '光芒四射', '随后', '她', '似乎', '心口', '交融', '说话', '流畅', '这些', '话', '从', '什么', '源头', '流', '出来', '我', '无从'), tags=('Flow', 'Endless', 'So', 'Shining', 'Then', 'She', 'Seems', 'Heart', 'Blend', 'Speak', 'Smooth', 'These', 'Words', 'From', 'What the', 'Source', 'Flow', 'Come out', 'I', "Don't"))),
#              ('2140',
#               Sentence(words=('判断', '一个十四岁', '的', '女孩', '有', '这样', '活跃', '这样', '宽大', '的', '胸怀', '装得', '下', '这', '纯洁', '充盈', '炽热', '的', '雄辩', '之'), tags=('Judge', 'A fourteen-year-old.', 'The', 'Girl', 'Yes', 'This way,', 'Active', 'This way,', 'Wide', 'The', 'Mind', "It's loaded.", 'Next', 'This', 'Pure', 'Filling', 'Hot', 'The', 'Eloquent', 'The'))),
#              ('2160',
#               Sentence(words=('泉', '么', '这', '就是', '那个', '使', '我', '难以忘怀', '的', '夜晚', '海伦', '谈话', '的', '特色', '她', '的', '心灵', '仿佛', '急于', '要'), tags=('Spring', 'Is that', 'This', 'It is', 'That one', 'Make', 'I', 'Unforgettable', 'The', 'Night', 'Helen', 'Talk', 'The', 'Characteristics', 'She', 'The', 'Mind', 'Seems', 'Rush', 'To'))),
#              ('2180',
#               Sentence(words=('在', '短暂', '的', '片刻', '中', '过得', '与', '众多', '长期', '苟活', '的', '人', '一样', '充实', '她们', '谈论着', '我', '从未', '听说', '过'), tags=('In', 'Short', 'The', 'Moment', 'In', "It's been through", 'And', 'Many', 'Long', 'Live', 'The', 'People', 'The same', 'Enrich', 'They', 'Talking about', 'I', 'Never', 'Heard', 'Too much'))),
#              ('2200',
#               Sentence(words=('的', '事情', '谈到', '逝去', '的', '民族', '和', '时代', '谈到', '遥远', '的', '国度', '；', '谈到', '被', '发现', '或', '臆测', '到', '的'), tags=('The', 'Things', 'Talked about', 'Gone', 'The', 'National', 'And', 'Times', 'Talked about', 'Distant', 'The', 'Country', ';', 'Talked about', 'Be', 'Found', 'Or', 'Speculation', 'To', 'The'))),
#              ('2220',
#               Sentence(words=('自然界', '的', '奥秘', '还', '谈到', '书籍', '她们', '看过', '的', '书', '真', '多', '啊', '！', '她们', '掌握', '的', '知识', '真', '丰富'), tags=('Nature', 'The', 'Mystery', 'Also', 'Talked about', 'Books', 'They', "I've seen it", 'The', 'Book', 'Really', 'Many', 'Ah, yes.', '!', 'They', 'Master', 'The', 'Knowledge', 'Really', 'Rich'))),
#              ('2240',
#               Sentence(words=('！', '随后', '她们', '似乎', '对', '法国人', '名', '和', '法国', '作者', '如', '指掌', '但', '最', '使', '我', '惊讶', '的', '是', '这时'), tags=('!', 'Then', 'They', 'Seems', 'Right', 'French', 'Name', 'And', 'France', 'Author', 'Such as', 'Fingers', 'But', 'Most', 'Make', 'I', 'Surprised', 'The', 'Is', 'Then'))),
#              ('2260',
#               Sentence(words=('坦普尔', '小姐', '问', '海伦', '是不是', '抽空', '在', '复习', '她', '爸爸', '教', '她', '的', '拉丁文', '还', '从', '书架上', '取', '一', '本书'), tags=('Temple', 'Miss', 'Ask', 'Helen', "Isn't it", 'Time', 'In', 'Review', 'She', 'Father', 'Teach', 'She', 'The', 'Latin', 'Also', 'From', 'On the shelf', 'Take', 'One', 'Book'))),
#              ('2280',
#               Sentence(words=('吩咐', '她', '朗读', '和', '解释', '维吉尔', '①', '的', '一页', '著作', '海伦', '照着', '做', '我', '每', '听', '一行', '朗朗', '的', '诗句'), tags=('Told', 'She', 'Read', 'And', 'Explain', 'Virgil', '-1', 'The', 'One page', 'Works', 'Helen', 'Follow', 'Do', 'I', 'Every', 'Listen', 'Line', 'Lang lang', 'The', 'Verses'))),
#              ('2300',
#               Sentence(words=('对', '她', '也', '就', '愈加', '肃然起敬', '她', '几乎', '还', '没有', '读完', '上床', '铃', '就', '响', '已不', '允许', '任何', '拖延', '坦普尔'), tags=('Right', 'She', 'Also', 'Just.', 'More', 'Respect', 'She', 'Almost', 'Also', 'No', 'Read it.', 'Sleep', 'Bell', 'Just.', 'Ring', 'No longer', 'Allow', 'Any', 'Delay', 'Temple'))),
#              ('2320',
#               Sentence(words=('小姐', '拥抱', '我们', '俩', '她', '把', '我们', '搂', '到', '怀里', '时说', '“', '上帝保佑', '你们', '我', '的', '孩子', '们', '！', '”'), tags=('Miss', 'Hug', 'We', 'Two', 'She', 'Put', 'We', 'Hugs', 'To', 'In the arms', 'When it says,', '"', 'God bless you.', 'You guys', 'I', 'The', 'Children', 'We', '!', '"'))),
#              ('2340',
#               Sentence(words=('她', '拥抱', '海', '伦比', '拥抱', '我', '要', '长', '些', '更', '不', '情愿', '放', '她', '走', '她', '一直', '目送', '海伦', '到'), tags=('She', 'Hug', 'Sea', 'Lumby', 'Hug', 'I', 'To', 'Long', 'Some', 'More', 'No', "'d rather", 'Put', 'She', 'Go', 'She', 'Always', 'Watched', 'Helen', 'To'))),
#              ('2360',
#               Sentence(words=('门边', '为', '海伦', '她', '再次', '伤心地', '叹口气', '；', '为', '海伦', '她', '从', '脸上', '抹', '去', '一滴', '眼泪', '到', '寝室', '我们'), tags=('By the door.', 'For', 'Helen', 'She', 'Again', 'Sadly', 'Sigh', ';', 'For', 'Helen', 'She', 'From', 'Face', 'Wipe', 'To', 'One drop.', 'Tears', 'To', 'Bedroom', 'We'))),
#              ('2380',
#               Sentence(words=('听见', '斯卡', '查德', '小姐', '的', '嗓音', '她', '正在', '检查', '抽屉', '而且', '刚好', '已', '把', '海伦', '的', '抽屉', '拉', '出来', '我们'), tags=('Hear', 'Scar', 'Chad', 'Miss', 'The', 'Voice', 'She', 'Is', 'Check', 'Drawer', 'And', 'Just', 'Has', 'Put', 'Helen', 'The', 'Drawer', 'Pull', 'Come out', 'We'))),
#              ('2400',
#               Sentence(words=('一', '走进', '房间', '海伦', '便', '当头', '挨', '一顿', '痛骂', '她', '告诉', '海伦', '明天', '要', '把', '五六', '件', '叠', '得', '乱七八糟'), tags=('One', 'Into', 'Room', 'Helen', 'Poe', 'Pledge', 'Get', 'A meal.', 'Blackguarded', 'She', 'Tell', 'Helen', 'Tomorrow', 'To', 'Put', 'Five six', 'Pieces', 'Stack', 'Get it.', 'A big mess'))),
#              ('2420',
#               Sentence(words=('的', '东西', '别', '在', '她', '的', '肩上', '“', '我', '的', '东西', '乱糟糟', '的', '真', '丢脸', '”', '海伦', '喃喃地', '同', '我'), tags=('The', 'Things', "Don't", 'In', 'She', 'The', 'Shoulder', '"', 'I', 'The', 'Things', 'Mess', 'The', 'Really', 'Embarrassing', '"', 'Helen', 'Muttering', 'With', 'I'))),
#              ('2440',
#               Sentence(words=('说', '“', '我', '是', '想', '把', '它们', '放', '整齐', '的', '可', '总是', '忘', '”', '第二', '早上', '斯卡', '查德', '小姐', '在'), tags=('Said', '"', 'I', 'Is', 'Think', 'Put', 'They', 'Put', 'Neat', 'The', 'Can be', 'Always', 'Forget', '"', 'Second', 'Morning', 'Scar', 'Chad', 'Miss', 'In'))),
#              ('2460',
#               Sentence(words=('一块', '纸牌', '上', '写下', '十分', '醒目', '的', '两个', '字', '“', '邋遢', '”', '像', '经文', '护符', '匣', '一样', '把', '它', '系'), tags=('A', 'Card', 'On', 'Write it down.', 'Very', 'Striking', 'The', 'Two', 'Word', '"', 'Sloppy', '"', 'Like', 'Scripture', 'Talisman', 'Box', 'The same', 'Put', 'It', 'System'))),
#              ('2480',
#               Sentence(words=('在', '海伦', '那', '宽大', '温顺', '聪颖', '一', '付善', '相的', '额头', '上', '她', '那么', '耐心', '而', '毫无', '怨言', '地', '佩戴', '着'), tags=('In', 'Helen', 'That', 'Wide', 'Docile', 'Intelligent', 'One', 'Pay good', 'Phase', 'Forehead', 'On', 'She', 'So', 'Patience', 'And', 'No', 'Complaints', 'Ground', 'Wear', 'On the'))),
#              ('2500',
#               Sentence(words=('它', '视之为', '应得', '的', '惩罚', '一直', '戴', '到', '晚上', '下午', '放学', '以后', '斯卡', '查德', '小姐', '一', '走', '我', '便', '跑'), tags=('It', 'See it as', 'Deserve', 'The', 'Punished', 'Always', 'Wear', 'To', 'At night', 'Afternoon', 'School', 'later', 'Scar', 'Chad', 'Miss', 'One', 'Go', 'I', 'Poe', 'Run'))),
#              ('2520',
#               Sentence(words=('到', '海伦', '那儿', '一把', '撕下', '这块', '牌子', '把', '它', '扔进', '火', '里', '她', '所', '不会', '有', '的', '火气', '整天', '在我心中'), tags=('To', 'Helen', 'There', 'One.', 'Tore', 'This one.', 'Brand', 'Put', 'It', 'Throw it in.', 'Fire', 'Inside', 'She', 'The', 'No', 'Yes', 'The', 'Anger', 'Day', 'In my heart'))),
#              ('2540',
#               Sentence(words=('燃烧', '着', '大滴', '大滴', '热泪', '一直', '烧灼', '着', '我', '的', '脸颊', '她', '那', '付', '悲哀', '的', '听天由命', '的', '样子', '使'), tags=('Combustion', 'On the', 'Big drops', 'Big drops', 'Tears', 'Always', 'Burning', 'On the', 'I', 'The', 'Cheeks', 'She', 'That', 'Pay', 'Sad', 'The', 'Resigned', 'The', 'What it looks like', 'Make'))),
#              ('2560',
#               Sentence(words=('我', '心里', '痛苦', '得', '难以忍受', '上述', '事件', '发生', '后', '大约', '一周', '坦普尔', '小姐', '写给', '劳埃德', '先生', '的', '信', '有', '回音'), tags=('I', 'Heart', 'Pain', 'Get it.', "It's unbearable.", 'Above', 'Event', 'Happen', 'After', 'About', 'One week', 'Temple', 'Miss', 'To', 'Lloyd', 'Mr', 'The', 'Letter', 'Yes', 'Echo'))),
#              ('2580',
#               Sentence(words=('他', '在', '信', '中', '所说', '的', '进一步', '证实', '我', '的', '自述', '坦普尔', '小姐', '把', '全校师生', '召集', '起来', '当众宣布', '对', '简'), tags=('He', 'In', 'Letter', 'In', "What's said", 'The', 'Further', 'Confirmed', 'I', 'The', 'Readme', 'Temple', 'Miss', 'Put', 'Teachers and students of the whole school', 'Called', 'Get up', 'Announcing in public', 'Right', 'Jane'))),
#              ('2600',
#               Sentence(words=('·', '爱', '所受', '的', '指责', '己', '经作', '调查', '而且', '很', '高兴', '地', '声明', '对', '简', '·', '爱', '的', '诋毁', '己'), tags=('·', 'Love', "What it's affected", 'The', 'Accused', "I've got your", 'Made', 'Investigation', 'And', 'Is', 'Happy', 'Ground', 'Statement', 'Right', 'Jane', '·', 'Love', 'The', 'Slander', "I've got your"))),
#              ('2620',
#               Sentence(words=('彻底澄清', '教师', '们', '随后', '同', '我', '握手', '吻', '我', '一阵', '欢悦', '的', '低语', '迥荡', '在', '我', '同伴', '的', '队伍', '之中'), tags=('Complete clarification', 'Teachers', 'We', 'Then', 'With', 'I', 'Shake hands', 'Kiss', 'I', 'A', 'Joyous', 'The', 'Whisper', "It's very different.", 'In', 'I', 'Companion', 'The', 'Team', 'In the middle'))),
#              ('2640',
#               Sentence(words=('这样', '我', '便', '卸下', '一个', '沉重', '的', '包袱', '我', '打算', '从头', '努力', '决心', '排除万难', '披荆斩棘', '地', '前进', '我', '拼命', '苦干'), tags=('This way,', 'I', 'Poe', 'Unload', 'One', 'Heavy', 'The', 'Burden', 'I', 'Planning', 'From scratch', 'Efforts', 'Determination', 'Eliminate all difficulties', 'The Thorns', 'Ground', 'Forward', 'I', 'Desperately', 'Worked hard'))),
#              ('2660',
#               Sentence(words=('付出', '几分', '努力', '便', '获得', '几分', '成功', '我', '的', '记忆力', '虽然', '不是', '生来', '很', '强', '但', '经过', '实干', '有', '改进'), tags=('Pay', 'Few', 'Efforts', 'Poe', 'Get', 'Few', 'Success', 'I', 'The', 'Memory', 'Although', 'No', 'Born', 'Is', 'Strong', 'But', 'After', 'Do-it-it-it-', 'Yes', 'Improved'))),
#              ('2680',
#               Sentence(words=('而', '反复', '练习', '使', '我', '的', '头脑', '更为', '机敏', '几周', '之后', '我', '被', '升到', '高班', '不到', '两个', '月', '我', '被'), tags=('And', 'Repeated', 'Practice', 'Make', 'I', 'The', 'Mind', 'More', 'Smart', 'A few weeks.', 'After', 'I', 'Be', 'Up to', 'High Class', 'Less than', 'Two', 'Month', 'I', 'Be'))),
#              ('2700',
#               Sentence(words=('允许', '学习', '法文', '和', '绘画', '我', '学', '动词', 'Etre', '的', '最', '基本', '的', '两个', '时态', '；', '同一天', '我', '作', '第一幅'), tags=('Allow', 'Learn', 'French', 'And', 'Painting', 'I', 'Learn', 'Verb', 'Etre', 'The', 'Most', 'Basic', 'The', 'Two', 'Tense', ';', 'Same', 'I', 'Make', 'The first picture'))),
#              ('2720',
#               Sentence(words=('茅屋', '素描', '顺便', '说', '一句', '屋子', '墙壁', '的', '倾斜度', '可', '与', '比萨斜塔', '相媲美', '那天', '夜里', '上床', '时', '我', '忘', '在'), tags=('Hut', 'Sketch', 'By the way.', 'Said', 'One sentence.', 'House', 'Walls', 'The', 'Inclination', 'Can be', 'And', 'Pisa', 'Comparable', 'That', 'Night', 'Sleep', 'When', 'I', 'Forget', 'In'))),
#              ('2740',
# ...
#              ('19080',
#               Sentence(words=('”', '他', '说', '“', '要是', '你', '的', '家', '在', '附近', '的话', '你', '是从', '哪儿', '来', '的', '”', '“', '就是', '下面'), tags=('"', 'He', 'Said', '"', 'If', 'You', 'The', 'Home', 'In', 'Near', 'Words', 'You', 'It is from', 'Where', 'To', 'The', '"', '"', 'It is', 'Below'))),
#              ('19100',
#               Sentence(words=('那个', '地方', '只要', '有', '月光', '在', '外面', '呆', '晚', '我', '也', '一点', '都', '不', '害怕', '我', '很', '乐意', '为', '你'), tags=('That one', 'Place', 'Just', 'Yes', 'Moonlight', 'In', 'Outside', 'Stay', 'Night', 'I', 'Also', 'A little.', 'All', 'No', 'Afraid', 'I', 'Is', 'Happy', 'For', 'You'))),
#              ('19120',
#               Sentence(words=('去', '跑', '一趟', '海村', '要是', '你', '想', '的话', '说真的', '我', '正要', '上', '那儿', '去', '寄', '封信', '”', '“', '你', '说'), tags=('To', 'Run', 'One trip.', 'Haimura', 'If', 'You', 'Think', 'Words', 'Seriously.', 'I', 'Was', 'On', 'There', 'To', 'Send', 'Letter', '"', '"', 'You', 'Said'))),
#              ('19140',
#               Sentence(words=('就', '住', '在', '下面', '是不是', '指有', '城垛', '的', '那', '幢', '房子', '”', '他', '指着', '桑', '菲尔德', '府', '这时', '月亮', '给'), tags=('Just.', 'Live', 'In', 'Below', "Isn't it", 'It means there.', 'Battlements', 'The', 'That', 'Building', 'House', '"', 'He', 'Point to', 'Sang', 'Field', 'Fu', 'Then', 'Moon', 'To give'))),
#              ('19160',
#               Sentence(words=('桑', '菲尔德', '府', '洒下', '灰白色', '的', '光', '清晰', '地', '勾勒', '出', '它', '以', '树林', '为', '背景', '的', '苍白', '轮廓', '而'), tags=('Sang', 'Field', 'Fu', 'Sprinkle it.', 'Grey-white', 'The', 'Light', 'Clear', 'Ground', 'Outline', 'Out', 'It', 'To', 'Woods', 'For', 'Background', 'The', 'Pale', 'Contour', 'And'))),
#              ('19180',
#               Sentence(words=('那', '树林', '在', '西边', '的', '天际', '衬托', '之下', '似乎', '成', '一', '大片', '阴影', '“', '是', '的', '先生', '”', '“', '那'), tags=('That', 'Woods', 'In', 'West', 'The', 'Sky', 'Foil', 'Under', 'Seems', 'Yes', 'One', 'Large', 'Shadow', '"', 'Is', 'The', 'Mr', '"', '"', 'That'))),
#              ('19200',
#               Sentence(words=('是', '谁', '的', '房子', '”', '“', '罗切斯特', '先生', '的', '”', '“', '你', '知道', '罗切斯特', '先生', '吗', '”', '“', '不', '知道'), tags=('Is', 'Who', 'The', 'House', '"', '"', 'Rochester', 'Mr', 'The', '"', '"', 'You', 'Know', 'Rochester', 'Mr', 'Do you?', '"', '"', 'No', 'Know'))),
#              ('19220',
#               Sentence(words=('从来', '没有', '见', '过', '他', '”', '“', '他', '不', '常住', '在', '那里', '吗', '”', '“', '是', '的', '”', '“', '能'), tags=('Never', 'No', 'See', 'Too much', 'He', '"', '"', 'He', 'No', 'Resident', 'In', 'There', 'Do you?', '"', '"', 'Is', 'The', '"', '"', 'Yes'))),
#              ('19240',
#               Sentence(words=('告诉', '我', '他', '在', '哪里', '吗', '”', '“', '我', '不', '知道', '”', '“', '当然', '你', '不是', '府上', '的', '佣人', '你'), tags=('Tell', 'I', 'He', 'In', 'Where', 'Do you?', '"', '"', 'I', 'No', 'Know', '"', '"', 'Of course', 'You', 'No', 'On the house', 'The', 'Servant', 'You'))),
#              ('19260',
#               Sentence(words=('是', '—', '—', '”', '他', '打住', '目光', '掠过', '我', '照例', '十分', '朴实', '的', '衣服', '我', '披', '着', '黑色', '美利奴', '羊毛'), tags=('Is', '—', '—', '"', 'He', 'Stop', 'Eyes', 'Flitted', 'I', 'Routinely', 'Very', 'Simple', 'The', 'Clothes', 'I', 'The Beatles', 'On the', 'Black', 'Merino', 'Wool'))),
#              ('19280',
#               Sentence(words=('斗篷', '戴', '着', '顶', '黑', '水獭', '皮帽', '这', '两件', '东西', '远远', '没有', '太太', '的', '佣人', '衣服', '那么', '讲究', '他', '似乎'), tags=('Cloak', 'Wear', 'On the', 'Top', 'Black', 'Otter', 'Leather hat', 'This', 'Two pieces', 'Things', 'Far', 'No', 'Wife', 'The', 'Servant', 'Clothes', 'So', 'Pay attention', 'He', 'Seems'))),
#              ('19300',
#               Sentence(words=('难以', '判断', '我', '的', '身份', '我', '帮', '他', '“', '我', '是', '家庭教师', '”', '“', '啊', '家庭教师', '！', '”', '他', '重复'), tags=("Can't", 'Judge', 'I', 'The', 'Identity', 'I', 'Help', 'He', '"', 'I', 'Is', 'Tutor', '"', '"', 'Ah, yes.', 'Tutor', '!', '"', 'He', 'Repeat'))),
#              ('19320',
#               Sentence(words=('一下', '“', '见鬼', '我', '竟', '把', '这', '也', '忘', '！', '家庭教师', '！', '”', '我', '的', '服饰', '再次', '成', '他', '审视'), tags=('One moment.', '"', 'Damn it', 'I', "It's", 'Put', 'This', 'Also', 'Forget', '!', 'Tutor', '!', '"', 'I', 'The', 'Clothing', 'Again', 'Yes', 'He', 'Look at'))),
#              ('19340',
#               Sentence(words=('的', '对象', '过', '两分钟', '他', '从', '台阶', '上', '站', '起来', '刚一', '挪动', '脸上', '就', '露出', '痛苦', '的', '表情', '“', '我'), tags=('The', 'Object', 'Too much', 'Two minutes', 'He', 'From', 'Steps', 'On', 'Stand', 'Get up', 'Just one.', 'Move', 'Face', 'Just.', 'Show', 'Pain', 'The', 'Expression', '"', 'I'))),
#              ('19360',
#               Sentence(words=('不能', '托', '你', '找', '人', '帮忙', '”', '他', '说', '“', '不过', '要是', '你', '愿意', '你', '本人', '倒', '可以', '帮', '我'), tags=('No', 'To', 'You', 'Find', 'People', 'Help', '"', 'He', 'Said', '"', 'But', 'If', 'You', 'Would', 'You', 'Myself', 'Pour down', 'OK', 'Help', 'I'))),
#              ('19380',
#               Sentence(words=('一点', '忙', '”', '“', '好', '的', '先生', '”', '“', '你', '有没有', '伞', '可以', '让', '我', '当', '拐杖', '用', '”', '“'), tags=('A little.', 'Busy', '"', '"', 'Good', 'The', 'Mr', '"', '"', 'You', 'Do you have?', 'Umbrella', 'OK', 'Let', 'I', 'When', 'Crutch', 'Use', '"', '"'))),
#              ('19400',
#               Sentence(words=('没有', '”', '“', '想', '办法', '抓住', '马笼头', '把', '马', '牵到', '我', '这里', '来', '你', '不', '害怕', '吗', '”', '我', '一个'), tags=('No', '"', '"', 'Think', 'Way', 'Catch', 'Horse Cage Head', 'Put', 'Horse', 'To lead to', 'I', 'Over here', 'To', 'You', 'No', 'Afraid', 'Do you?', '"', 'I', 'One'))),
#              ('19420',
#               Sentence(words=('人', '是', '准', '不敢', '去', '碰', '一匹', '马', '的', '但', '既然', '他', '吩咐', '我', '去', '干', '我', '也', '就', '乐意'), tags=('People', 'Is', 'Quasi -', "Can't", 'To', 'Touch', 'One horse.', 'Horse', 'The', 'But', 'Since', 'He', 'Told', 'I', 'To', 'Do', 'I', 'Also', 'Just.', 'Happy'))),
#              ('19440',
#               Sentence(words=('服从', '我', '把', '皮手筒', '放在', '台阶', '上', '向', '那', '匹', '高高的', '骏马', '走去', '我', '竭力', '想', '抓住', '马笼头', '但', '这'), tags=('Obey', 'I', 'Put', 'Leather hand barrel', 'Put in', 'Steps', 'On', 'To', 'That', 'Pi', 'High', 'Horse', 'Go.', 'I', 'Tried', 'Think', 'Catch', 'Horse Cage Head', 'But', 'This'))),
#              ('19460',
#               Sentence(words=('匹', '马', '性子', '很烈', '不让', '我', '靠近', '它', '头部', '我', '试', '又', '试', '却', '都', '劳而无功', '我', '还', '很怕', '被'), tags=('Pi', 'Horse', 'Temper', "It's intense.", "Don't let it", 'I', 'Near', 'It', 'Head', 'I', 'Try', 'And again', 'Try', 'But', 'All', 'Toil withno stouss.', 'I', 'Also', "I'm scared.", 'Be'))),
#              ('19480',
#               Sentence(words=('它', '的', '前腿', '踩', '着', '这位', '赶路', '人', '等待', '并', '观察', '片刻', '最后', '终于', '笑', '起来', '“', '我', '明白', '”'), tags=('It', 'The', 'Forelegs', 'Step', 'On the', 'The', 'On the way', 'People', 'Wait', 'And', 'Observation', 'Moment', 'At last', 'Finally', 'Laugh', 'Get up', '"', 'I', 'Got it', '"'))),
#              ('19500',
#               Sentence(words=('他', '说', '“', '山', '是', '永远', '搬', '不到', '穆罕默德', '这边', '来', '的', '因此', '你', '所', '能', '做到', '的', '是', '帮助'), tags=('He', 'Said', '"', 'Mountain', 'Is', 'Forever', 'Move', 'Less than', 'Mohammed', 'This way', 'To', 'The', 'So', 'You', 'The', 'Yes', 'Do', 'The', 'Is', 'Help'))),
#              ('19520',
#               Sentence(words=('穆罕默德', '走到', '山', '那边', '去', '我', '得', '请', '你', '到', '这儿', '来', '”', '我', '走', '过去', '—', '—', '“', '对不起'), tags=('Mohammed', 'Go to', 'Mountain', 'Over there', 'To', 'I', 'Get it.', 'Please', 'You', 'To', 'Here', 'To', '"', 'I', 'Go', 'Past', '—', '—', '"', 'I am sorry'))),
#              ('19540',
#               Sentence(words=('”', '他', '继续', '说', '“', '出于', '需要', '我', '不得不', '请', '你', '帮忙', '”', '他', '把', '一只', '沉重', '的', '手', '搭'), tags=('"', 'He', 'Go on', 'Said', '"', 'For', 'Need', 'I', 'Had', 'Please', 'You', 'Help', '"', 'He', 'Put', 'One', 'Heavy', 'The', 'Hand', 'Take'))),
#              ('19560',
#               Sentence(words=('在', '我', '肩上', '吃力', '地', '倚', '着', '我', '一', '瘸', '一', '瘸', '朝', '他', '的', '马', '走', '去', '他', '一'), tags=('In', 'I', 'Shoulder', 'Labored', 'Ground', 'Leaning', 'On the', 'I', 'One', 'Lame', 'One', 'Lame', 'Towards', 'He', 'The', 'Horse', 'Go', 'To', 'He', 'One'))),
#              ('19580',
#               Sentence(words=('抓住', '笼头', '就', '立刻', '使', '马', '服服贴贴', '随后', '跳', '上', '马鞍', '因为', '搓', '一下', '扭伤', '的', '部位', '一', '用力', '便'), tags=('Catch', 'Bridle', 'Just.', 'Immediately', 'Make', 'Horse', 'Service stickers', 'Then', 'Jump', 'On', 'Saddle', 'Because', 'Rub', 'One moment.', 'Sprain', 'The', 'Parts', 'One', 'Hard', 'Poe'))),
#              ('19600',
#               Sentence(words=('露出', '痛苦', '的', '表情', '“', '好', '啦', '”', '他', '说', '放松', '紧咬', '着', '的', '下唇', '“', '把', '马鞭', '递给', '我'), tags=('Show', 'Pain', 'The', 'Expression', '"', 'Good', "That's it.", '"', 'He', 'Said', 'Just relax', 'Tight bite', 'On the', 'The', 'Lower lip', '"', 'Put', 'Whip', 'Handed it to', 'I'))),
#              ('19620',
#               Sentence(words=('就', '行', '啦', '在', '树篱', '下面', '”', '我', '找', '一下', '把', '马鞭', '找到', '“', '谢谢', '你', '现在', '你', '快', '去'), tags=('Just.', 'Yes', "That's it.", 'In', 'Hedges', 'Below', '"', 'I', 'Find', 'One moment.', 'Put', 'Whip', 'Found it', '"', 'Thank you', 'You', 'Right now', 'You', 'Fast', 'To'))),
#              ('19640',
#               Sentence(words=('海村', '寄信', '罢', '快去快回', '”', '他', '把', '带', '马刺', '的', '后', '跟', '一', '叩', '那马', '先是', '一', '惊', '后腿', '跃起'), tags=('Haimura', 'Letter', "Let's go.", 'Go back.', '"', 'He', 'Put', 'Take', 'Spurs', 'The', 'After', 'With', 'One', "I don't have", 'That horse.', 'First', 'One', 'Surprised', 'Hind legs', 'Leaping'))),
#              ('19660',
#               Sentence(words=('随后', '便', '疾驰', '而', '去', '那条', '狗', '窜', '上去', '紧追不舍', '刹那之间', '三者', '便', '无影无踪', '像', '荒野', '中', '的', '石楠', '被'), tags=('Then', 'Poe', 'Galloped', 'And', 'To', 'That one.', 'Dog', 'Sprang', 'Up', 'Keep up', 'In a split second,', 'Three', 'Poe', 'Trace', 'Like', 'Wilderness', 'In', 'The', 'Heather', 'Be'))),
#              ('19680',
#               Sentence(words=('一阵', '狂风', '卷', '走', '我', '拾起', '皮手筒', '继续', '赶路', '对', '我', '来说', '这件', '事', '已经', '发生', '并', '已', '成为', '过去'), tags=('A', 'Wind', 'Volume', 'Go', 'I', 'Pick up', 'Leather hand barrel', 'Go on', 'On the way', 'Right', 'I', 'Say,', 'This one.', 'Things', 'Have', 'Happen', 'And', 'Has', 'Become', 'Past'))),
#              ('19700',
#               Sentence(words=('在', '某种程度', '上', '说', '它', '既', '不', '重要', '也', '不', '浪漫', '又', '不', '有趣', '但', '它', '却', '标志', '着', '单调乏味'), tags=('In', 'To some extent.', 'On', 'Said', 'It', 'Both', 'No', 'Important', 'Also', 'No', 'Romantic', 'And again', 'No', 'Interesting', 'But', 'It', 'But', 'Sign', 'On the', 'Monotony'))),
#              ('19720',
#               Sentence(words=('的', '生活', '有', '一个', '小时', '的', '变化', '人家', '需要', '我', '的', '帮助', '而且', '求', '我', '而', '我', '给予帮助', '我', '很'), tags=('The', 'Life', 'Yes', 'One', 'Hours', 'The', 'Change', 'People', 'Need', 'I', 'The', 'Help', 'And', 'Please', 'I', 'And', 'I', 'Help', 'I', 'Is'))),
#              ('19740',
#               Sentence(words=('高兴', '总算', '干', '点', '什么', '这件', '事', '尽管', '微不足道', '稍纵即逝', '但', '毕竟', '是', '积极', '的', '而', '我', '对', '被动', '的'), tags=('Happy', 'Finally', 'Do', 'Point', 'What the', 'This one.', 'Things', 'Although', 'Insignificant', 'Fleeting', 'But', 'After all', 'Is', 'Positive', 'The', 'And', 'I', 'Right', 'Passive', 'The'))),
#              ('19760',
#               Sentence(words=('生活', '方式', '已', '感到', '厌倦', '这', '张', '新面孔', '犹如', '一幅', '新画', '被', '送进', '记忆', '的', '画廊', '它', '同', '已经', '张贴'), tags=('Life', 'Way', 'Has', 'Feel', 'Tired', 'This', 'Zhang', 'New faces', 'Like', 'One', 'New paintings', 'Be', 'Send in', 'Memory', 'The', 'Gallery', 'It', 'With', 'Have', 'Posted'))),
#              ('19780',
#               Sentence(words=('着', '的', '画', '全然不同', '第一', '因为', '这', '是', '位', '男性', '；', '第二', '他', '又', '黑', '又', '强壮', '又', '严厉', '我'), tags=('On the', 'The', 'Draw', "It's totally different.", 'First', 'Because', 'This', 'Is', 'Bit', 'Men', ';', 'Second', 'He', 'And again', 'Black', 'And again', 'Strong', 'And again', 'Strict', 'I'))),
#              ('19800',
#               Sentence(words=('进', '海村', '把', '信', '投入', '邮局', '的', '时候', '这', '幅画', '仍', '浮现', '在', '我', '眼前', '我', '迅步', '下山', '一路', '赶回'), tags=('Into', 'Haimura', 'Put', 'Letter', 'Input', 'Post office', 'The', 'When', 'This', 'Paintings', 'Still', 'Emerge', 'In', 'I', 'Eyes', 'I', 'Fast Step', 'Down', 'Way', 'Back'))),
#              ('19820',
#               Sentence(words=('家', '时', '也', '依然', '看到', '它', '我', '路过', '台阶', '时', '驻足', '片刻', '举目', '四顾', '并', '静听', '着', '心想', '马蹄声', '会'), tags=('Home', 'When', 'Also', 'Still', 'See', 'It', 'I', 'Passing', 'Steps', 'When', 'Stop', 'Moment', 'Eye-catching', 'Four concerns', 'And', 'Listening', 'On the', 'Thought', 'Horseshoe Sound', 'Yes'))),
#              ('19840',
#               Sentence(words=('再次', '在', '小', '路上', '回响', '一位', '身披', '斗篷', '的', '骑手', '一条', '盖', '特拉西', '似的', '纽芬兰', '狗会', '重新', '出现', '在', '眼前'), tags=('Again', 'In', 'Small', 'Way', 'Echo', 'A', 'Dressed in', 'Cloak', 'The', 'Rider', 'One', 'Cover', 'Tracy', "It's like.", 'Newfoundland', 'Dog club', 'Re -', 'Appear', 'In', 'Eyes'))),
#              ('19860',
#               Sentence(words=('但', '我', '只', '看到', '树篱', '和', '面前', '一棵', '没有', '枝梢', '的', '柳树', '静静地', '兀立', '着', '迎接', '月亮', '的', '清辉', '；'), tags=('But', 'I', 'Only', 'See', 'Hedges', 'And', 'Front', 'One', 'No', 'Branches', 'The', 'Willow', 'Quietly', 'Standing', 'On the', 'Meet', 'Moon', 'The', 'Qinghui', ';'))),
#              ('19880',
#               Sentence(words=('我', '只', '听到', '一阵', '微风', '在', '一英里', '开外', '绕', '着', '桑', '菲尔德', '府', '的', '树林', '时', '起', '时落', '；', '当'), tags=('I', 'Only', 'Hear', 'A', 'Breeze', 'In', 'One mile.', 'Away', 'Around', 'On the', 'Sang', 'Field', 'Fu', 'The', 'Woods', 'When', 'From', 'Time and time drop', ';', 'When'))),
#              ('19900',
#               Sentence(words=('我', '朝', '轻风', '拂拂', '的', '方向', '俯视', '时', '我', '的', '目光', '扫', '过府', '楼', '正面', '看到', '一个', '窗户', '里', '亮'), tags=('I', 'Towards', 'Breeze', 'Brushing', 'The', 'Direction', 'Overlooking', 'When', 'I', 'The', 'Eyes', 'Sweep', 'Over the house', 'Floor', 'Positive', 'See', 'One', 'Window', 'Inside', 'Bright'))),
#              ('19920',
#               Sentence(words=('着', '灯光', '提醒', '我', '时候', '已经', '不早', '我', '匆匆', '往前走', '去', '我', '不', '情愿', '再次', '跨进', '桑', '菲尔德', '府', '踏进'), tags=('On the', 'Light', 'Remind', 'I', 'When', 'Have', "It's not early.", 'I', 'Hurried', 'Go ahead.', 'To', 'I', 'No', "'d rather", 'Again', 'Step in', 'Sang', 'Field', 'Fu', 'Entered'))),
#              ('19940',
#               Sentence(words=('门槛', '就', '意味着', '回到', '一潭死水', '之中', '穿过', '寂静', '的', '大厅', '登上', '暗', '洞洞', '的', '楼梯', '寻找', '我', '那', '孤寂', '的'), tags=('Threshold', 'Just.', 'It means', 'Back', 'Backwater', 'In the middle', 'Through', 'Silence', 'The', 'Hall', 'Boarded', 'Dark', 'Holes', 'The', 'Stairs', 'Find', 'I', 'That', 'Lonely', 'The'))),
#              ('19960',
#               Sentence(words=('小房间', '然后', '去', '见', '心如古井', '的', '费尔法克斯', '太太', '同', '她', '只', '同', '她', '度过', '漫长', '的', '冬夜', '这', '一切', '将'), tags=('Small room', 'And then', 'To', 'See', 'Heart is like an ancient well', 'The', 'Fairfax', 'Wife', 'With', 'She', 'Only', 'With', 'She', 'Spend', 'Long', 'The', 'Winter Night', 'This', 'All', 'Will'))),
#              ('19980',
#               Sentence(words=('彻底', '浇灭', '我', '这回', '步行', '所', '激起', '的', '兴奋', '重', '又', '用', '一成不变', '的', '静止', '生活', '的', '无形', '镣铐', '锁住'), tags=('Completely', 'Watering out', 'I', 'This time.', 'Walk', 'The', 'Stirred', 'The', 'Excited', 'Heavy', 'And again', 'Use', 'Same', 'The', 'Static', 'Life', 'The', 'Intangible', 'Chains', 'Lock up.'))),
#              ...])

# %% [markdown]
# The class `Dataset` below incorporates our function above, reads in the Brown corpus and creates a collection of `keys`, a set of (unique) words, a sequence of words and a mirror sequence of tags as tuples, with `N` being the number of words in the Brown corpus.
#
# Then it splits all this nice data into a training and test decomposition by using the `Subset` class defined further below, which mirrors the `Dataset` class.

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %% [markdown]
# Let's read in the Brown corpus *again*, leveraging our classes above now, which order the corpus into efficiently navigable structures:

# %%
data = Dataset(tags_file, txt_file, train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 1040 sentences in the corpus.
# There are 832 sentences in the training set.
# There are 208 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 20798 samples of 5223 unique words in the corpus.
# There are 16638 samples of 4521 unique words in the training set.
# There are 4160 samples of 1776 unique words in the testing set.
# There are 702 words in the test set that are missing in the training set.

# %% [markdown]
# Let's look at an example POS tagging:

# %%
key = '10'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: 10
# words:
# 	('半个', '小时', '不到', '钟', '就', '敲响', '五点', '散课', '大家', '都', '进', '饭厅', '去', '吃', '茶点', '我', '这', '才', '大', '着', '胆')
# tags:
# 	('Half', 'Hours', 'Less than', 'Minutes', 'Just.', 'Ring', 'Five', 'Breakout class', 'Everyone', 'All', 'Into', 'Dining room', 'To', 'Eat', 'Refreshment', 'I', 'This', "It's just", 'Big', 'On the', 'Bile')

# %% [markdown]
# This is how easy it is, now, to access words and associated tags, using the vocabulary of Machine Learning: `X` is the independent variable, and `Y` the dependent variable!

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('半个', '小时', '不到', '钟', '就', '敲响', '五点', '散课', '大家', '都', '进', '饭厅', '去', '吃', '茶点', '我', '这', '才', '大', '着', '胆')
#
# Labels 1: ('Half', 'Hours', 'Less than', 'Minutes', 'Just.', 'Ring', 'Five', 'Breakout class', 'Everyone', 'All', 'Into', 'Dining room', 'To', 'Eat', 'Refreshment', 'I', 'This', "It's just", 'Big', 'On the', 'Bile')
#
# Sentence 2: ('走', '下', '凳子', '这时', '暮色', '正浓', '我', '躲进', '一个', '角落', '在', '地板', '上', '坐下', '来', '一直', '支撑', '着', '我', '的')
#
# Labels 2: ('Go', 'Next', 'Stool', 'Then', 'Twilight', 'Positive', 'I', 'Hide in.', 'One', 'Corner', 'In', 'Floor', 'On', 'Sit down', 'To', 'Always', 'Support', 'On the', 'I', 'The')

# %% [markdown]
# Use `Dataset.stream()` to enumerate (word, tag) samples for the entire corpus. Let's enumerate the first 4:

# %%
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 10: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('半个', 'Half')
# 	 ('小时', 'Hours')
# 	 ('不到', 'Less than')
# 	 ('钟', 'Minutes')
# 	 ('就', 'Just.')
# 	 ('敲响', 'Ring')
# 	 ('五点', 'Five')
# 	 ('散课', 'Breakout class')
# 	 ('大家', 'Everyone')
# 	 ('都', 'All')
# 	 ('进', 'Into')
# 	 ('饭厅', 'Dining room')

# %% [markdown]
# These are all words and tags in our **training set**. Let's uncover the first 4:

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:10], tags[0:10]
# Out:
# (['进步', '此外', '我', '也', '深受', '同学', '们', '的', '欢迎', '同'],
#  ['Progress',
#   'In addition,',
#   'I',
#   'Also',
#   'By',
#   'Classmates',
#   'We',
#   'The',
#   'Welcome',
#   'With'])

# %% [markdown]
# # POS Tagger using BOW Model
#
# Let's create a dictionary of word + tag pairs where the values are just counts. Note that some words may be associated with different POS tags, in which case they will produce *distinct* pairs:

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)
word_counts
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'进步': defaultdict(int, {'Progress': 4}),
#              '此外': defaultdict(int, {'In addition,': 4}),
#              '我': defaultdict(int, {'I': 823}),
#              '也': defaultdict(int, {'Also': 86}),
#              '深受': defaultdict(int, {'By': 1}),
#              '同学': defaultdict(int, {'Classmates': 1}),
#              '们': defaultdict(int, {'We': 17}),
#              '的': defaultdict(int, {'The': 1124}),
#              '欢迎': defaultdict(int, {'Welcome': 1}),
#              '同': defaultdict(int, {'With': 45}),
#              '年龄': defaultdict(int, {'Age': 3}),
#              '相仿': defaultdict(int, {'Similar': 1}),
#              '人': defaultdict(int, {'People': 88}),
#              '对': defaultdict(int, {'Right': 42}),
#              '平等': defaultdict(int, {'Equal': 3}),
#              '相待': defaultdict(int, {'Wait inge': 2}),
#              '屈尊': defaultdict(int, {'Condescension': 1}),
#              '就': defaultdict(int, {'Just.': 47}),
#              '驾': defaultdict(int, {'Driving': 1}),
#              '结果': defaultdict(int, {'Results': 4}),
#              '这样': defaultdict(int, {'This way,': 19}),
#              '倒': defaultdict(int, {'Pour down': 12}),
#              '更好': defaultdict(int, {'Better': 4}),
#              '处境': defaultdict(int, {'Situation': 3}),
#              '更': defaultdict(int, {'More': 16}),
#              '自由': defaultdict(int, {'Free': 5}),
#              '还': defaultdict(int, {'Also': 48}),
#              '在': defaultdict(int, {'In': 230}),
#              '沉思': defaultdict(int, {'Meditation': 3}),
#              '着': defaultdict(int, {'On the': 145}),
#              '这个': defaultdict(int, {'This one': 24}),
#              '跟着': defaultdict(int, {'Follow': 4}),
#              '费尔法克斯': defaultdict(int, {'Fairfax': 32}),
#              '太太': defaultdict(int, {'Wife': 47}),
#              '她': defaultdict(int, {'She': 294}),
#              '把': defaultdict(int, {'Put': 92}),
#              '刚才': defaultdict(int, {'Just now': 4}),
#              '新闻': defaultdict(int, {'News': 1}),
#              '重复': defaultdict(int, {'Repeat': 3}),
#              '一遍': defaultdict(int, {'Once again.': 3}),
#              '说': defaultdict(int, {'Said': 79}),
#              '外科医生': defaultdict(int, {'Surgeon': 2}),
#              '卡特': defaultdict(int, {'Carter': 1}),
#              '已经': defaultdict(int, {'Have': 27}),
#              '来': defaultdict(int, {'To': 55}),
#              '这会儿': defaultdict(int, {'Now': 4}),
#              '罗切斯特': defaultdict(int, {'Rochester': 19}),
#              '先生': defaultdict(int, {'Mr': 33}),
#              '睡': defaultdict(int, {'Sleep': 6}),
#              '得': defaultdict(int, {'Get it.': 60}),
#              '好好': defaultdict(int, {'Good': 2}),
#              '’': defaultdict(int, {"'": 5}),
#              '”': defaultdict(int, {'"': 239}),
#              '喃喃地': defaultdict(int, {'Muttering': 2}),
#              '“': defaultdict(int, {'"': 248}),
#              '你': defaultdict(int, {'You': 174}),
#              '现在': defaultdict(int, {'Right now': 40}),
#              '上': defaultdict(int, {'On': 86}),
#              '哪儿': defaultdict(int, {'Where': 6}),
#              '去': defaultdict(int, {'To': 68}),
#              '呀': defaultdict(int, {'Oh, yes.': 18}),
#              '因为': defaultdict(int, {'Because': 38}),
#              '—': defaultdict(int, {'—': 53}),
#              '靠近': defaultdict(int, {'Near': 6}),
#              '大门': defaultdict(int, {'Door': 3}),
#              '那个': defaultdict(int, {'That one': 11}),
#              '教堂': defaultdict(int, {'Church': 8}),
#              '是': defaultdict(int, {'Is': 186}),
#              '他': defaultdict(int, {'He': 125}),
#              '管': defaultdict(int, {'Tube': 1}),
#              '这位': defaultdict(int, {'The': 13}),
#              '母亲': defaultdict(int, {'Mother': 3}),
#              '家': defaultdict(int, {'Home': 8}),
#              '那他': defaultdict(int, {'Then he': 2}),
#              '不是': defaultdict(int, {'No': 27}),
#              '自己': defaultdict(int, {'Myself': 52}),
#              '主动': defaultdict(int, {'Active': 1}),
#              '要': defaultdict(int, {'To': 38}),
#              '抚养': defaultdict(int, {'Raise': 3}),
#              '小姐': defaultdict(int, {'Miss': 56}),
#              '感到': defaultdict(int, {'Feel': 15}),
#              '很': defaultdict(int, {'Is': 58}),
#              '遗憾': defaultdict(int, {'Regret': 2}),
#              '不得不': defaultdict(int, {'Had': 4}),
#              '矮篱': defaultdict(int, {'Dwarf Hedges': 1}),
#              '草地': defaultdict(int, {'Grass': 4}),
#              '和': defaultdict(int, {'And': 126}),
#              '庭园': defaultdict(int, {'Garden': 3}),
#              '分开': defaultdict(int, {'Separate': 1}),
#              '上长': defaultdict(int, {'Upper long': 1}),
#              '一排排': defaultdict(int, {'A row of': 3}),
#              '巨大': defaultdict(int, {'Huge': 3}),
#              '老': defaultdict(int, {'Old': 2}),
#              '荆棘': defaultdict(int, {'Thorns': 3}),
#              '树丛': defaultdict(int, {'Trees': 4}),
#              '强劲': defaultdict(int, {'Strong': 1}),
#              '多节': defaultdict(int, {'Multi-section': 1}),
#              '大': defaultdict(int, {'Big': 31}),
#              '如': defaultdict(int, {'Such as': 7}),
#              '橡树': defaultdict(int, {'Oak': 6}),
#              '疼痛': defaultdict(int, {'Pain': 1}),
#              '蹒跚': defaultdict(int, {'Lurched': 1}),
#              '地': defaultdict(int, {'Ground': 59}),
#              '踱': defaultdict(int, {"I'd be": 1}),
#              '向': defaultdict(int, {'To': 10}),
#              '起身': defaultdict(int, {'Up': 3}),
#              '离开': defaultdict(int, {'Leave': 9}),
#              '台阶': defaultdict(int, {'Steps': 5}),
#              '一': defaultdict(int, {'One': 37}),
#              '屁股': defaultdict(int, {'Ass': 1}),
#              '坐下': defaultdict(int, {'Sit down': 8}),
#              '心里': defaultdict(int, {'Heart': 7}),
#              '发现': defaultdict(int, {'Found': 11}),
#              '一位': defaultdict(int, {'A': 19}),
#              '所': defaultdict(int, {'The': 27}),
#              '企盼': defaultdict(int, {'Hope': 1}),
#              '融洽': defaultdict(int, {'Harmonious': 2}),
#              '伙伴': defaultdict(int, {'Partner': 3}),
#              '不过': defaultdict(int, {'But': 32}),
#              '今晚': defaultdict(int, {'Tonight': 6}),
#              '可': defaultdict(int, {'Can be': 4}),
#              '不想': defaultdict(int, {"Don't want to": 1}),
#              '留': defaultdict(int, {'Stay': 3}),
#              '确实': defaultdict(int, {'Do': 9}),
#              '去年': defaultdict(int, {'Last year': 1}),
#              '冬天': defaultdict(int, {'Winter': 3}),
#              '如果': defaultdict(int, {'If': 4}),
#              '记得': defaultdict(int, {'Remember': 5}),
#              '的话': defaultdict(int, {'Words': 11}),
#              '那': defaultdict(int, {'That': 46}),
#              '个': defaultdict(int, {'A': 27}),
#              '很冷': defaultdict(int, {"It's cold.": 1}),
#              '下雪': defaultdict(int, {'Snow': 1}),
#              '就是': defaultdict(int, {'It is': 20}),
#              '刮风下雨': defaultdict(int, {"It's windy and rainy.": 1}),
#              '从': defaultdict(int, {'From': 47}),
#              '十一月': defaultdict(int, {'November': 2}),
#              '呢': defaultdict(int, {'What about?': 22}),
#              '可是': defaultdict(int, {'But': 7}),
#              '跟': defaultdict(int, {'With': 22}),
#              '千千万万': defaultdict(int, {'Thousands': 2}),
#              '有': defaultdict(int, {'Yes': 70}),
#              '什么': defaultdict(int, {'What the': 20}),
#              '关系': defaultdict(int, {'Relationship': 2}),
#              '认识': defaultdict(int, {'Know': 2}),
#              '八十个': defaultdict(int, {'Eighty.': 2}),
#              '马': defaultdict(int, {'Horse': 15}),
#              '接跟': defaultdict(int, {'Pick up': 1}),
#              '而': defaultdict(int, {'And': 66}),
#              '匹': defaultdict(int, {'Pi': 6}),
#              '高头大马': defaultdict(int, {'Tall horse': 1}),
#              '马背上': defaultdict(int, {'On horseback.': 1}),
#              '坐': defaultdict(int, {'Sit': 8}),
#              '骑手': defaultdict(int, {'Rider': 3}),
#              '男人': defaultdict(int, {'Man': 5}),
#              '本身': defaultdict(int, {'Itself': 2}),
#              '立刻': defaultdict(int, {'Immediately': 10}),
#              '驱散': defaultdict(int, {'Disperse': 2}),
#              '消瘦': defaultdict(int, {'Thin': 1}),
#              '手': defaultdict(int, {'Hand': 5}),
#              '手腕': defaultdict(int, {'Wrist': 1}),
#              '都': defaultdict(int, {'All': 55}),
#              '冰冷': defaultdict(int, {'Cold': 3}),
#              '只有': defaultdict(int, {'Only': 6}),
#              '微笑': defaultdict(int, {'Smile': 4}),
#              '依旧': defaultdict(int, {'Still': 3}),
#              '为什么': defaultdict(int, {'Why': 4}),
#              '到': defaultdict(int, {'To': 62}),
#              '这儿': defaultdict(int, {'Here': 8}),
#              '鼻音': defaultdict(int, {'Twang': 1}),
#              '曲': defaultdict(int, {'Song': 2}),
#              '除': defaultdict(int, {'Except': 10}),
#              '认为': defaultdict(int, {'Think': 11}),
#              '讨厌': defaultdict(int, {'Hate': 4}),
#              '没有': defaultdict(int, {'No': 90}),
#              '别的': defaultdict(int, {'Other': 4}),
#              '看法': defaultdict(int, {'View': 1}),
#              '满意': defaultdict(int, {'Satisfaction': 7}),
#              '迎来': defaultdict(int, {'Usher': 1}),
#              '它': defaultdict(int, {'It': 57}),
#              '最初': defaultdict(int, {'First': 1}),
#              '深沉': defaultdict(int, {'Deep': 2}),
#              '曲调': defaultdict(int, {'Tune': 2}),
#              '天真烂漫': defaultdict(int, {'Innocent': 1}),
#              '情调': defaultdict(int, {'Mood': 1}),
#              '唱': defaultdict(int, {'Sing': 2}),
#              '完': defaultdict(int, {'Finish': 4}),
#              '以后': defaultdict(int, {'later': 12}),
#              '膝头': defaultdict(int, {'Knees': 4}),
#              '跳': defaultdict(int, {'Jump': 4}),
#              '下': defaultdict(int, {'Next': 21}),
#              '给': defaultdict(int, {'To give': 19}),
#              '怀疑': defaultdict(int, {'Doubt': 1}),
#              '包含': defaultdict(int, {'Contains': 1}),
#              '要死': defaultdict(int, {'Die': 1}),
#              '意思': defaultdict(int, {'Mean': 3}),
#              '但': defaultdict(int, {'But': 71}),
#              '此刻': defaultdict(int, {'Now': 8}),
#              '立即': defaultdict(int, {'Immediately': 2}),
#              '明白': defaultdict(int, {'Got it': 4}),
#              '理解': defaultdict(int, {'Understand': 2}),
#              '起来': defaultdict(int, {'Get up': 27}),
#              '这': defaultdict(int, {'This': 90}),
#              '那里': defaultdict(int, {'There': 14}),
#              '等': defaultdict(int, {'Wait, wait, wait': 16}),
#              '公共': defaultdict(int, {'Public': 1}),
#              '马车': defaultdict(int, {'Carriage': 10}),
#              '刷好': defaultdict(int, {'Brush it.': 1}),
#              '黑': defaultdict(int, {'Black': 7}),
#              '旅行': defaultdict(int, {'Travel': 1}),
#              '装备': defaultdict(int, {'Equipment': 1}),
#              '好': defaultdict(int, {'Good': 29}),
#              '帽子': defaultdict(int, {'Hat': 2}),
#              '手套': defaultdict(int, {'Gloves': 1}),
#              '皮手筒': defaultdict(int, {'Leather hand barrel': 5}),
#              '所有': defaultdict(int, {'All': 2}),
#              '服从': defaultdict(int, {'Obey': 1}),
#              '放在': defaultdict(int, {'Put in': 5}),
#              '高高的': defaultdict(int, {'High': 3}),
#              '骏马': defaultdict(int, {'Horse': 1}),
#              '走去': defaultdict(int, {'Go.': 2}),
#              '竭力': defaultdict(int, {'Tried': 2}),
#              '想': defaultdict(int, {'Think': 35}),
#              '抓住': defaultdict(int, {'Catch': 3}),
#              '马笼头': defaultdict(int, {'Horse Cage Head': 1}),
#              '敢肯定': defaultdict(int, {'Be sure.': 2}),
#              '很多': defaultdict(int, {'A lot': 13}),
#              '那么': defaultdict(int, {'So': 30}),
#              '同情': defaultdict(int, {'Sympathy': 3}),
#              '布罗克': defaultdict(int, {'Brock': 10}),
#              '赫斯特': defaultdict(int, {'Hurst': 9}),
#              '说话': defaultdict(int, {'Speak': 9}),
#              '她们': defaultdict(int, {'They': 16}),
#              '怎么': defaultdict(int, {'How': 4}),
#              '可能': defaultdict(int, {'possible': 11}),
#              '妈妈': defaultdict(int, {'Mom': 6}),
#              '圣母': defaultdict(int, {'Virgin': 2}),
#              '玛丽亚': defaultdict(int, {'Maria': 1}),
#              '那儿': defaultdict(int, {'There': 18}),
#              '去后': defaultdict(int, {'After you go.': 1}),
#              '谁': defaultdict(int, {'Who': 10}),
#              '一块儿': defaultdict(int, {'A piece of': 1}),
#              '住': defaultdict(int, {'Live': 9}),
#              '弗雷德里克': defaultdict(int, {'Frederick': 2}),
#              '像': defaultdict(int, {'Like': 30}),
#              '墓穴': defaultdict(int, {'Grave': 3}),
#              '指指': defaultdict(int, {'Refers to': 1}),
#              '窗子': defaultdict(int, {'Window': 6}),
#              '相对': defaultdict(int, {'Relative': 1}),
#              '应': defaultdict(int, {'Should': 1}),
#              '一扇': defaultdict(int, {'One': 5}),
#              '又': defaultdict(int, {'And again': 55}),
#              '宽': defaultdict(int, {'Wide': 1}),
#              '拱门': defaultdict(int, {'Arches': 2}),
#              '一样': defaultdict(int, {'The same': 29}),
#              '海伦': defaultdict(int, {'Helen': 45}),
#              '要是': defaultdict(int, {'If': 19}),
#              '说错': defaultdict(int, {"That's wrong.": 1}),
#              '足以': defaultdict(int, {'Enough': 1}),
#              '使': defaultdict(int, {'Make': 41}),
#              '有幸': defaultdict(int, {'Fortunate enough': 2}),
#              '听': defaultdict(int, {'Listen': 13}),
#              '谈话': defaultdict(int, {'Talk': 3}),
#              '品味': defaultdict(int, {'Taste': 2}),
#              '高级': defaultdict(int, {'Senior': 1}),
#              '脚步': defaultdict(int, {'Footsteps': 1}),
#              '欣赏': defaultdict(int, {'Appreciate': 4}),
#              '此时': defaultdict(int, {'At this point,': 1}),
#              '此景': defaultdict(int, {'This scene': 1}),
#              '蕴蓄': defaultdict(int, {'Contains': 1}),
#              '种种': defaultdict(int, {'Various': 5}),
#              '欢乐': defaultdict(int, {'Joy': 1}),
#              '时候': defaultdict(int, {'When': 14}),
#              '三点': defaultdict(int, {'Three': 1}),
#              '经过': defaultdict(int, {'After': 6}),
#              '钟楼': defaultdict(int, {'Clock tower': 2}),
#              '时': defaultdict(int, {'When': 45}),
#              '势': defaultdict(int, {'Potential': 1}),
#              '自然': defaultdict(int, {'Natural': 4}),
#              '不能': defaultdict(int, {'No': 9}),
#              '忽视': defaultdict(int, {'Ignore': 1}),
#              '所以': defaultdict(int, {'So': 9}),
#              '仍': defaultdict(int, {'Still': 4}),
#              '担任': defaultdict(int, {'As': 2}),
#              '司库': defaultdict(int, {'Treasurer': 1}),
#              '职': defaultdict(int, {'Vocational': 1}),
#              '履行': defaultdict(int, {'Fulfill': 1}),
#              '职务': defaultdict(int, {'Duties': 2}),
#              '得到': defaultdict(int, {'Get': 11}),
#              '更为': defaultdict(int, {'More': 5}),
#              '慷慨': defaultdict(int, {'Generous': 2}),
#              '富有': defaultdict(int, {'Rich': 1}),
#              '睡着': defaultdict(int, {'Fell asleep': 5}),
#              '一支': defaultdict(int, {'One': 3}),
#              '灯芯': defaultdict(int, {'Wick': 1}),
#              '未': defaultdict(int, {'Not': 4}),
#              '剪': defaultdict(int, {'Cut': 1}),
#              '蜡烛': defaultdict(int, {'Candle': 8}),
#              '幽幽地': defaultdict(int, {'The claustrophobic': 1}),
#              '桌子': defaultdict(int, {'Table': 1}),
#              '上燃': defaultdict(int, {'On-fire': 1}),
#              '看到': defaultdict(int, {'See': 20}),
#              '坦普尔': defaultdict(int, {'Temple': 25}),
#              '后来': defaultdict(int, {'Later': 6}),
#              '知道': defaultdict(int, {'Know': 32}),
#              '赶路': defaultdict(int, {'On the way': 4}),
#              '没': defaultdict(int, {"Didn't": 3}),
#              '走': defaultdict(int, {'Go': 30}),
#              '几步': defaultdict(int, {'A few steps.': 1}),
#              '便': defaultdict(int, {'Poe': 38}),
#              '回过头来': defaultdict(int, {'Looking back.': 1}),
#              '一阵': defaultdict(int, {'A': 9}),
#              '东西': defaultdict(int, {'Things': 21}),
#              '滑落': defaultdict(int, {'Slipped': 1}),
#              '声音': defaultdict(int, {'Voice': 8}),
#              '一声': defaultdict(int, {'One out.': 3}),
#              '怎么办': defaultdict(int, {'What to do': 1}),
#              '活见鬼': defaultdict(int, {'Live hell.': 1}),
#              '图案': defaultdict(int, {'Pattern': 1}),
#              '墙纸': defaultdict(int, {'Wallpaper': 2}),
#              '地毯': defaultdict(int, {'Carpet': 6}),
#              '家具': defaultdict(int, {'Furniture': 4}),
#              '壁炉': defaultdict(int, {'Fireplace': 4}),
#              '摆设': defaultdict(int, {'Decoration': 1}),
#              '图片': defaultdict(int, {'Image': 1}),
#              '其中': defaultdict(int, {'Where': 2}),
#              '一幅': defaultdict(int, {'One': 9}),
#              '喜欢': defaultdict(int, {'Like': 21}),
#              '小家伙': defaultdict(int, {'Little': 1}),
#              '正像': defaultdict(int, {'As': 2}),
#              '好心': defaultdict(int, {'Kind': 3}),
#              '怀着': defaultdict(int, {'With': 1}),
#              '感激': defaultdict(int, {'Grateful': 1}),
#              '之': defaultdict(int, {'The': 9}),
#              '情': defaultdict(int, {'Love': 1}),
#              '同时': defaultdict(int, {'At the same time,': 4}),
#              '达': defaultdict(int, {'Da': 1}),
#              '不到': defaultdict(int, {'Less than': 7}),
#              '难道': defaultdict(int, {"Don't": 2}),
#              '这事': defaultdict(int, {'This thing.': 2}),
#              '不': defaultdict(int, {'No': 75}),
#              '可行': defaultdict(int, {'Feasible': 1}),
#              '达到': defaultdict(int, {'Reach': 1}),
#              '目的': defaultdict(int, {'Objective': 3}),
#              '并非': defaultdict(int, {'Not': 1}),
#              '难事': defaultdict(int, {'Difficult': 1}),
#              '只要': defaultdict(int, {'Just': 6}),
#              '肯': defaultdict(int, {'Ken': 2}),
#              '动脑筋': defaultdict(int, {'Brainstorm': 1}),
#              '红房子': defaultdict(int, {'Red House': 1}),
#              '事件': defaultdict(int, {'Event': 2}),
#              '详细': defaultdict(int, {'With': 1}),
#              '诉说': defaultdict(int, {'Tell': 2}),
#              '情绪': defaultdict(int, {'Emotions': 3}),
#              '有点': defaultdict(int, {'A little bit.': 2}),
#              '失态': defaultdict(int, {'Loss': 1}),
#              '当': defaultdict(int, {'When': 16}),
#              '里德': defaultdict(int, {'Reed': 9}),
#              '断然拒绝': defaultdict(int, {'Categorically refused.': 1}),
#              '发疯': defaultdict(int, {'Crazy': 1}),
#              '似的': defaultdict(int, {"It's like.": 5}),
#              '科特': defaultdict(int, {'Kurt': 1}),
#              '工业': defaultdict(int, {'Industrial': 1}),
#              '城市': defaultdict(int, {'City': 3}),
#              '坐落': defaultdict(int, {'Located': 3}),
#              '埃': defaultdict(int, {'E': 1}),
#              '×': defaultdict(int, {'s': 11}),
#              '河岸': defaultdict(int, {'River': 1}),
#              '无疑': defaultdict(int, {'Undoubtedly': 2}),
#              '够': defaultdict(int, {'Enough': 7}),
#              '热闹': defaultdict(int, {'Lively': 2}),
#              '岂': defaultdict(int, {"Don't you": 1}),
#              '踏上去': defaultdict(int, {'Get on the road': 1}),
#              '洛顿': defaultdict(int, {'Lotton': 6}),
#              '路途': defaultdict(int, {'Road': 1}),
#              '顺便': defaultdict(int, {'By the way.': 2}),
#              '提': defaultdict(int, {'Ti': 1}),
#              '一句': defaultdict(int, {'One sentence.': 4}),
#              '小路': defaultdict(int, {'Path': 4}),
#              '风景如画': defaultdict(int, {'Picturesque': 1}),
#              '沿着': defaultdict(int, {'Along': 3}),
#              '小溪': defaultdict(int, {'Stream': 2}),
#              '向前': defaultdict(int, {'Forward': 2}),
#              '延伸': defaultdict(int, {'Extended': 1}),
#              '穿过': defaultdict(int, {'Through': 8}),
#              '弯弯曲曲': defaultdict(int, {'Winding': 1}),
#              '秀色': defaultdict(int, {'Show': 1}),
#              '诱人': defaultdict(int, {'Attractive': 2}),
#              '山谷': defaultdict(int, {'Valley': 2}),
#              '游戏': defaultdict(int, {'Game': 2}),
#              '时刻': defaultdict(int, {'Moment': 3}),
#              '有时': defaultdict(int, {'Sometimes': 6}),
#              '逢': defaultdict(int, {'Every': 1}),
#              '好日子': defaultdict(int, {'Day': 1}),
#              '天气': defaultdict(int, {'Weather': 2}),
#              '甚至': defaultdict(int, {'Even': 2}),
#              '变得': defaultdict(int, {'Become': 4}),
#              '温暖': defaultdict(int, {'Warm': 4}),
#              '舒适': defaultdict(int, {'Comfortable': 6}),
#              '枯黄': defaultdict(int, {'Yellow': 1}),
#              '苗圃': defaultdict(int, {'Nursery': 1}),
#              '长': defaultdict(int, {'Long': 7}),
#              '出': defaultdict(int, {'Out': 10}),
#              '一片': defaultdict(int, {'A': 6}),
#              '新绿': defaultdict(int, {'Green': 1}),
#              '一天': defaultdict(int, {'One day': 7}),
#              '精疲力尽': defaultdict(int, {'Exhausted': 2}),
#              '谈到': defaultdict(int, {'Talked about': 3}),
#              '伤心': defaultdict(int, {'Sad': 2}),
#              '话题': defaultdict(int, {'Topic': 1}),
#              '比': defaultdict(int, {'Than': 16}),
#              '平时': defaultdict(int, {'Usually': 3}),
#              '克制': defaultdict(int, {'Restraint': 1}),
#              '记住': defaultdict(int, {'Remember': 1}),
#              '告诫': defaultdict(int, {'Warned': 1}),
#              '绳子': defaultdict(int, {'Rope': 1}),
#              '捆好': defaultdict(int, {'Tie it up.': 1}),
#              '贴上标签': defaultdict(int, {'Put a label on it.': 1}),
#              '半小时': defaultdict(int, {'Half an hour.': 2}),
#              '之后': defaultdict(int, {'After': 8}),
#              '脚夫': defaultdict(int, {'Porter': 3}),
#              '取走': defaultdict(int, {'Take it.': 1}),
#              '送往': defaultdict(int, {'Send to': 2}),
#              '则': defaultdict(int, {'Then': 2}),
#              '第二天': defaultdict(int, {'Day 2': 6}),
#              '一早': defaultdict(int, {'Morning': 1}),
#              '赶到': defaultdict(int, {'To': 1}),
#              '白天': defaultdict(int, {'Day': 4}),
#              '异样': defaultdict(int, {'Strange': 2}),
#              '抖动': defaultdict(int, {'Jitter': 2}),
#              '弄醒': defaultdict(int, {'Wake up.': 2}),
#              '抬起头来': defaultdict(int, {'Look up.': 2}),
#              '发现自己': defaultdict(int, {'Find yourself': 2}),
#              '正': defaultdict(int, {'Is': 14}),
#              '躺': defaultdict(int, {'Lying': 11}),
#              '别人': defaultdict(int, {'Others': 10}),
#              '怀抱': defaultdict(int, {'Arms': 2}),
#              '里': defaultdict(int, {'Inside': 48}),
#              '彻底': defaultdict(int, {'Completely': 3}),
#              '浇灭': defaultdict(int, {'Watering out': 1}),
#              '这回': defaultdict(int, {'This time.': 1}),
#              '步行': defaultdict(int, {'Walk': 1}),
#              '激起': defaultdict(int, {'Stirred': 1}),
#              '兴奋': defaultdict(int, {'Excited': 4}),
#              '重': defaultdict(int, {'Heavy': 2}),
#              '用': defaultdict(int, {'Use': 18}),
#              '一成不变': defaultdict(int, {'Same': 1}),
#              '静止': defaultdict(int, {'Static': 1}),
#              '生活': defaultdict(int, {'Life': 19}),
#              '无形': defaultdict(int, {'Intangible': 2}),
#              '镣铐': defaultdict(int, {'Chains': 1}),
#              '锁住': defaultdict(int, {'Lock up.': 1}),
#              '吸引': defaultdict(int, {'Attract': 2}),
#              '争辩': defaultdict(int, {'Argue': 1}),
#              '或许': defaultdict(int, {'Maybe': 1}),
#              '桑': defaultdict(int, {'Sang': 19}),
#              '菲尔德': defaultdict(int, {'Field': 20}),
#              '离镇': defaultdict(int, {'Away from town': 1}),
#              '远': defaultdict(int, {'Far': 7}),
#              '这时': defaultdict(int, {'Then': 18}),
#              '残烛': defaultdict(int, {'Residual Candles': 1}),
#              '落入': defaultdict(int, {'Fall': 2}),
#              '语言': defaultdict(int, {'Language': 2}),
#              '几句': defaultdict(int, {'A few words.': 2}),
#              '起初': defaultdict(int, {'Initially': 3}),
#              '回答': defaultdict(int, {'Reply': 14}),
#              '简短': defaultdict(int, {'Short': 1}),
#              '我们': defaultdict(int, {'We': 61}),
#              '桌旁': defaultdict(int, {'At the table': 1}),
#              '坐定': defaultdict(int, {'Sit down.': 2}),
#              '淡褐色': defaultdict(int, {'Hazel': 1}),
#              '上面': defaultdict(int, {'Above': 3}),
#              '摆': defaultdict(int, {'Swing': 4}),
#              '基础教育': defaultdict(int, {'Elementary education': 1}),
#              '需要': defaultdict(int, {'Need': 11}),
#              '各类': defaultdict(int, {'Various': 1}),
#              '书籍': defaultdict(int, {'Books': 3}),
#              '几部': defaultdict(int, {'Several': 1}),
#              '轻松': defaultdict(int, {'Easy': 1}),
#              '文学作品': defaultdict(int, {'Literary works': 1}),
#              '诗歌': defaultdict(int, {'Poetry': 2}),
#              '传记': defaultdict(int, {'Biography': 1}),
#              '游记': defaultdict(int, {'Travels': 1}),
#              '一些': defaultdict(int, {'A few': 6}),
#              '传奇': defaultdict(int, {'Legend': 1}),
#              '柜子': defaultdict(int, {'Cabinet': 1}),
#              '奇怪': defaultdict(int, {'Strange': 5}),
#              '雕刻': defaultdict(int, {'Carving': 2}),
#              '棕榈': defaultdict(int, {'Palm': 1}),
#              '树枝': defaultdict(int, {'Branches': 1}),
#              '小天使': defaultdict(int, {'Little Angel': 1}),
#              '头部': defaultdict(int, {'Head': 2}),
#              '看上去': defaultdict(int, {'Look': 9}),
#              '各种': defaultdict(int, {'Various': 4}),
#              '希伯莱': defaultdict(int, {'Hibernian': 1}),
#              '约柜': defaultdict(int, {'Interview cabinet': 1}),
#              '；': defaultdict(int, {';': 24}),
#              '映照': defaultdict(int, {'Mapping': 4}),
#              '叫': defaultdict(int, {'Call': 16}),
#              '派': defaultdict(int, {'Sent': 2}),
#              '洛特': defaultdict(int, {'Lott': 1}),
#              '！': defaultdict(int, {'!': 40}),
#              '后': defaultdict(int, {'After': 16}),
#              '乖乖': defaultdict(int, {'Be good.': 1}),
#              '吱声': defaultdict(int, {'Squeaking': 1}),
#              '咽下': defaultdict(int, {'Swallow it.': 1}),
#              '眼泪': defaultdict(int, {'Tears': 2}),
#              '咳嗽': defaultdict(int, {'Cough': 2}),
#              '吵醒': defaultdict(int, {'Wake': 1}),
#              '护士': defaultdict(int, {'Nurse': 7}),
#              '咳完': defaultdict(int, {"I've finished coughing up": 1}),
#              '几分钟': defaultdict(int, {'A few minutes.': 5}),
#              '随后': defaultdict(int, {'Then': 26}),
#              '亮': defaultdict(int, {'Bright': 3}),
#              '阳光': defaultdict(int, {'Sunlight': 7}),
#              '蓝色': defaultdict(int, {'Blue': 4}),
#              '鲜艳': defaultdict(int, {'Bright': 1}),
#              '印花布': defaultdict(int, {'Calico': 1}),
#              '窗帘': defaultdict(int, {'Curtains': 4}),
#              '缝隙': defaultdict(int, {'Gap': 1}),
#              '中': defaultdict(int, {'In': 31}),
#              '射进来': defaultdict(int, {'Shoot in.': 1}),
#              '照': defaultdict(int, {'Photo': 4}),
#              '糊着': defaultdict(int, {'Paste': 1}),
#              '四壁': defaultdict(int, {'Walls': 1}),
#              '故事': defaultdict(int, {'Story': 7}),
#              '猜想': defaultdict(int, {'Guess': 4}),
#              '这些': defaultdict(int, {'These': 20}),
#              '家庭': defaultdict(int, {'Family': 5}),
#              '女': defaultdict(int, {'Woman': 4}),
#              '教师': defaultdict(int, {'Teachers': 10}),
#              '自个儿': defaultdict(int, {'Myself': 1}),
#              '想看': defaultdict(int, {'I want to see it.': 1}),
#              '书': defaultdict(int, {'Book': 5}),
#              '的确': defaultdict(int, {'Do': 2}),
#              '眼下': defaultdict(int, {'Now': 2}),
#              '也许': defaultdict(int, {'Maybe': 10}),
#              '不止': defaultdict(int, {'More than': 1}),
#              '一切': defaultdict(int, {'All': 15}),
#              '而是': defaultdict(int, {'But': 4}),
#              '独一无二': defaultdict(int, {'Unique': 2}),
#              '头脑': defaultdict(int, {'Mind': 5}),
#              '某种': defaultdict(int, {'Some kind of': 3}),
#              '激发': defaultdict(int, {'Stimulate': 3}),
#              '内在': defaultdict(int, {'Inner': 1}),
#              '力量': defaultdict(int, {'Power': 3}),
#              '事': defaultdict(int, {'Things': 10}),
#              '脑袋': defaultdict(int, {'Head': 2}),
#              '第一次': defaultdict(int, {'First time': 4}),
#              '潜心': defaultdict(int, {'Painstaking': 1}),
#              '已': defaultdict(int, {'Has': 29}),
#              '被': defaultdict(int, {'Be': 40}),
#              '灌输': defaultdict(int, {'Instill': 1}),
#              '进去': defaultdict(int, {'Get in': 3}),
#              '天堂': defaultdict(int, {'Heaven': 2}),
#              '地狱': defaultdict(int, {'Hell': 1}),
#              '发生': defaultdict(int, {'Happen': 2}),
#              '最': defaultdict(int, {'Most': 9}),
#              '坏': defaultdict(int, {'Bad': 3}),
#              '情况': defaultdict(int, {'Situation': 7}),
#              '可以': defaultdict(int, {'OK': 25}),
#              '再': defaultdict(int, {'And again': 3}),
#              '登广告': defaultdict(int, {'Advertising': 3}),
#              '多': defaultdict(int, {'Many': 25}),
#              '一下': defaultdict(int, {'One moment.': 17}),
#              '铃': defaultdict(int, {'Bell': 4}),
#              '想要': defaultdict(int, {'Want': 1}),
#              '想解': defaultdict(int, {'I want to figure it out.': 1}),
#              '来客': defaultdict(int, {'Visitors': 1}),
#              '莉娅': defaultdict(int, {'Leah': 8}),
#              '走进': defaultdict(int, {'Into': 5}),
#              '门': defaultdict(int, {'Door': 13}),
#              '这条': defaultdict(int, {'This one.': 2}),
#              '狗': defaultdict(int, {'Dog': 6}),
#              '怎么回事': defaultdict(int, {"What's going on": 1}),
#              '突然': defaultdict(int, {'Suddenly': 2}),
#              '厌倦': defaultdict(int, {'Tired': 2}),
#              '憧憬': defaultdict(int, {'Vision': 1}),
#              '渴望': defaultdict(int, {'Desire': 5}),
#              '为': defaultdict(int, {'For': 21}),
#              '作': defaultdict(int, {'Make': 7}),
#              '一个': defaultdict(int, {'One': 99}),
#              '祷告': defaultdict(int, {'Pray': 2}),
#              '祈祷': defaultdict(int, {'Pray': 2}),
#              '似乎': defaultdict(int, {'Seems': 11}),
#              '问': defaultdict(int, {'Ask': 23}),
#              '哪': defaultdict(int, {'Which': 3}),
#              '房间': defaultdict(int, {'Room': 35}),
#              '屋里': defaultdict(int, {'Inside the house.': 3}),
#              '随身带': defaultdict(int, {'Carry-on': 1}),
#              '树林': defaultdict(int, {'Woods': 6}),
#              '各人': defaultdict(int, {'Each': 1}),
#              '找': defaultdict(int, {'Find': 7}),
#              '地方': defaultdict(int, {'Place': 21}),
#              '享受': defaultdict(int, {'Enjoy': 6}),
#              '一顿': defaultdict(int, {'A meal.': 2}),
#              '盛宴': defaultdict(int, {'Feast': 3}),
#              '坐在': defaultdict(int, {'Sitting in the': 7}),
#              '还有': defaultdict(int, {'And also': 12}),
#              '三': defaultdict(int, {'Three': 2}),
#              '楼': defaultdict(int, {'Floor': 3}),
#              '某些': defaultdict(int, {'Some': 3}),
#              '虽然': defaultdict(int, {'Although': 8}),
#              '暗': defaultdict(int, {'Dark': 2}),
#              '低': defaultdict(int, {'Low': 5}),
#              '古色古香': defaultdict(int, {'Antique': 1}),
#              '气派': defaultdict(int, {'Style': 3}),
#              '看来': defaultdict(int, {'Looks like': 2}),
#              '还是': defaultdict(int, {'Still is': 13}),
#              '别有情趣': defaultdict(int, {"Don't have fun.": 1}),
#              '小马': defaultdict(int, {'Pony': 1}),
#              '呆': defaultdict(int, {'Stay': 10}),
#              '花园': defaultdict(int, {'Garden': 5}),
#              '门口': defaultdict(int, {'Door': 3}),
#              '玛丽': defaultdict(int, {'Mary': 3}),
#              '·': defaultdict(int, {'·': 20}),
#              '安': defaultdict(int, {'An': 3}),
#              '一定': defaultdict(int, {'Must': 5}),
#              '有人': defaultdict(int, {'Someone': 9}),
#              '病': defaultdict(int, {'Disease': 2}),
#              '很重': defaultdict(int, {"It's heavy.": 1}),
#              '才': defaultdict(int, {"It's just": 10}),
#              '姑娘': defaultdict(int, {'Girl': 7}),
#              '会': defaultdict(int, {'Yes': 45}),
#              '我会': defaultdict(int, {'I will': 7}),
#              '吗': defaultdict(int, {'Do you?': 45}),
#              '一把': defaultdict(int, {'One.': 2}),
#              '撕下': defaultdict(int, {'Tore': 1}),
#              '这块': defaultdict(int, {'This one.': 3}),
#              '牌子': defaultdict(int, {'Brand': 1}),
#              '扔进': defaultdict(int, {'Throw it in.': 1}),
#              '火': defaultdict(int, {'Fire': 1}),
#              '不会': defaultdict(int, {'No': 12}),
#              '火气': defaultdict(int, {'Anger': 1}),
#              '整天': defaultdict(int, {'Day': 1}),
#              '在我心中': defaultdict(int, {'In my heart': 1}),
#              '露一手': defaultdict(int, {'Exposed one hand': 1}),
#              '椅子': defaultdict(int, {'Chair': 5}),
#              '下来': defaultdict(int, {'Get down': 3}),
#              '走到': defaultdict(int, {'Go to': 4}),
#              '面前': defaultdict(int, {'Front': 6}),
#              '坐上': defaultdict(int, {'Take it up.': 1}),
#              '接着': defaultdict(int, {'Then': 4}),
#              '一本正经': defaultdict(int, {'Serious': 1}),
#              '抱': defaultdict(int, {'Hold': 5}),
#              '双臂': defaultdict(int, {'Arms': 1}),
#              '这时候': defaultdict(int, {"That's when we": 1}),
#              '结婚': defaultdict(int, {'Get married': 3}),
#              '随': defaultdict(int, {'With': 1}),
#              '丈夫': defaultdict(int, {'Husband': 3}),
#              '牧师': defaultdict(int, {'Priest': 2}),
#              '出色': defaultdict(int, {'Excellent': 1}),
#              '几乎': defaultdict(int, {'Almost': 7}),
#              '与': defaultdict(int, {'And': 41}),
#              '妻子': defaultdict(int, {'Wife': 2}),
#              '相': defaultdict(int, {'Phase': 1}),
#              '疾驰': defaultdict(int, {'Galloped': 1}),
#              '那条': defaultdict(int, {'That one.': 5}),
#              '窜': defaultdict(int, {'Sprang': 2}),
#              '上去': defaultdict(int, {'Up': 3}),
#              '紧追不舍': defaultdict(int, {'Keep up': 1}),
#              '刹那之间': defaultdict(int, {'In a split second,': 1}),
#              '三者': defaultdict(int, {'Three': 1}),
#              '无影无踪': defaultdict(int, {'Trace': 1}),
#              '荒野': defaultdict(int, {'Wilderness': 1}),
#              '石楠': defaultdict(int, {'Heather': 1}),
#              '习惯': defaultdict(int, {'Habit': 4}),
#              '两': defaultdict(int, {'Two': 9}),
#              '小时': defaultdict(int, {'Hours': 10}),
#              '黑暗': defaultdict(int, {'Dark': 3}),
#              '恰成': defaultdict(int, {'Just in.': 1}),
#              '对比': defaultdict(int, {'Contrast': 1}),
#              '弄': defaultdict(int, {'Get': 2}),
#              '眼花缭乱': defaultdict(int, {'Dazzled': 1}),
#              '然而': defaultdict(int, {'However': 7}),
#              '定下': defaultdict(int, {'Set': 1}),
#              '神': defaultdict(int, {'God': 4}),
#              '盖': defaultdict(int, {'Cover': 7}),
#              '特拉西': defaultdict(int, {'Tracy': 6}),
#              '位': defaultdict(int, {'Bit': 3}),
#              '旅行者': defaultdict(int, {'Travelers': 2}),
#              '抄近路': defaultdict(int, {'Cut': 1}),
#              '米尔科': defaultdict(int, {'Milko': 6}),
#              '特': defaultdict(int, {'Special': 4}),
#              '身边': defaultdict(int, {'Side': 7}),
#              '走过': defaultdict(int, {'Walked': 6}),
#              '继续': defaultdict(int, {'Go on': 19}),
#              '开始': defaultdict(int, {'Begin': 13}),
#              '觉得': defaultdict(int, {'Think': 16}),
#              '饿': defaultdict(int, {'Hungry': 1}),
#              '份儿': defaultdict(int, {'A serving.': 1}),
#              '很小': defaultdict(int, {"It's small.": 1}),
#              '同样': defaultdict(int, {'Same': 7}),
#              '注意': defaultdict(int, {'Attention': 5}),
#              '巴巴拉': defaultdict(int, {'Barbara': 3}),
#              '遮': defaultdict(int, {'Cover': 1}),
#              '圆肚窗': defaultdict(int, {'Round belly window': 1}),
#              '闪烁着': defaultdict(int, {'Flashing': 2}),
#              '烛光': defaultdict(int, {'Candlelight': 2}),
#              '其余': defaultdict(int, {'Rest': 3}),
#              '漆黑': defaultdict(int, {'Dark': 1}),
#              '停': defaultdict(int, {'Stop': 1}),
#              '前门': defaultdict(int, {'Front door': 3}),
#              '女佣': defaultdict(int, {'Maid': 2}),
#              '开门': defaultdict(int, {'Open the door': 1}),
#              '下车': defaultdict(int, {'Get out': 1}),
#              '满口': defaultdict(int, {'Full': 1}),
#              '英语': defaultdict(int, {'English': 3}),
#              '索菲娅': defaultdict(int, {'Sophia': 8}),
#              '保姆': defaultdict(int, {'Nanny': 8}),
#              '一起': defaultdict(int, {'Together.': 10}),
#              '乘条': defaultdict(int, {'Multiply': 1}),
#              '大船': defaultdict(int, {'Ship': 1}),
#              '海洋': defaultdict(int, {'Ocean': 2}),
#              '乔治': defaultdict(int, {'George': 2}),
#              '三世': defaultdict(int, {'III': 1}),
#              '肖像': defaultdict(int, {'Portrait': 2}),
#              '另': defaultdict(int, {'Other': 6}),
#              '威尔士': defaultdict(int, {'Wales': 2}),
#              '亲王': defaultdict(int, {'Prince': 1}),
#              '画': defaultdict(int, {'Draw': 10}),
#              '沃尔夫': defaultdict(int, {'Wolf': 1}),
#              '死': defaultdict(int, {'Die': 9}),
#              '封信': defaultdict(int, {'Letter': 2}),
#              '写给': defaultdict(int, {'To': 1}),
#              'J': defaultdict(int, {'J': 2}),
#              '.': defaultdict(int, {'.': 7}),
#              'E': defaultdict(int, {'E': 3}),
#              '这么': defaultdict(int, {'So': 9}),
#              '一封': defaultdict(int, {'One letter.': 1}),
#              '男性': defaultdict(int, {'Men': 2}),
#              '躯体': defaultdict(int, {'Body': 2}),
#              '中那': defaultdict(int, {'Midna': 1}),
#              '本能': defaultdict(int, {'Instinct': 1}),
#              '品质': defaultdict(int, {'Quality': 2}),
#              '共鸣': defaultdict(int, {'Resonance': 1}),
#              '诊所': defaultdict(int, {'Clinic': 1}),
#              '护士长': defaultdict(int, {'Head nurse': 1}),
#              '并未': defaultdict(int, {'Not': 1}),
#              '习惯于': defaultdict(int, {'Get used to it.': 2}),
#              '新': defaultdict(int, {'New': 17}),
#              '规矩': defaultdict(int, {'Rules': 1}),
#              '因此': defaultdict(int, {'So': 6}),
#              '给得': defaultdict(int, {'Give it to': 1}),
#              '比较': defaultdict(int, {'Comparison': 3}),
#              '大方': defaultdict(int, {'Generous': 2}),
#              '饭': defaultdict(int, {'Rice': 1}),
#              '灯光': defaultdict(int, {'Light': 4}),
#              '提醒': defaultdict(int, {'Remind': 3}),
#              '不早': defaultdict(int, {"It's not early.": 1}),
#              '匆匆': defaultdict(int, {'Hurried': 1}),
#              '往前走': defaultdict(int, {'Go ahead.': 2}),
#              '情愿': defaultdict(int, {"'d rather": 1}),
#              '再次': defaultdict(int, {'Again': 8}),
#              '跨进': defaultdict(int, {'Step in': 2}),
#              '府': defaultdict(int, {'Fu': 6}),
#              '踏进': defaultdict(int, {'Entered': 2}),
#              '声响': defaultdict(int, {'Sound': 1}),
#              '地开': defaultdict(int, {'Open': 1}),
#              '关': defaultdict(int, {'Off': 4}),
#              '两道': defaultdict(int, {'Two': 1}),
#              '一排': defaultdict(int, {'A row.': 2}),
#              '楼梯': defaultdict(int, {'Stairs': 12}),
#              '拾级而上': defaultdict(int, {'Pick up level and up': 1}),
#              '正对面': defaultdict(int, {'Directly opposite': 1}),
#              '便是': defaultdict(int, {'Is': 1}),
#              '星': defaultdict(int, {'Star': 1}),
#              '信': defaultdict(int, {'Letter': 5}),
#              '溪水': defaultdict(int, {'Stream': 1}),
#              '魅力': defaultdict(int, {'Charm': 4}),
#              '冠冕堂皇': defaultdict(int, {'Sounding': 1}),
#              '差使': defaultdict(int, {'Poor make': 2}),
#              '度量': defaultdict(int, {'Measure': 1}),
#              '脚码': defaultdict(int, {'Foot code': 1}),
#              '做': defaultdict(int, {'Do': 21}),
#              '一双': defaultdict(int, {'A pair': 1}),
#              '鞋': defaultdict(int, {'Shoes': 1}),
#              '肩膀': defaultdict(int, {'Shoulder': 2}),
#              '胳膊': defaultdict(int, {'Arm': 6}),
#              '搂': defaultdict(int, {'Hugs': 3}),
#              '脖子': defaultdict(int, {'Neck': 2}),
#              '醒来': defaultdict(int, {'Wake up': 2}),
#              '小房间': defaultdict(int, {'Small room': 4}),
#              '这里': defaultdict(int, {'Over here': 16}),
#              '从来': defaultdict(int, {'Never': 6}),
#              '闹鬼': defaultdict(int, {'Haunted': 2}),
#              '鬼魂': defaultdict(int, {'Ghost': 2}),
#              '七点': defaultdict(int, {'Seven': 1}),
#              '半': defaultdict(int, {'Half': 1}),
#              '事务': defaultdict(int, {'Transaction': 2}),
#              '射出来': defaultdict(int, {'Shoot it out.': 1}),
#              '两扇门': defaultdict(int, {'Two doors.': 1}),
#              '开': defaultdict(int, {'Open': 6}),
#              '只见': defaultdict(int, {'Saw': 3}),
#              '宜人': defaultdict(int, {'Pleasant': 1}),
#              '炉火': defaultdict(int, {'Fire': 8}),
#              '映出': defaultdict(int, {'Reflected': 2}),
#              '大理石': defaultdict(int, {'Marble': 4}),
#              '炉板': defaultdict(int, {'Furnace plate': 1}),
#              '铜制': defaultdict(int, {'Copper': 1}),
#              '炉具': defaultdict(int, {'Stoves': 1}),
#              '并': defaultdict(int, {'And': 38}),
#              '绝不会': defaultdict(int, {'Never.': 1}),
#              '高兴': defaultdict(int, {'Happy': 11}),
#              '聪明': defaultdict(int, {'Smart': 3}),
#              '贝茜': defaultdict(int, {'Bessie': 12}),
#              '以': defaultdict(int, {'To': 10}),
#              '表示': defaultdict(int, {'Said': 5}),
#              '安慰': defaultdict(int, {'Comfort': 1}),
#              '人人': defaultdict(int, {'Everyone': 3}),
#              '相信': defaultdict(int, {'Believe': 12}),
#              '说谎': defaultdict(int, {'Lie': 1}),
#              '面包': defaultdict(int, {'Bread': 2}),
#              '噎住': defaultdict(int, {'Hold on.': 1}),
#              '凝视着': defaultdict(int, {'Staring': 3}),
#              '惊奇': defaultdict(int, {'Surprise': 1}),
#              '虽': defaultdict(int, {'Although': 2}),
#              '竭尽全力': defaultdict(int, {'Tried': 1}),
#              '却': defaultdict(int, {'But': 33}),
#              '主人': defaultdict(int, {'Master': 5}),
#              '平静': defaultdict(int, {'Calm': 7}),
#              '当然': defaultdict(int, {'Of course': 5}),
#              '跌断': defaultdict(int, {'Falling': 1}),
#              '只不过': defaultdict(int, {'Just': 3}),
#              '扭坏': defaultdict(int, {'Twisted': 1}),
#              '脚': defaultdict(int, {'Feet': 4}),
#              '站': defaultdict(int, {'Stand': 11}),
#              '试试': defaultdict(int, {'Try it.': 1}),
#              '不由自主': defaultdict(int, {'Involuntary': 1}),
#              '叫声': defaultdict(int, {'Call': 1}),
#              '唉': defaultdict(int, {'Alas': 1}),
#              '相距': defaultdict(int, {'Apart': 1}),
#              '一英里': defaultdict(int, {'One mile.': 2}),
#              '万籁俱寂': defaultdict(int, {'All the silence': 2}),
#              '清晰': defaultdict(int, {'Clear': 7}),
#              '听到': defaultdict(int, {'Hear': 8}),
#              '村落': defaultdict(int, {'Village': 1}),
#              '轻微': defaultdict(int, {'Slight': 1}),
#              '动静': defaultdict(int, {'Movement': 2}),
#              '耳朵': defaultdict(int, {'Ears': 4}),
#              '感受': defaultdict(int, {'Feel': 5}),
#              '水流声': defaultdict(int, {'The sound of water flow': 1}),
#              '不见': defaultdict(int, {'Missing': 3}),
#              '类': defaultdict(int, {'Class': 1}),
#              '侍者': defaultdict(int, {'Waiter': 2}),
#              '是否': defaultdict(int, {'Whether': 4}),
#              '探问': defaultdict(int, {'An outlaw': 1}),
#              '过': defaultdict(int, {'Too much': 27}),
#              '爱': defaultdict(int, {'Love': 16}),
#              '授予': defaultdict(int, {'Granted': 1}),
#              '满腔热情': defaultdict(int, {'Enthusiastic': 2}),
#              '地干': defaultdict(int, {'Ground dry': 1}),
#              '两年': defaultdict(int, {'Two years': 3}),
#              '改变': defaultdict(int, {'Change': 3}),
#              '主意': defaultdict(int, {'Idea': 3}),
#              '历经': defaultdict(int, {'After': 1}),
#              '变迁': defaultdict(int, {'Change': 1}),
#              '一直': defaultdict(int, {'Always': 6}),
#              '握': defaultdict(int, {'Hold': 1}),
#              '下手': defaultdict(int, {'Get off the hand': 1}),
#              '怎么样': defaultdict(int, {'What do you think': 4}),
#              '告诉': defaultdict(int, {'Tell': 7}),
#              '问题': defaultdict(int, {'Problem': 12}),
#              '太': defaultdict(int, {'Too': 6}),
#              '礼貌': defaultdict(int, {'Polite': 1}),
#              '更何况': defaultdict(int, {"What's more,": 1}),
#              '到时候': defaultdict(int, {'When the time comes,': 1}),
#              '肯定': defaultdict(int, {'Sure': 4}),
#              '有所': defaultdict(int, {'There are some': 2}),
#              '闻': defaultdict(int, {'Smell': 2}),
#              '花格': defaultdict(int, {'Flower': 1}),
#              '窗': defaultdict(int, {'Window': 2}),
#              '这类': defaultdict(int, {'This kind of': 1}),
#              '直通': defaultdict(int, {'Through': 1}),
#              '一间': defaultdict(int, {'One': 6}),
#              '间': defaultdict(int, {'Between': 1}),
#              '卧室': defaultdict(int, {'Bedroom': 2}),
#              '长长': defaultdict(int, {'Long': 1}),
#              '道': defaultdict(int, {'Road': 6}),
#              '住家': defaultdict(int, {'Home': 1}),
#              '说说话': defaultdict(int, {'Talk.': 1}),
#              '教': defaultdict(int, {'Teach': 7}),
#              '读书': defaultdict(int, {'Reading': 2}),
#              '让': defaultdict(int, {'Let': 22}),
#              '成为': defaultdict(int, {'Become': 4}),
#              '女人': defaultdict(int, {'Woman': 8}),
#              '走近': defaultdict(int, {'Get close': 6}),
#              '曾': defaultdict(int, {'Had': 7}),
#              '吩咐': defaultdict(int, {'Told': 5}),
#              '用作': defaultdict(int, {'As': 2}),
#              '教室': defaultdict(int, {'Classroom': 4}),
#              '大部分': defaultdict(int, {'Most': 1}),
#              '锁': defaultdict(int, {'Lock': 2}),
#              '玻璃门': defaultdict(int, {'Glass door': 2}),
#              '内': defaultdict(int, {'Inside': 2}),
#              '书架': defaultdict(int, {'Shelf': 1}),
#              '却是': defaultdict(int, {'But it is.': 4}),
#              '敞开': defaultdict(int, {'Open': 4}),
#              '半个': defaultdict(int, {'Half': 1}),
#              '钟': defaultdict(int, {'Minutes': 3}),
#              '敲响': defaultdict(int, {'Ring': 5}),
#              '五点': defaultdict(int, {'Five': 1}),
#              '散课': defaultdict(int, {'Breakout class': 1}),
#              '大家': defaultdict(int, {'Everyone': 4}),
#              '进': defaultdict(int, {'Into': 5}),
#              '饭厅': defaultdict(int, {'Dining room': 1}),
#              '吃': defaultdict(int, {'Eat': 10}),
#              '茶点': defaultdict(int, {'Refreshment': 5}),
#              '胆': defaultdict(int, {'Bile': 1}),
#              '描绘': defaultdict(int, {'Depicted': 2}),
#              '人和事': defaultdict(int, {'People and things': 1}),
#              '特点': defaultdict(int, {'Characteristics': 1}),
#              '善良': defaultdict(int, {'Kind': 4}),
#              '属于': defaultdict(int, {'Belongs to': 2}),
#              '类人': defaultdict(int, {'Class': 1}),
#              '问话': defaultdict(int, {'Questioning': 1}),
#              '大惑不解': defaultdict(int, {'Mystified': 1}),
#              '伙食': defaultdict(int, {'Food': 2}),
#              '量': defaultdict(int, {'Volume': 1}),
#              '少质': defaultdict(int, {'Less quality': 1}),
#              '差': defaultdict(int, {'Poor': 1}),
#              '做饭': defaultdict(int, {'Cook': 1}),
#              '水': defaultdict(int, {'Water': 2}),
#              '臭': defaultdict(int, {'Stink': 1}),
#              '恶心': defaultdict(int, {'Nausea': 1}),
#              '学生': defaultdict(int, {'Students': 11}),
#              '衣着': defaultdict(int, {'Clothes': 3}),
#              '远靠': defaultdict(int, {'Far away.': 1}),
#              '房子': defaultdict(int, {'House': 13}),
#              '另外': defaultdict(int, {'Other than that': 2}),
#              '一头': defaultdict(int, {'A': 4}),
#              '认得': defaultdict(int, {'Recognize': 4}),
#              '路': defaultdict(int, {'Lu': 4}),
#              '夏夜': defaultdict(int, {'Summer': 1}),
#              '皎洁': defaultdict(int, {'Bright': 1}),
#              '月光': defaultdict(int, {'Moonlight': 5}),
#              '零零落落': defaultdict(int, {'Zero fall': 2}),
#              '洒进': defaultdict(int, {'Sprinkle in': 1}),
#              '那样': defaultdict(int, {"That's it.": 4}),
#              '多久': defaultdict(int, {'How long': 3}),
#              '愿意': defaultdict(int, {'Would': 3}),
#              '偶象': defaultdict(int, {'Even image': 1}),
#              '崇拜': defaultdict(int, {'Worship': 1}),
#              '般的': defaultdict(int, {'Like': 6}),
#              '虔诚': defaultdict(int, {'Pious': 1}),
#              '写': defaultdict(int, {'Write': 3}),
#              '迎合': defaultdict(int, {'Meet': 1}),
#              '父母': defaultdict(int, {'Parents': 2}),
#              '利己主义': defaultdict(int, {'Egoism': 1}),
#              '附和': defaultdict(int, {'Echo': 1}),
#              '时髦': defaultdict(int, {'Fashionable': 1}),
#              '高论': defaultdict(int, {'High theory': 1}),
#              '支持': defaultdict(int, {'Support': 1}),
#              '忍受': defaultdict(int, {'Stand': 1}),
#              '骨': defaultdict(int, {'Bone': 1}),
#              '折断': defaultdict(int, {'Break': 1}),
#              '或者': defaultdict(int, {'Or': 17}),
#              '愿让': defaultdict(int, {'Would you like to let': 1}),
#              '公牛': defaultdict(int, {'Bull': 1}),
#              '悬空': defaultdict(int, {'Dangling': 1}),
#              '抛起': defaultdict(int, {'Throw it up.': 1}),
#              '一匹': defaultdict(int, {'One horse.': 4}),
#              '蹶': defaultdict(int, {'The': 1}),
#              '腿': defaultdict(int, {'Leg': 2}),
#              '绅士': defaultdict(int, {'Gentleman': 5}),
#              '如此': defaultdict(int, {'So': 4}),
#              '大胆': defaultdict(int, {'Bold': 1}),
#              '违背': defaultdict(int, {'Against': 1}),
#              '心愿': defaultdict(int, {'Wish': 3}),
#              '提出': defaultdict(int, {'Presented': 4}),
#              '而且': defaultdict(int, {'And': 22}),
#              '开口': defaultdict(int, {'Opening': 2}),
#              '出于': defaultdict(int, {'For': 2}),
#              '请': defaultdict(int, {'Please': 8}),
#              '帮忙': defaultdict(int, {'Help': 6}),
#              '一只': defaultdict(int, {'One': 3}),
#              '沉重': defaultdict(int, {'Heavy': 3}),
#              '搭': defaultdict(int, {'Take': 2}),
#              '退缩': defaultdict(int, {'Retreat': 2}),
#              '打开': defaultdict(int, {'Open it': 5}),
#              '窗户': defaultdict(int, {'Window': 5}),
#              '梳妆台': defaultdict(int, {'Dresser': 1}),
#              '收拾': defaultdict(int, {'Pack': 2}),
#              '徒劳无功': defaultdict(int, {'Vain': 1}),
#              '心': defaultdict(int, {'Heart': 2}),
#              '乱加': defaultdict(int, {'Messy': 1}),
#              '麻': defaultdict(int, {'Ma': 1}),
#              '便立': defaultdict(int, {'The poise': 1}),
#              '转转': defaultdict(int, {'Turn': 1}),
#              '拉开': defaultdict(int, {'Opened': 2}),
#              '望见': defaultdict(int, {'See': 1}),
#              '一两颗': defaultdict(int, {'One or two.': 1}),
#              '星星': defaultdict(int, {'Stars': 2}),
#              '寒夜': defaultdict(int, {'Night': 1}),
#              '历史悠久': defaultdict(int, {'Has a long history': 1}),
#              '窄小': defaultdict(int, {'Narrow': 1}),
#              '高': defaultdict(int, {'High': 6}),
#              '背': defaultdict(int, {'Back': 2}),
#              '更加': defaultdict(int, {'More': 7}),
#              '古老': defaultdict(int, {'Old': 2}),
#              ...})

# %% [markdown]
# Let's produce a dictionary where words (keys) are associated with their ***most frequent*** POS tag:

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())
mfc_table
# Out:
# {'进步': 'Progress',
#  '此外': 'In addition,',
#  '我': 'I',
#  '也': 'Also',
#  '深受': 'By',
#  '同学': 'Classmates',
#  '们': 'We',
#  '的': 'The',
#  '欢迎': 'Welcome',
#  '同': 'With',
#  '年龄': 'Age',
#  '相仿': 'Similar',
#  '人': 'People',
#  '对': 'Right',
#  '平等': 'Equal',
#  '相待': 'Wait inge',
#  '屈尊': 'Condescension',
#  '就': 'Just.',
#  '驾': 'Driving',
#  '结果': 'Results',
#  '这样': 'This way,',
#  '倒': 'Pour down',
#  '更好': 'Better',
#  '处境': 'Situation',
#  '更': 'More',
#  '自由': 'Free',
#  '还': 'Also',
#  '在': 'In',
#  '沉思': 'Meditation',
#  '着': 'On the',
#  '这个': 'This one',
#  '跟着': 'Follow',
#  '费尔法克斯': 'Fairfax',
#  '太太': 'Wife',
#  '她': 'She',
#  '把': 'Put',
#  '刚才': 'Just now',
#  '新闻': 'News',
#  '重复': 'Repeat',
#  '一遍': 'Once again.',
#  '说': 'Said',
#  '外科医生': 'Surgeon',
#  '卡特': 'Carter',
#  '已经': 'Have',
#  '来': 'To',
#  '这会儿': 'Now',
#  '罗切斯特': 'Rochester',
#  '先生': 'Mr',
#  '睡': 'Sleep',
#  '得': 'Get it.',
#  '好好': 'Good',
#  '’': "'",
#  '”': '"',
#  '喃喃地': 'Muttering',
#  '“': '"',
#  '你': 'You',
#  '现在': 'Right now',
#  '上': 'On',
#  '哪儿': 'Where',
#  '去': 'To',
#  '呀': 'Oh, yes.',
#  '因为': 'Because',
#  '—': '—',
#  '靠近': 'Near',
#  '大门': 'Door',
#  '那个': 'That one',
#  '教堂': 'Church',
#  '是': 'Is',
#  '他': 'He',
#  '管': 'Tube',
#  '这位': 'The',
#  '母亲': 'Mother',
#  '家': 'Home',
#  '那他': 'Then he',
#  '不是': 'No',
#  '自己': 'Myself',
#  '主动': 'Active',
#  '要': 'To',
#  '抚养': 'Raise',
#  '小姐': 'Miss',
#  '感到': 'Feel',
#  '很': 'Is',
#  '遗憾': 'Regret',
#  '不得不': 'Had',
#  '矮篱': 'Dwarf Hedges',
#  '草地': 'Grass',
#  '和': 'And',
#  '庭园': 'Garden',
#  '分开': 'Separate',
#  '上长': 'Upper long',
#  '一排排': 'A row of',
#  '巨大': 'Huge',
#  '老': 'Old',
#  '荆棘': 'Thorns',
#  '树丛': 'Trees',
#  '强劲': 'Strong',
#  '多节': 'Multi-section',
#  '大': 'Big',
#  '如': 'Such as',
#  '橡树': 'Oak',
#  '疼痛': 'Pain',
#  '蹒跚': 'Lurched',
#  '地': 'Ground',
#  '踱': "I'd be",
#  '向': 'To',
#  '起身': 'Up',
#  '离开': 'Leave',
#  '台阶': 'Steps',
#  '一': 'One',
#  '屁股': 'Ass',
#  '坐下': 'Sit down',
#  '心里': 'Heart',
#  '发现': 'Found',
#  '一位': 'A',
#  '所': 'The',
#  '企盼': 'Hope',
#  '融洽': 'Harmonious',
#  '伙伴': 'Partner',
#  '不过': 'But',
#  '今晚': 'Tonight',
#  '可': 'Can be',
#  '不想': "Don't want to",
#  '留': 'Stay',
#  '确实': 'Do',
#  '去年': 'Last year',
#  '冬天': 'Winter',
#  '如果': 'If',
#  '记得': 'Remember',
#  '的话': 'Words',
#  '那': 'That',
#  '个': 'A',
#  '很冷': "It's cold.",
#  '下雪': 'Snow',
#  '就是': 'It is',
#  '刮风下雨': "It's windy and rainy.",
#  '从': 'From',
#  '十一月': 'November',
#  '呢': 'What about?',
#  '可是': 'But',
#  '跟': 'With',
#  '千千万万': 'Thousands',
#  '有': 'Yes',
#  '什么': 'What the',
#  '关系': 'Relationship',
#  '认识': 'Know',
#  '八十个': 'Eighty.',
#  '马': 'Horse',
#  '接跟': 'Pick up',
#  '而': 'And',
#  '匹': 'Pi',
#  '高头大马': 'Tall horse',
#  '马背上': 'On horseback.',
#  '坐': 'Sit',
#  '骑手': 'Rider',
#  '男人': 'Man',
#  '本身': 'Itself',
#  '立刻': 'Immediately',
#  '驱散': 'Disperse',
#  '消瘦': 'Thin',
#  '手': 'Hand',
#  '手腕': 'Wrist',
#  '都': 'All',
#  '冰冷': 'Cold',
#  '只有': 'Only',
#  '微笑': 'Smile',
#  '依旧': 'Still',
#  '为什么': 'Why',
#  '到': 'To',
#  '这儿': 'Here',
#  '鼻音': 'Twang',
#  '曲': 'Song',
#  '除': 'Except',
#  '认为': 'Think',
#  '讨厌': 'Hate',
#  '没有': 'No',
#  '别的': 'Other',
#  '看法': 'View',
#  '满意': 'Satisfaction',
#  '迎来': 'Usher',
#  '它': 'It',
#  '最初': 'First',
#  '深沉': 'Deep',
#  '曲调': 'Tune',
#  '天真烂漫': 'Innocent',
#  '情调': 'Mood',
#  '唱': 'Sing',
#  '完': 'Finish',
#  '以后': 'later',
#  '膝头': 'Knees',
#  '跳': 'Jump',
#  '下': 'Next',
#  '给': 'To give',
#  '怀疑': 'Doubt',
#  '包含': 'Contains',
#  '要死': 'Die',
#  '意思': 'Mean',
#  '但': 'But',
#  '此刻': 'Now',
#  '立即': 'Immediately',
#  '明白': 'Got it',
#  '理解': 'Understand',
#  '起来': 'Get up',
#  '这': 'This',
#  '那里': 'There',
#  '等': 'Wait, wait, wait',
#  '公共': 'Public',
#  '马车': 'Carriage',
#  '刷好': 'Brush it.',
#  '黑': 'Black',
#  '旅行': 'Travel',
#  '装备': 'Equipment',
#  '好': 'Good',
#  '帽子': 'Hat',
#  '手套': 'Gloves',
#  '皮手筒': 'Leather hand barrel',
#  '所有': 'All',
#  '服从': 'Obey',
#  '放在': 'Put in',
#  '高高的': 'High',
#  '骏马': 'Horse',
#  '走去': 'Go.',
#  '竭力': 'Tried',
#  '想': 'Think',
#  '抓住': 'Catch',
#  '马笼头': 'Horse Cage Head',
#  '敢肯定': 'Be sure.',
#  '很多': 'A lot',
#  '那么': 'So',
#  '同情': 'Sympathy',
#  '布罗克': 'Brock',
#  '赫斯特': 'Hurst',
#  '说话': 'Speak',
#  '她们': 'They',
#  '怎么': 'How',
#  '可能': 'possible',
#  '妈妈': 'Mom',
#  '圣母': 'Virgin',
#  '玛丽亚': 'Maria',
#  '那儿': 'There',
#  '去后': 'After you go.',
#  '谁': 'Who',
#  '一块儿': 'A piece of',
#  '住': 'Live',
#  '弗雷德里克': 'Frederick',
#  '像': 'Like',
#  '墓穴': 'Grave',
#  '指指': 'Refers to',
#  '窗子': 'Window',
#  '相对': 'Relative',
#  '应': 'Should',
#  '一扇': 'One',
#  '又': 'And again',
#  '宽': 'Wide',
#  '拱门': 'Arches',
#  '一样': 'The same',
#  '海伦': 'Helen',
#  '要是': 'If',
#  '说错': "That's wrong.",
#  '足以': 'Enough',
#  '使': 'Make',
#  '有幸': 'Fortunate enough',
#  '听': 'Listen',
#  '谈话': 'Talk',
#  '品味': 'Taste',
#  '高级': 'Senior',
#  '脚步': 'Footsteps',
#  '欣赏': 'Appreciate',
#  '此时': 'At this point,',
#  '此景': 'This scene',
#  '蕴蓄': 'Contains',
#  '种种': 'Various',
#  '欢乐': 'Joy',
#  '时候': 'When',
#  '三点': 'Three',
#  '经过': 'After',
#  '钟楼': 'Clock tower',
#  '时': 'When',
#  '势': 'Potential',
#  '自然': 'Natural',
#  '不能': 'No',
#  '忽视': 'Ignore',
#  '所以': 'So',
#  '仍': 'Still',
#  '担任': 'As',
#  '司库': 'Treasurer',
#  '职': 'Vocational',
#  '履行': 'Fulfill',
#  '职务': 'Duties',
#  '得到': 'Get',
#  '更为': 'More',
#  '慷慨': 'Generous',
#  '富有': 'Rich',
#  '睡着': 'Fell asleep',
#  '一支': 'One',
#  '灯芯': 'Wick',
#  '未': 'Not',
#  '剪': 'Cut',
#  '蜡烛': 'Candle',
#  '幽幽地': 'The claustrophobic',
#  '桌子': 'Table',
#  '上燃': 'On-fire',
#  '看到': 'See',
#  '坦普尔': 'Temple',
#  '后来': 'Later',
#  '知道': 'Know',
#  '赶路': 'On the way',
#  '没': "Didn't",
#  '走': 'Go',
#  '几步': 'A few steps.',
#  '便': 'Poe',
#  '回过头来': 'Looking back.',
#  '一阵': 'A',
#  '东西': 'Things',
#  '滑落': 'Slipped',
#  '声音': 'Voice',
#  '一声': 'One out.',
#  '怎么办': 'What to do',
#  '活见鬼': 'Live hell.',
#  '图案': 'Pattern',
#  '墙纸': 'Wallpaper',
#  '地毯': 'Carpet',
#  '家具': 'Furniture',
#  '壁炉': 'Fireplace',
#  '摆设': 'Decoration',
#  '图片': 'Image',
#  '其中': 'Where',
#  '一幅': 'One',
#  '喜欢': 'Like',
#  '小家伙': 'Little',
#  '正像': 'As',
#  '好心': 'Kind',
#  '怀着': 'With',
#  '感激': 'Grateful',
#  '之': 'The',
#  '情': 'Love',
#  '同时': 'At the same time,',
#  '达': 'Da',
#  '不到': 'Less than',
#  '难道': "Don't",
#  '这事': 'This thing.',
#  '不': 'No',
#  '可行': 'Feasible',
#  '达到': 'Reach',
#  '目的': 'Objective',
#  '并非': 'Not',
#  '难事': 'Difficult',
#  '只要': 'Just',
#  '肯': 'Ken',
#  '动脑筋': 'Brainstorm',
#  '红房子': 'Red House',
#  '事件': 'Event',
#  '详细': 'With',
#  '诉说': 'Tell',
#  '情绪': 'Emotions',
#  '有点': 'A little bit.',
#  '失态': 'Loss',
#  '当': 'When',
#  '里德': 'Reed',
#  '断然拒绝': 'Categorically refused.',
#  '发疯': 'Crazy',
#  '似的': "It's like.",
#  '科特': 'Kurt',
#  '工业': 'Industrial',
#  '城市': 'City',
#  '坐落': 'Located',
#  '埃': 'E',
#  '×': 's',
#  '河岸': 'River',
#  '无疑': 'Undoubtedly',
#  '够': 'Enough',
#  '热闹': 'Lively',
#  '岂': "Don't you",
#  '踏上去': 'Get on the road',
#  '洛顿': 'Lotton',
#  '路途': 'Road',
#  '顺便': 'By the way.',
#  '提': 'Ti',
#  '一句': 'One sentence.',
#  '小路': 'Path',
#  '风景如画': 'Picturesque',
#  '沿着': 'Along',
#  '小溪': 'Stream',
#  '向前': 'Forward',
#  '延伸': 'Extended',
#  '穿过': 'Through',
#  '弯弯曲曲': 'Winding',
#  '秀色': 'Show',
#  '诱人': 'Attractive',
#  '山谷': 'Valley',
#  '游戏': 'Game',
#  '时刻': 'Moment',
#  '有时': 'Sometimes',
#  '逢': 'Every',
#  '好日子': 'Day',
#  '天气': 'Weather',
#  '甚至': 'Even',
#  '变得': 'Become',
#  '温暖': 'Warm',
#  '舒适': 'Comfortable',
#  '枯黄': 'Yellow',
#  '苗圃': 'Nursery',
#  '长': 'Long',
#  '出': 'Out',
#  '一片': 'A',
#  '新绿': 'Green',
#  '一天': 'One day',
#  '精疲力尽': 'Exhausted',
#  '谈到': 'Talked about',
#  '伤心': 'Sad',
#  '话题': 'Topic',
#  '比': 'Than',
#  '平时': 'Usually',
#  '克制': 'Restraint',
#  '记住': 'Remember',
#  '告诫': 'Warned',
#  '绳子': 'Rope',
#  '捆好': 'Tie it up.',
#  '贴上标签': 'Put a label on it.',
#  '半小时': 'Half an hour.',
#  '之后': 'After',
#  '脚夫': 'Porter',
#  '取走': 'Take it.',
#  '送往': 'Send to',
#  '则': 'Then',
#  '第二天': 'Day 2',
#  '一早': 'Morning',
#  '赶到': 'To',
#  '白天': 'Day',
#  '异样': 'Strange',
#  '抖动': 'Jitter',
#  '弄醒': 'Wake up.',
#  '抬起头来': 'Look up.',
#  '发现自己': 'Find yourself',
#  '正': 'Is',
#  '躺': 'Lying',
#  '别人': 'Others',
#  '怀抱': 'Arms',
#  '里': 'Inside',
#  '彻底': 'Completely',
#  '浇灭': 'Watering out',
#  '这回': 'This time.',
#  '步行': 'Walk',
#  '激起': 'Stirred',
#  '兴奋': 'Excited',
#  '重': 'Heavy',
#  '用': 'Use',
#  '一成不变': 'Same',
#  '静止': 'Static',
#  '生活': 'Life',
#  '无形': 'Intangible',
#  '镣铐': 'Chains',
#  '锁住': 'Lock up.',
#  '吸引': 'Attract',
#  '争辩': 'Argue',
#  '或许': 'Maybe',
#  '桑': 'Sang',
#  '菲尔德': 'Field',
#  '离镇': 'Away from town',
#  '远': 'Far',
#  '这时': 'Then',
#  '残烛': 'Residual Candles',
#  '落入': 'Fall',
#  '语言': 'Language',
#  '几句': 'A few words.',
#  '起初': 'Initially',
#  '回答': 'Reply',
#  '简短': 'Short',
#  '我们': 'We',
#  '桌旁': 'At the table',
#  '坐定': 'Sit down.',
#  '淡褐色': 'Hazel',
#  '上面': 'Above',
#  '摆': 'Swing',
#  '基础教育': 'Elementary education',
#  '需要': 'Need',
#  '各类': 'Various',
#  '书籍': 'Books',
#  '几部': 'Several',
#  '轻松': 'Easy',
#  '文学作品': 'Literary works',
#  '诗歌': 'Poetry',
#  '传记': 'Biography',
#  '游记': 'Travels',
#  '一些': 'A few',
#  '传奇': 'Legend',
#  '柜子': 'Cabinet',
#  '奇怪': 'Strange',
#  '雕刻': 'Carving',
#  '棕榈': 'Palm',
#  '树枝': 'Branches',
#  '小天使': 'Little Angel',
#  '头部': 'Head',
#  '看上去': 'Look',
#  '各种': 'Various',
#  '希伯莱': 'Hibernian',
#  '约柜': 'Interview cabinet',
#  '；': ';',
#  '映照': 'Mapping',
#  '叫': 'Call',
#  '派': 'Sent',
#  '洛特': 'Lott',
#  '！': '!',
#  '后': 'After',
#  '乖乖': 'Be good.',
#  '吱声': 'Squeaking',
#  '咽下': 'Swallow it.',
#  '眼泪': 'Tears',
#  '咳嗽': 'Cough',
#  '吵醒': 'Wake',
#  '护士': 'Nurse',
#  '咳完': "I've finished coughing up",
#  '几分钟': 'A few minutes.',
#  '随后': 'Then',
#  '亮': 'Bright',
#  '阳光': 'Sunlight',
#  '蓝色': 'Blue',
#  '鲜艳': 'Bright',
#  '印花布': 'Calico',
#  '窗帘': 'Curtains',
#  '缝隙': 'Gap',
#  '中': 'In',
#  '射进来': 'Shoot in.',
#  '照': 'Photo',
#  '糊着': 'Paste',
#  '四壁': 'Walls',
#  '故事': 'Story',
#  '猜想': 'Guess',
#  '这些': 'These',
#  '家庭': 'Family',
#  '女': 'Woman',
#  '教师': 'Teachers',
#  '自个儿': 'Myself',
#  '想看': 'I want to see it.',
#  '书': 'Book',
#  '的确': 'Do',
#  '眼下': 'Now',
#  '也许': 'Maybe',
#  '不止': 'More than',
#  '一切': 'All',
#  '而是': 'But',
#  '独一无二': 'Unique',
#  '头脑': 'Mind',
#  '某种': 'Some kind of',
#  '激发': 'Stimulate',
#  '内在': 'Inner',
#  '力量': 'Power',
#  '事': 'Things',
#  '脑袋': 'Head',
#  '第一次': 'First time',
#  '潜心': 'Painstaking',
#  '已': 'Has',
#  '被': 'Be',
#  '灌输': 'Instill',
#  '进去': 'Get in',
#  '天堂': 'Heaven',
#  '地狱': 'Hell',
#  '发生': 'Happen',
#  '最': 'Most',
#  '坏': 'Bad',
#  '情况': 'Situation',
#  '可以': 'OK',
#  '再': 'And again',
#  '登广告': 'Advertising',
#  '多': 'Many',
#  '一下': 'One moment.',
#  '铃': 'Bell',
#  '想要': 'Want',
#  '想解': 'I want to figure it out.',
#  '来客': 'Visitors',
#  '莉娅': 'Leah',
#  '走进': 'Into',
#  '门': 'Door',
#  '这条': 'This one.',
#  '狗': 'Dog',
#  '怎么回事': "What's going on",
#  '突然': 'Suddenly',
#  '厌倦': 'Tired',
#  '憧憬': 'Vision',
#  '渴望': 'Desire',
#  '为': 'For',
#  '作': 'Make',
#  '一个': 'One',
#  '祷告': 'Pray',
#  '祈祷': 'Pray',
#  '似乎': 'Seems',
#  '问': 'Ask',
#  '哪': 'Which',
#  '房间': 'Room',
#  '屋里': 'Inside the house.',
#  '随身带': 'Carry-on',
#  '树林': 'Woods',
#  '各人': 'Each',
#  '找': 'Find',
#  '地方': 'Place',
#  '享受': 'Enjoy',
#  '一顿': 'A meal.',
#  '盛宴': 'Feast',
#  '坐在': 'Sitting in the',
#  '还有': 'And also',
#  '三': 'Three',
#  '楼': 'Floor',
#  '某些': 'Some',
#  '虽然': 'Although',
#  '暗': 'Dark',
#  '低': 'Low',
#  '古色古香': 'Antique',
#  '气派': 'Style',
#  '看来': 'Looks like',
#  '还是': 'Still is',
#  '别有情趣': "Don't have fun.",
#  '小马': 'Pony',
#  '呆': 'Stay',
#  '花园': 'Garden',
#  '门口': 'Door',
#  '玛丽': 'Mary',
#  '·': '·',
#  '安': 'An',
#  '一定': 'Must',
#  '有人': 'Someone',
#  '病': 'Disease',
#  '很重': "It's heavy.",
#  '才': "It's just",
#  '姑娘': 'Girl',
#  '会': 'Yes',
#  '我会': 'I will',
#  '吗': 'Do you?',
#  '一把': 'One.',
#  '撕下': 'Tore',
#  '这块': 'This one.',
#  '牌子': 'Brand',
#  '扔进': 'Throw it in.',
#  '火': 'Fire',
#  '不会': 'No',
#  '火气': 'Anger',
#  '整天': 'Day',
#  '在我心中': 'In my heart',
#  '露一手': 'Exposed one hand',
#  '椅子': 'Chair',
#  '下来': 'Get down',
#  '走到': 'Go to',
#  '面前': 'Front',
#  '坐上': 'Take it up.',
#  '接着': 'Then',
#  '一本正经': 'Serious',
#  '抱': 'Hold',
#  '双臂': 'Arms',
#  '这时候': "That's when we",
#  '结婚': 'Get married',
#  '随': 'With',
#  '丈夫': 'Husband',
#  '牧师': 'Priest',
#  '出色': 'Excellent',
#  '几乎': 'Almost',
#  '与': 'And',
#  '妻子': 'Wife',
#  '相': 'Phase',
#  '疾驰': 'Galloped',
#  '那条': 'That one.',
#  '窜': 'Sprang',
#  '上去': 'Up',
#  '紧追不舍': 'Keep up',
#  '刹那之间': 'In a split second,',
#  '三者': 'Three',
#  '无影无踪': 'Trace',
#  '荒野': 'Wilderness',
#  '石楠': 'Heather',
#  '习惯': 'Habit',
#  '两': 'Two',
#  '小时': 'Hours',
#  '黑暗': 'Dark',
#  '恰成': 'Just in.',
#  '对比': 'Contrast',
#  '弄': 'Get',
#  '眼花缭乱': 'Dazzled',
#  '然而': 'However',
#  '定下': 'Set',
#  '神': 'God',
#  '盖': 'Cover',
#  '特拉西': 'Tracy',
#  '位': 'Bit',
#  '旅行者': 'Travelers',
#  '抄近路': 'Cut',
#  '米尔科': 'Milko',
#  '特': 'Special',
#  '身边': 'Side',
#  '走过': 'Walked',
#  '继续': 'Go on',
#  '开始': 'Begin',
#  '觉得': 'Think',
#  '饿': 'Hungry',
#  '份儿': 'A serving.',
#  '很小': "It's small.",
#  '同样': 'Same',
#  '注意': 'Attention',
#  '巴巴拉': 'Barbara',
#  '遮': 'Cover',
#  '圆肚窗': 'Round belly window',
#  '闪烁着': 'Flashing',
#  '烛光': 'Candlelight',
#  '其余': 'Rest',
#  '漆黑': 'Dark',
#  '停': 'Stop',
#  '前门': 'Front door',
#  '女佣': 'Maid',
#  '开门': 'Open the door',
#  '下车': 'Get out',
#  '满口': 'Full',
#  '英语': 'English',
#  '索菲娅': 'Sophia',
#  '保姆': 'Nanny',
#  '一起': 'Together.',
#  '乘条': 'Multiply',
#  '大船': 'Ship',
#  '海洋': 'Ocean',
#  '乔治': 'George',
#  '三世': 'III',
#  '肖像': 'Portrait',
#  '另': 'Other',
#  '威尔士': 'Wales',
#  '亲王': 'Prince',
#  '画': 'Draw',
#  '沃尔夫': 'Wolf',
#  '死': 'Die',
#  '封信': 'Letter',
#  '写给': 'To',
#  'J': 'J',
#  '.': '.',
#  'E': 'E',
#  '这么': 'So',
#  '一封': 'One letter.',
#  '男性': 'Men',
#  '躯体': 'Body',
#  '中那': 'Midna',
#  '本能': 'Instinct',
#  '品质': 'Quality',
#  '共鸣': 'Resonance',
#  '诊所': 'Clinic',
#  '护士长': 'Head nurse',
#  '并未': 'Not',
#  '习惯于': 'Get used to it.',
#  '新': 'New',
#  '规矩': 'Rules',
#  '因此': 'So',
#  '给得': 'Give it to',
#  '比较': 'Comparison',
#  '大方': 'Generous',
#  '饭': 'Rice',
#  '灯光': 'Light',
#  '提醒': 'Remind',
#  '不早': "It's not early.",
#  '匆匆': 'Hurried',
#  '往前走': 'Go ahead.',
#  '情愿': "'d rather",
#  '再次': 'Again',
#  '跨进': 'Step in',
#  '府': 'Fu',
#  '踏进': 'Entered',
#  '声响': 'Sound',
#  '地开': 'Open',
#  '关': 'Off',
#  '两道': 'Two',
#  '一排': 'A row.',
#  '楼梯': 'Stairs',
#  '拾级而上': 'Pick up level and up',
#  '正对面': 'Directly opposite',
#  '便是': 'Is',
#  '星': 'Star',
#  '信': 'Letter',
#  '溪水': 'Stream',
#  '魅力': 'Charm',
#  '冠冕堂皇': 'Sounding',
#  '差使': 'Poor make',
#  '度量': 'Measure',
#  '脚码': 'Foot code',
#  '做': 'Do',
#  '一双': 'A pair',
#  '鞋': 'Shoes',
#  '肩膀': 'Shoulder',
#  '胳膊': 'Arm',
#  '搂': 'Hugs',
#  '脖子': 'Neck',
#  '醒来': 'Wake up',
#  '小房间': 'Small room',
#  '这里': 'Over here',
#  '从来': 'Never',
#  '闹鬼': 'Haunted',
#  '鬼魂': 'Ghost',
#  '七点': 'Seven',
#  '半': 'Half',
#  '事务': 'Transaction',
#  '射出来': 'Shoot it out.',
#  '两扇门': 'Two doors.',
#  '开': 'Open',
#  '只见': 'Saw',
#  '宜人': 'Pleasant',
#  '炉火': 'Fire',
#  '映出': 'Reflected',
#  '大理石': 'Marble',
#  '炉板': 'Furnace plate',
#  '铜制': 'Copper',
#  '炉具': 'Stoves',
#  '并': 'And',
#  '绝不会': 'Never.',
#  '高兴': 'Happy',
#  '聪明': 'Smart',
#  '贝茜': 'Bessie',
#  '以': 'To',
#  '表示': 'Said',
#  '安慰': 'Comfort',
#  '人人': 'Everyone',
#  '相信': 'Believe',
#  '说谎': 'Lie',
#  '面包': 'Bread',
#  '噎住': 'Hold on.',
#  '凝视着': 'Staring',
#  '惊奇': 'Surprise',
#  '虽': 'Although',
#  '竭尽全力': 'Tried',
#  '却': 'But',
#  '主人': 'Master',
#  '平静': 'Calm',
#  '当然': 'Of course',
#  '跌断': 'Falling',
#  '只不过': 'Just',
#  '扭坏': 'Twisted',
#  '脚': 'Feet',
#  '站': 'Stand',
#  '试试': 'Try it.',
#  '不由自主': 'Involuntary',
#  '叫声': 'Call',
#  '唉': 'Alas',
#  '相距': 'Apart',
#  '一英里': 'One mile.',
#  '万籁俱寂': 'All the silence',
#  '清晰': 'Clear',
#  '听到': 'Hear',
#  '村落': 'Village',
#  '轻微': 'Slight',
#  '动静': 'Movement',
#  '耳朵': 'Ears',
#  '感受': 'Feel',
#  '水流声': 'The sound of water flow',
#  '不见': 'Missing',
#  '类': 'Class',
#  '侍者': 'Waiter',
#  '是否': 'Whether',
#  '探问': 'An outlaw',
#  '过': 'Too much',
#  '爱': 'Love',
#  '授予': 'Granted',
#  '满腔热情': 'Enthusiastic',
#  '地干': 'Ground dry',
#  '两年': 'Two years',
#  '改变': 'Change',
#  '主意': 'Idea',
#  '历经': 'After',
#  '变迁': 'Change',
#  '一直': 'Always',
#  '握': 'Hold',
#  '下手': 'Get off the hand',
#  '怎么样': 'What do you think',
#  '告诉': 'Tell',
#  '问题': 'Problem',
#  '太': 'Too',
#  '礼貌': 'Polite',
#  '更何况': "What's more,",
#  '到时候': 'When the time comes,',
#  '肯定': 'Sure',
#  '有所': 'There are some',
#  '闻': 'Smell',
#  '花格': 'Flower',
#  '窗': 'Window',
#  '这类': 'This kind of',
#  '直通': 'Through',
#  '一间': 'One',
#  '间': 'Between',
#  '卧室': 'Bedroom',
#  '长长': 'Long',
#  '道': 'Road',
#  '住家': 'Home',
#  '说说话': 'Talk.',
#  '教': 'Teach',
#  '读书': 'Reading',
#  '让': 'Let',
#  '成为': 'Become',
#  '女人': 'Woman',
#  '走近': 'Get close',
#  '曾': 'Had',
#  '吩咐': 'Told',
#  '用作': 'As',
#  '教室': 'Classroom',
#  '大部分': 'Most',
#  '锁': 'Lock',
#  '玻璃门': 'Glass door',
#  '内': 'Inside',
#  '书架': 'Shelf',
#  '却是': 'But it is.',
#  '敞开': 'Open',
#  '半个': 'Half',
#  '钟': 'Minutes',
#  '敲响': 'Ring',
#  '五点': 'Five',
#  '散课': 'Breakout class',
#  '大家': 'Everyone',
#  '进': 'Into',
#  '饭厅': 'Dining room',
#  '吃': 'Eat',
#  '茶点': 'Refreshment',
#  '胆': 'Bile',
#  '描绘': 'Depicted',
#  '人和事': 'People and things',
#  '特点': 'Characteristics',
#  '善良': 'Kind',
#  '属于': 'Belongs to',
#  '类人': 'Class',
#  '问话': 'Questioning',
#  '大惑不解': 'Mystified',
#  '伙食': 'Food',
#  '量': 'Volume',
#  '少质': 'Less quality',
#  '差': 'Poor',
#  '做饭': 'Cook',
#  '水': 'Water',
#  '臭': 'Stink',
#  '恶心': 'Nausea',
#  '学生': 'Students',
#  '衣着': 'Clothes',
#  '远靠': 'Far away.',
#  '房子': 'House',
#  '另外': 'Other than that',
#  '一头': 'A',
#  '认得': 'Recognize',
#  '路': 'Lu',
#  '夏夜': 'Summer',
#  '皎洁': 'Bright',
#  '月光': 'Moonlight',
#  '零零落落': 'Zero fall',
#  '洒进': 'Sprinkle in',
#  '那样': "That's it.",
#  '多久': 'How long',
#  '愿意': 'Would',
#  '偶象': 'Even image',
#  '崇拜': 'Worship',
#  '般的': 'Like',
#  '虔诚': 'Pious',
#  '写': 'Write',
#  '迎合': 'Meet',
#  '父母': 'Parents',
#  '利己主义': 'Egoism',
#  '附和': 'Echo',
#  '时髦': 'Fashionable',
#  '高论': 'High theory',
#  '支持': 'Support',
#  '忍受': 'Stand',
#  '骨': 'Bone',
#  '折断': 'Break',
#  '或者': 'Or',
#  '愿让': 'Would you like to let',
#  '公牛': 'Bull',
#  '悬空': 'Dangling',
#  '抛起': 'Throw it up.',
#  '一匹': 'One horse.',
#  '蹶': 'The',
#  '腿': 'Leg',
#  '绅士': 'Gentleman',
#  '如此': 'So',
#  '大胆': 'Bold',
#  '违背': 'Against',
#  '心愿': 'Wish',
#  '提出': 'Presented',
#  '而且': 'And',
#  '开口': 'Opening',
#  '出于': 'For',
#  '请': 'Please',
#  '帮忙': 'Help',
#  '一只': 'One',
#  '沉重': 'Heavy',
#  '搭': 'Take',
#  '退缩': 'Retreat',
#  '打开': 'Open it',
#  '窗户': 'Window',
#  '梳妆台': 'Dresser',
#  '收拾': 'Pack',
#  '徒劳无功': 'Vain',
#  '心': 'Heart',
#  '乱加': 'Messy',
#  '麻': 'Ma',
#  '便立': 'The poise',
#  '转转': 'Turn',
#  '拉开': 'Opened',
#  '望见': 'See',
#  '一两颗': 'One or two.',
#  '星星': 'Stars',
#  '寒夜': 'Night',
#  '历史悠久': 'Has a long history',
#  '窄小': 'Narrow',
#  '高': 'High',
#  '背': 'Back',
#  '更加': 'More',
#  '古老': 'Old',
#  ...}

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 120: break
# Out:
# 进步 Progress
# 此外 In addition,
# 我 I
# 也 Also
# 深受 By
# 同学 Classmates
# 们 We
# 的 The
# 欢迎 Welcome
# 同 With
# 年龄 Age
# 相仿 Similar
# 人 People
# 对 Right
# 平等 Equal
# 相待 Wait inge
# 屈尊 Condescension
# 就 Just.
# 驾 Driving
# 结果 Results
# 这样 This way,
# 倒 Pour down
# 更好 Better
# 处境 Situation
# 更 More
# 自由 Free
# 还 Also
# 在 In
# 沉思 Meditation
# 着 On the
# 这个 This one
# 跟着 Follow
# 费尔法克斯 Fairfax
# 太太 Wife
# 她 She
# 把 Put
# 刚才 Just now
# 新闻 News
# 重复 Repeat
# 一遍 Once again.
# 说 Said
# 外科医生 Surgeon
# 卡特 Carter
# 已经 Have
# 来 To
# 这会儿 Now
# 罗切斯特 Rochester
# 先生 Mr
# 睡 Sleep
# 得 Get it.
# 好好 Good
# ’ '
# ” "
# 喃喃地 Muttering
# “ "
# 你 You
# 现在 Right now
# 上 On
# 哪儿 Where
# 去 To
# 呀 Oh, yes.
# 因为 Because
# — —
# 靠近 Near
# 大门 Door
# 那个 That one
# 教堂 Church
# 是 Is
# 他 He
# 管 Tube
# 这位 The
# 母亲 Mother
# 家 Home
# 那他 Then he
# 不是 No
# 自己 Myself
# 主动 Active
# 要 To
# 抚养 Raise
# 小姐 Miss
# 感到 Feel
# 很 Is
# 遗憾 Regret
# 不得不 Had
# 矮篱 Dwarf Hedges
# 草地 Grass
# 和 And
# 庭园 Garden
# 分开 Separate
# 上长 Upper long
# 一排排 A row of
# 巨大 Huge
# 老 Old
# 荆棘 Thorns
# 树丛 Trees
# 强劲 Strong
# 多节 Multi-section
# 大 Big
# 如 Such as
# 橡树 Oak
# 疼痛 Pain
# 蹒跚 Lurched
# 地 Ground
# 踱 I'd be
# 向 To
# 起身 Up
# 离开 Leave
# 台阶 Steps
# 一 One
# 屁股 Ass
# 坐下 Sit down
# 心里 Heart
# 发现 Found
# 一位 A
# 所 The
# 企盼 Hope
# 融洽 Harmonious
# 伙伴 Partner
# 不过 But
# 今晚 Tonight
# 可 Can be

# %% [markdown]
# Python `namedtuple` supports a type of container-like dictionary that, like dictionaries, contains keys that are hashed to particular values. But it supports *both* access from key values as well as *iteration*, the functionality that dictionaries lack.
#
# Let's write a class that takes in a table in its constructor and adds `<MISSING>` POS tags if the word is missing from the training set (possible that a word is in the test set but missing from the training set). It also has a `viterbi` method that takes in the table and builds a sequence of states that we will use in our Hidden Markov Model.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %% [markdown]
# So essentially we built a table that associates words with their most frequent POS tag. This is a simplistic **bag of words** (BOW) model. Let's see, given a sentence, if we *guess the hidden states* (POS tags) right!

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:1]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: 15680
#
# Sentence: ('没听说过', '”', '费尔法克斯', '太太', '笑', '着', '说', '“', '鬼', '的', '传说', '也', '没有', '没有', '传奇', '或者', '鬼故事', '”', '“', '我')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '"', 'Fairfax', 'Wife', 'Laugh', 'On the', 'Said', '"', 'Ghost', 'The', '<MISSING>', 'Also', 'No', 'No', 'Legend', 'Or', '<MISSING>', '"', '"', 'I']
#
# Actual labels:
# --------------
# ("I've never heard of it.", '"', 'Fairfax', 'Wife', 'Laugh', 'On the', 'Said', '"', 'Ghost', 'The', 'Legend', 'Also', 'No', 'No', 'Legend', 'Or', 'Ghost Story', '"', '"', 'I')

# %% [markdown]
# Pretty good! Let's evaluate the accuracy of our most-frequent-tag tagger:

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 100.00%
# testing accuracy mfc_model: 81.95%

# %% [markdown]
# # Hidden Markov Model
#
# Let's build a POS tagger using a Hidden Markov Model.
#
# First, let's see how many POS tags we have in our corpus, using the python `Counter` structure that we used last week to count instances.

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
len(tag_unigrams)
# Out:
# 3215

# %% [markdown]
# We'll *slightly* modify the code above to get our POS bigrams, from *both* training and test subsets, to uncover which POS tags follow which other POS tags. So, instead of a simple list of POS tags, `Counter` will count *neighboring* POS tuples!

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
len(tag_bigrams)
# Out:
# 8188

# %% [markdown]
# What tags do our sentences *begin* with?

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'Half': 1,
#          'Go': 3,
#          'Magic': 1,
#          'No': 10,
#          'Do': 4,
#          'The': 73,
#          'On the': 12,
#          'Progress': 1,
#          'I': 58,
#          'The date': 1,
#          'When': 4,
#          'Walked': 1,
#          'Said': 7,
#          'Bread': 1,
#          "Can't": 3,
#          'Knee': 1,
#          '"': 33,
#          'People': 9,
#          'Despise': 1,
#          'Be sure.': 1,
#          'Also': 10,
#          'Public': 1,
#          'You': 11,
#          'Obvious': 1,
#          'To': 14,
#          'Whole': 1,
#          'Stand': 3,
#          'Horse': 2,
#          'Love': 3,
#          'Go inside.': 1,
#          ';': 4,
#          'Yes': 7,
#          'Charges': 1,
#          'Rewards': 1,
#          'Sink': 1,
#          'She': 17,
#          'Moon': 1,
#          'Recognize it.': 1,
#          'We': 3,
#          'Apartments': 1,
#          'Chair': 1,
#          'Do you?': 3,
#          'Forever': 2,
#          'Girl': 1,
#          'Wife': 4,
#          'But': 13,
#          'Jane': 3,
#          'Fact': 1,
#          'A few minutes.': 1,
#          'Exhausted': 1,
#          'Blindly': 1,
#          'Listen': 1,
#          'Beg': 1,
#          'I will': 1,
#          'Slander': 1,
#          'Say,': 1,
#          'Begin': 3,
#          'Think': 4,
#          'Pull': 1,
#          'Sigh': 1,
#          'Just.': 4,
#          'How': 2,
#          'Has': 2,
#          'Iron': 1,
#          'Wait, wait, wait': 1,
#          'Lack': 1,
#          'Right now': 1,
#          'Food': 1,
#          'Take': 1,
#          'Gentle': 1,
#          'Maybe': 1,
#          'Power': 2,
#          'In': 21,
#          'Flow': 1,
#          'Judge': 1,
#          'Spring': 2,
#          'Nature': 1,
#          '!': 2,
#          'Temple': 3,
#          'Told': 1,
#          'Right': 1,
#          'Miss': 4,
#          'By the door.': 1,
#          'Hear': 3,
#          'One': 9,
#          'A': 5,
#          'It': 2,
#          'Combustion': 1,
#          'He': 7,
#          '·': 1,
#          'Complete clarification': 1,
#          'This way,': 2,
#          'Pay': 1,
#          'And': 18,
#          'Allow': 2,
#          'Hut': 1,
#          'Reverie': 1,
#          'In this way,': 1,
#          'Mature': 1,
#          'Ivy': 1,
#          'Fluent': 1,
#          'Strong': 1,
#          'Head': 1,
#          'Hard': 1,
#          'Raging': 1,
#          'Game': 1,
#          'Than': 2,
#          'Three colors': 1,
#          'Shade': 1,
#          'That': 8,
#          'Until': 1,
#          'Rush': 1,
#          'As for': 1,
#          'Quiet': 1,
#          'Get up': 2,
#          'Male': 1,
#          'Flowered': 1,
#          'Golden': 1,
#          'Always': 2,
#          'Put': 3,
#          'Another thing.': 1,
#          "I've got your": 1,
#          'Girls': 1,
#          'All': 4,
#          'Teachers': 1,
#          'Blanket': 1,
#          'Dean': 1,
#          'Distribution': 1,
#          'such as lin': 1,
#          'Smell': 1,
#          'Wonderful': 1,
#          'Where': 1,
#          'Lowood': 1,
#          'Is': 19,
#          'Less': 1,
#          'These': 1,
#          'Look': 2,
#          'What the': 6,
#          'Harmonious': 1,
#          'Many': 1,
#          'Affection': 1,
#          'School': 4,
#          'Get': 3,
#          'Occasion': 1,
#          'Can not see clearly': 1,
#          'Get it.': 2,
#          'In the forest': 1,
#          'Pony': 1,
#          'Evening': 1,
#          'Dig it.': 1,
#          'A while': 1,
#          'Sky': 2,
#          'Connotation': 1,
#          'Rickety': 1,
#          'Close the door': 1,
#          'Mr': 3,
#          'Doubt': 1,
#          'Sentence': 1,
#          'Drop': 1,
#          'So': 8,
#          'Aisle': 2,
#          'Get close': 1,
#          'Be': 3,
#          'Sound': 1,
#          'From': 2,
#          'Stuffy': 1,
#          'Close': 2,
#          'On': 1,
#          'Body': 1,
#          'Hangings': 1,
#          'Fear': 1,
#          'Calm': 1,
#          'Thin': 1,
#          'Sick.': 1,
#          'Come': 1,
#          'Softly': 1,
#          'Photo': 1,
#          'Go on': 1,
#          'Sad': 1,
#          'Disaster': 1,
#          'Believe': 2,
#          'Creator': 1,
#          'Die': 1,
#          'Oh, God': 1,
#          'After': 1,
#          'Universal': 1,
#          'Ah, yes.': 3,
#          'Have': 4,
#          'The one.': 2,
#          'Shoulder': 2,
#          'Brock': 1,
#          'Marble': 2,
#          '-': 3,
#          'Life': 3,
#          'Only': 2,
#          'Ground': 3,
#          'This': 6,
#          'Benefit': 1,
#          'Make': 3,
#          'Potential': 1,
#          'Compassion': 1,
#          'Happy': 2,
#          'And again': 3,
#          'As': 1,
#          'Communication': 1,
#          'Partner': 1,
#          'Match': 1,
#          'No longer': 2,
#          'Very': 3,
#          'Step in': 1,
#          'Thinking': 1,
#          'Gap': 1,
#          "Let's say": 1,
#          'Feel': 1,
#          'The mountains are up and down': 1,
#          'Mountain': 1,
#          'World': 1,
#          'Know': 2,
#          'Suddenly': 2,
#          'Into': 3,
#          'New': 4,
#          'Available.': 1,
#          'Just': 1,
#          'Twang': 1,
#          'Exempt': 1,
#          'Must': 2,
#          'Because': 2,
#          "It's a waste": 1,
#          'Here': 1,
#          'Found it': 1,
#          'How can I do that': 1,
#          'Had': 2,
#          'Then': 2,
#          'What about?': 1,
#          'Same': 1,
#          'Send to': 1,
#          'Teaching': 1,
#          "It's just": 1,
#          '.': 3,
#          'Principal': 1,
#          'Store': 1,
#          'Week': 1,
#          'Get on the road': 1,
#          'Letter': 2,
#          'Put it on.': 1,
#          'Put it in': 1,
#          'Homework': 1,
#          'Other': 2,
#          'Effect': 1,
#          'Abbreviation': 1,
#          'Please': 1,
#          'Near': 1,
#          "Let's go": 1,
#          'Legitimate': 1,
#          'Old fashioned': 1,
#          'Place': 2,
#          'London': 2,
#          'Kurt': 1,
#          'Better': 1,
#          'Candlestick': 1,
#          'For': 2,
#          'Of course': 1,
#          'Transaction': 1,
#          'Enough': 1,
#          'Rope': 1,
#          'There': 1,
#          'One moment.': 4,
#          'Now': 1,
#          'Quasi -': 1,
#          'Living room': 1,
#          '—': 3,
#          'Hand': 1,
#          'Women': 1,
#          "Happy can't help itself": 1,
#          'Little': 1,
#          'Bobby': 1,
#          'They': 3,
#          'Good': 1,
#          'Too': 1,
#          'Not good': 1,
#          'Dividends': 1,
#          'Lips': 1,
#          'Completely': 2,
#          'Children': 1,
#          'Never.': 1,
#          'Reed': 1,
#          'With': 3,
#          'Pieces': 1,
#          'Pour down': 2,
#          'Foreign': 1,
#          'Later': 1,
#          'Hours': 1,
#          'Hurst': 1,
#          'Imagine': 1,
#          'The same': 2,
#          'By': 3,
#          'Inside': 3,
#          'Clock': 1,
#          'One stop.': 1,
#          'Anxious': 1,
#          'Sang': 5,
#          'Side': 2,
#          'Uneasy': 1,
#          'Call': 3,
#          'Leather hand barrel': 1,
#          'Off': 1,
#          'Carriage': 1,
#          'Fairfax': 1,
#          'End': 1,
#          'Happen': 1,
#          'Put it down': 1,
#          'Quite': 1,
#          'Area': 1,
#          'Field': 3,
#          'Eyes': 1,
#          'One.': 1,
#          'Wearing': 1,
#          'Feet': 1,
#          "Today's people": 1,
#          'Dear': 1,
#          'Sit': 1,
#          'Frozen': 1,
#          'Besides': 1,
#          'Ears': 1,
#          'More': 1,
#          'Teach': 1,
#          'Lonely': 1,
#          'Servant': 1,
#          'Poor': 1,
#          'Day': 1,
#          "It's too late": 1,
#          'Those': 1,
#          'Next': 1,
#          'High': 1,
#          'Church': 1,
#          'Finally': 1,
#          'Efforts': 1,
#          'Room': 2,
#          'Pu': 1,
#          'Small': 1,
#          'Abnormal': 1,
#          'A little bit of a': 1,
#          'Desire': 1,
#          'Instead': 1,
#          'Situation': 1,
#          'Wish': 1,
#          "It's logical.": 1,
#          'Although': 2,
#          'Neat': 1,
#          'Stairs': 1,
#          'Chest care': 1,
#          'Ceiling': 1,
#          'Magnificent': 1,
#          'Battlements': 2,
#          'Dwarf Hedges': 1,
#          'Broad': 1,
#          'Often': 2,
#          'Everyone': 1,
#          'At least': 1,
#          "It's nothing to do with me": 1,
#          'Expect': 1,
#          'Guardian': 1,
#          'Big': 1,
#          'Kind': 1,
#          'Condescension': 1,
#          'Facial features': 1,
#          'But it is.': 1,
#          'French': 1,
#          'Fortunately': 1,
#          'Lady': 2,
#          'Teacher': 1,
#          'Myself': 1,
#          'Road': 2,
#          'OK': 1,
#          'On board': 1,
#          'Days': 1,
#          'Plate': 1,
#          'Go hang out.': 1,
#          'And also': 2,
#          'Mom': 1,
#          'Curls': 1,
#          'Waiter': 1,
#          'Up and up': 1,
#          'Innocent': 1,
#          'Recite': 1,
#          'First': 1,
#          'Experienced': 1,
#          "That's it.": 1,
#          'Above': 1,
#          'Story': 2,
#          'Globe': 1,
#          'Habit': 1,
#          'Purple': 1,
#          'Color': 1,
#          'Spar': 1,
#          'A little.': 2,
#          'Like': 2,
#          'Hanging': 1,
#          'Leaves': 1,
#          'Out': 2,
#          'Material': 1,
#          'Raise': 1,
#          'Long': 1,
#          'See': 1,
#          'Laugh': 1,
#          'Two': 1,
#          'Depicted': 1,
#          "There's nothing else.": 1,
#          'Understand': 1,
#          'Way': 1,
#          'Once': 1,
#          'Projected': 1,
#          'Wear': 1,
#          'Quaint': 1,
#          'Shut down': 1,
#          'Strange': 1,
#          'Things': 1,
#          'Small room': 2,
#          'Wandering': 1,
#          "I've never heard of it.": 1,
#          'Sleep': 1,
#          'Skylight': 1,
#          'Lawn': 1,
#          'Brown': 1,
#          'Blue': 2,
#          'Woods': 1,
#          'Laughter': 3,
#          'Rang': 1,
#          'Poe': 1,
#          'Who': 1,
#          'Shouting': 1,
#          'Thirty': 1,
#          'Remember': 1,
#          'When it was,': 1,
#          'Aspects': 1,
#          'Tame': 1,
#          'Special': 1,
#          'Language': 1,
#          'Maintain': 1,
#          'Even image': 1,
#          'Lie': 1,
#          'Isolated': 1,
#          'Adele': 2,
#          'Any': 1,
#          'At the same time,': 1,
#          'If': 1,
#          'Strict': 1,
#          'Narrow heart': 1,
#          'Beyond': 1,
#          'To this end': 1,
#          'A few': 1,
#          'Cause': 1,
#          'Opening': 1,
#          'On the house': 1,
#          'Narrative': 1,
#          'October': 1,
#          'Lu': 1,
#          'To give': 1,
#          'Taste': 1,
#          'Reply': 1,
#          'Footsteps': 1,
#          'Minutes': 1,
#          'One mile.': 1,
#          'Stay': 1,
#          'Evergreen': 1,
#          'Silent': 1,
#          "It's like.": 1,
#          'Top knot': 1,
#          'Nest': 1,
#          'Go.': 1,
#          'Bright': 1,
#          'Apart': 1,
#          'Too much': 2,
#          'Wind': 1,
#          "It's true.": 1,
#          'Thick ink': 1,
#          'Mountains': 1,
#          "Don't move.": 1,
#          'Memory': 1,
#          'Condensing': 1,
#          'Elves': 1,
#          'Magic Gas': 1,
#          'Cover': 2,
#          'On the way': 1,
#          'Yelling': 1,
#          'Help': 1,
#          'Right away': 1,
#          'Horse hiss': 1,
#          'Bend down.': 1,
#          'Pain': 1,
#          'Falling': 1,
#          'Clear': 1,
#          'About': 1,
#          'Gentleman': 1,
#          'Men': 1,
#          'Avoid': 1,
#          'Let': 1,
#          'That one': 1,
#          'Never': 1,
#          'Tell': 1,
#          'Cloak': 1,
#          'Obey': 1,
#          'Pi': 1,
#          'Mohammed': 1,
#          'Catch': 1,
#          'Show': 1,
#          'Haimura': 1,
#          'Home': 1,
#          'Again': 1,
#          'Threshold': 1,
#          'Throw': 1,
#          'Comparable': 1,
#          'Natural': 1,
#          'Building': 1,
#          'Profound': 1,
#          'Stars': 1,
#          'Light up': 1,
#          'Shoot it out.': 1,
#          'Together.': 1,
#          'Follow': 1,
#          'Fire': 1,
#          'Tone': 1,
#          'Railings': 1})

# %% [markdown]
# What tags do our sentences *end* with?

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
# tag_ends

# %% [markdown]
# Not surprising that most end with a period `.`! Ideally, we should end with the previous-to-last tag!

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
# tag_ends

# %% [markdown]
# Let's create our Hidden Markov Model and peek into most popular words per POS tag.
#
# `tag_words_count` contains words associated to each POS tag, arranged by frequency so that we can eventually evaluate *emission* probabilities, which are probabilities of observable states (wrods) given hidden states (POS tags).

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-2] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

# tag_words_count

# %%
ending_tag_list
# Out:
# ['On the',
#  'I',
#  'No',
#  'Performance',
#  'Made',
#  'Miss',
#  'Same',
#  'Equal',
#  'And also',
#  'This one',
#  'Light',
#  '"',
#  'Or',
#  'But',
#  'On the',
#  'First',
#  'What about?',
#  'Thousands',
#  'Eighty.',
#  'You',
#  'I',
#  'He',
#  'Everywhere',
#  'Yes',
#  'Yes',
#  'Myself',
#  '"',
#  'You',
#  'No',
#  'Look for it.',
#  'I will',
#  'Leg',
#  'People',
#  'Body',
#  'Outside',
#  'World',
#  'In',
#  'Suffered',
#  'But',
#  'Inside',
#  'We',
#  'Sad',
#  'Mixed up',
#  'One',
#  'Take up',
#  'Silently',
#  'Cloud Block',
#  'We',
#  '"',
#  "Let's do it",
#  'She',
#  'Low',
#  'All',
#  "'m afraid",
#  'Yes',
#  'A',
#  '"',
#  'The',
#  'She',
#  'Raise',
#  'Good',
#  'Myself',
#  'Remember',
#  'I',
#  'Excited',
#  'Warned',
#  'Content',
#  'Narrative',
#  'No',
#  'Crazy',
#  'Is',
#  'Some',
#  'You',
#  'Right',
#  'Is',
#  'That',
#  'Joy',
#  '"',
#  'Stand',
#  'She',
#  'The',
#  'Servant',
#  'Plate',
#  'The',
#  "It's because",
#  'She',
#  'Go',
#  'One moment.',
#  'All',
#  'Barbara',
#  'This',
#  'A small piece.',
#  'Fruit',
#  'Less',
#  'Drink',
#  'Hostess',
#  'Tray',
#  'And',
#  'Solemn',
#  'She',
#  'The',
#  'Is',
#  'Power',
#  'Then',
#  'More',
#  'Meaningful',
#  'I',
#  'Eloquent',
#  'Rush',
#  'Heard',
#  'To',
#  'Really',
#  'Is',
#  'One',
#  'The',
#  'Delay',
#  '!',
#  'Helen',
#  'Bedroom',
#  'Come out',
#  'Get it.',
#  'With',
#  'Miss',
#  'It',
#  'Wear',
#  'Poe',
#  'Day',
#  'What it looks like',
#  'Yes',
#  'Right',
#  'Slander',
#  'Team',
#  'Desperately',
#  'Yes',
#  'I',
#  'Make',
#  'Forget',
#  'I',
#  'Feast',
#  'Kei',
#  'Peck',
#  'Green',
#  'French',
#  'Each other',
#  'The',
#  'Or',
#  'No longer',
#  'Red',
#  'Canada',
#  'Spend',
#  'Green',
#  'Increasingly',
#  'And',
#  'In',
#  'A',
#  'Trees',
#  'This',
#  'Oh, yes.',
#  'And',
#  'Rapids',
#  'More',
#  'One',
#  'Vegetation',
#  'Vibrant',
#  'Wild',
#  'Talk',
#  'And',
#  'Just.',
#  'When',
#  'Or not',
#  'Time epidemic',
#  'To',
#  'Eighty-five',
#  'Because',
#  'Miss',
#  "It's not far away.",
#  'People',
#  'People',
#  'In',
#  'Aisle',
#  'From',
#  'Up root',
#  'Little',
#  'Apple',
#  'Lowood',
#  'Season',
#  'Love',
#  'Never',
#  'Successor',
#  'The',
#  'Housekeeper',
#  'Yes',
#  'Like',
#  'River',
#  'On',
#  'Wilson',
#  'She',
#  'Happy',
#  'Said',
#  "Get where you've got to do",
#  'No',
#  'She',
#  'First',
#  'The',
#  'Senior',
#  'Yes',
#  'Affection',
#  'All',
#  'Right now',
#  'No',
#  'Childish',
#  'The',
#  'In',
#  'And',
#  '·',
#  'Place',
#  'A group of',
#  'Ride',
#  "It's just",
#  'Forest',
#  'Many',
#  'West',
#  'Ground',
#  'The',
#  'Is',
#  'Very',
#  'Hell',
#  'See',
#  'Think',
#  'But',
#  'After',
#  '"',
#  'Said',
#  'Let',
#  'No',
#  'Get up',
#  'The',
#  'See',
#  'Nurse',
#  'In',
#  'To',
#  'Hours',
#  'Has',
#  'Find',
#  'Ground',
#  'Remind',
#  'People',
#  '—',
#  'Finally',
#  'Star',
#  'To',
#  'I',
#  'Met',
#  'Under',
#  'One.',
#  'Later',
#  'Stop it',
#  'See',
#  'Myself',
#  'I',
#  '!',
#  'No',
#  'Also',
#  'Here',
#  'Heard',
#  'Maybe',
#  'The',
#  'Is',
#  'A few minutes.',
#  '"',
#  'After',
#  'Can be',
#  'The',
#  'Too',
#  'Big',
#  'Wrong',
#  '"',
#  'I',
#  'He',
#  'Give it back.',
#  'And',
#  'Believe',
#  'The',
#  'Die',
#  'Great',
#  'Think about it.',
#  'She',
#  'Lying',
#  'How',
#  'Leave',
#  'Helen',
#  'Good night',
#  'The',
#  'Arms',
#  'Be',
#  'I',
#  'Burns',
#  'The',
#  'Arms',
#  'Be',
#  'I',
#  'Burns',
#  'Grave',
#  'Grey',
#  '-',
#  'Life',
#  'But',
#  'The',
#  'Poe',
#  'People',
#  'Health',
#  'The',
#  'Big',
#  'Rules',
#  'And again',
#  'And',
#  'Know',
#  'When the time comes,',
#  'When',
#  'I',
#  'Conditions',
#  'The',
#  '1st',
#  'Change',
#  'Friendship',
#  'I',
#  'Wife',
#  'I',
#  'The',
#  'Thought',
#  'Believe',
#  'The',
#  'After',
#  'The',
#  'When',
#  'I',
#  'This',
#  'Things',
#  'The',
#  'Keep',
#  'Experience',
#  'Worried',
#  'True meaning',
#  'Edge',
#  'Is',
#  'The',
#  'Canyon',
#  'The',
#  'After',
#  'No',
#  'And',
#  'I',
#  'Conventional',
#  'Be',
#  'Begged',
#  'I',
#  'I',
#  'Long',
#  '!',
#  'Come out.',
#  'Usual',
#  'Tune',
#  'This',
#  'Yes',
#  'Sweet',
#  'I',
#  'This',
#  'Ken',
#  'Night',
#  'The',
#  'The',
#  'The',
#  'Less than',
#  'I',
#  'Nothing has happened.',
#  'In',
#  'When',
#  'I',
#  'How',
#  'Advertising',
#  'Reply',
#  'To',
#  'Very',
#  'Bell',
#  'Lady',
#  'Think',
#  'Competent',
#  'Zhang',
#  '.',
#  'New to come',
#  'Promise',
#  'Go shopping',
#  'The',
#  'I',
#  'Valley',
#  'I',
#  'Shoes',
#  'Post office',
#  '.',
#  'In',
#  'One',
#  '—',
#  '"',
#  'Ago',
#  'We',
#  'I',
#  'Candlestick',
#  'Hypnosis',
#  'On the agency',
#  'The',
#  'Provide',
#  'Thirty',
#  'Milko',
#  'Stability',
#  'Cool',
#  'Decent',
#  'Wife',
#  'The',
#  'Order',
#  'Memory',
#  'County',
#  'Place',
#  "Don't you",
#  'Round',
#  'Residual Candles',
#  'Myself',
#  'Found it',
#  'Please',
#  'They',
#  'Day 2',
#  'I',
#  'I',
#  'I',
#  'When',
#  'The',
#  'The one.',
#  'Tutor',
#  'Also',
#  'Has',
#  'To',
#  'Put',
#  'To',
#  'I',
#  "Can't",
#  'Servant',
#  '"',
#  'The',
#  'She',
#  'I',
#  'Pay',
#  'The',
#  'I',
#  'On the',
#  'Around',
#  'So',
#  'There',
#  'Head',
#  'What do you think',
#  'Knees',
#  'High',
#  'Watch',
#  'Two',
#  'On',
#  '—',
#  'Found',
#  "It doesn't",
#  'Performance',
#  'We',
#  'He',
#  'He',
#  'But',
#  'A lot',
#  'Early',
#  'No',
#  'I',
#  'Miss',
#  "That's it.",
#  'I',
#  'Most',
#  'Heart',
#  'You',
#  'Open it',
#  '"',
#  'Learning',
#  'Draw',
#  'In',
#  '!',
#  'They',
#  'Do',
#  'Jane',
#  'I',
#  'People',
#  'Despise',
#  'Seven years.',
#  'Outside',
#  'After',
#  'He',
#  'Tell',
#  'Several',
#  'Is',
#  'Wine merchants',
#  'Talk about',
#  'In',
#  'Gates',
#  'The',
#  'Novel',
#  'Must',
#  'Furnishings',
#  'Where',
#  'The',
#  'Put',
#  'The',
#  'Special Town',
#  'Thought',
#  'When',
#  'I',
#  'Love',
#  'Wait',
#  'To',
#  'Heavy',
#  'Make',
#  'Do you have?',
#  'No',
#  'The',
#  'Get up',
#  'Point.',
#  'I',
#  'Put it in',
#  'Many',
#  '"',
#  'The',
#  'Comfortable',
#  'To',
#  'One time.',
#  'And',
#  'And',
#  'The',
#  'Wife',
#  'Not',
#  '"',
#  'Is',
#  'House',
#  'Such as',
#  'I',
#  'From',
#  'Tower',
#  'Marked',
#  'Past',
#  'Main entrance',
#  'I',
#  'Around',
#  'Candlelight',
#  'God',
#  'Swing',
#  'Widow',
#  'Same',
#  'In',
#  'Teachers',
#  'Also',
#  '"',
#  'To',
#  "That's right",
#  'Cloak',
#  "'m afraid",
#  'From',
#  'She',
#  'I',
#  'Guests',
#  'And',
#  'Early',
#  'Tray',
#  'The',
#  'Special',
#  'Fairfax',
#  'The',
#  'This one',
#  'You',
#  'Family',
#  'But',
#  '"',
#  '"',
#  'Is',
#  'Place',
#  'I',
#  'But',
#  'Lose',
#  'From',
#  'Alone',
#  'Think',
#  'And',
#  'Children',
#  'I',
#  'Hope',
#  'Stay',
#  'The',
#  'The',
#  'The',
#  'Inside',
#  'She',
#  'Locked',
#  'All',
#  'And',
#  'Bleak',
#  'The',
#  "Don't",
#  'Impression',
#  'Now',
#  'Thanksgiving',
#  'No',
#  'Lonely',
#  'When',
#  'Walls',
#  'Room',
#  'Effect',
#  'Also',
#  'Resurrection',
#  'Things',
#  'Be careful',
#  '—',
#  'The',
#  'Allow',
#  'Bar.',
#  'I',
#  'Yes',
#  'Reason',
#  '—',
#  'The',
#  'Disgust',
#  'Pack',
#  'The',
#  'Wear',
#  'Look at it.',
#  'Oak',
#  "That's it.",
#  'Threshold',
#  'The',
#  'Quite a large scale',
#  'Top',
#  'Against',
#  'On',
#  'Such as',
#  'The',
#  'Quiet',
#  'The',
#  'In',
#  'Pan',
#  'The',
#  'Wife',
#  'She',
#  'Ground',
#  'Is',
#  'Unless',
#  'Need',
#  '"',
#  'Of course',
#  'The',
#  'Is',
#  'I',
#  'Distant relative',
#  'Village',
#  'The',
#  'In fact',
#  'All',
#  'The',
#  'County',
#  'This one',
#  'So',
#  'No',
#  'On the',
#  'Look',
#  'Thin',
#  '"',
#  'She',
#  'They',
#  'And',
#  'Too much',
#  'English',
#  'The',
#  'With',
#  'Imitate',
#  'She',
#  'Use',
#  'Use',
#  'French',
#  'Like',
#  'People',
#  'Through',
#  'Rochester',
#  'Sleep',
#  '"',
#  'Morning',
#  'All',
#  'Walked',
#  'The',
#  'Sophia',
#  'A lot',
#  'Speak',
#  'Listen to the habit',
#  'One or two.',
#  'In',
#  'I',
#  'A lot, a lot.',
#  'They',
#  'I',
#  'Arms',
#  'Song',
#  'She',
#  'One',
#  'Feel',
#  'Performance',
#  'At least',
#  'Yes',
#  'To give',
#  'Recite',
#  'Description',
#  '"',
#  'This way,',
#  'No way',
#  'And',
#  'Like',
#  'Together.',
#  'Stay',
#  'United Kingdom',
#  'Mr',
#  'Open',
#  'A few',
#  'Book',
#  'And',
#  'And',
#  'All',
#  'Speak',
#  'To',
#  'Pencil',
#  'Room',
#  'Big',
#  'Window',
#  'Several',
#  'I',
#  'It',
#  'Living room',
#  'The same',
#  'Go inside.',
#  'Eyes',
#  'On the',
#  'And',
#  'Pa',
#  'Also',
#  'I',
#  'People',
#  'Material',
#  'Rush',
#  'Difficult',
#  'Habit',
#  '"',
#  'The',
#  'You',
#  'The',
#  'Get it.',
#  '"',
#  'A lot',
#  '"',
#  'Clear',
#  'In',
#  'No way',
#  'About',
#  'Observation',
#  'But',
#  '—',
#  'Feel',
#  'Way',
#  'Special',
#  "Don't have fun.",
#  'The',
#  'Tree',
#  ';',
#  'Stay',
#  "Chen's story",
#  'Gloom',
#  'Door',
#  'Flowered',
#  'Weird',
#  'Behind',
#  'Is',
#  'I',
#  '"',
#  'Now',
#  'They',
#  '"',
#  'Do you?',
#  'Through',
#  'OK',
#  'The',
#  'Dot',
#  'Also',
#  'The',
#  'Pleasing',
#  'Watching',
#  'Next',
#  'I',
#  'Escalator',
#  'And again',
#  'Castle',
#  'Hear',
#  'Heavy',
#  'A',
#  'But',
#  'Loud',
#  'That',
#  'S & p',
#  'Here',
#  '"',
#  'Fairfax',
#  'Too much',
#  'Without',
#  'Things',
#  'Age',
#  "It's hard to imagine.",
#  'Said',
#  'We',
#  'No',
#  'What do you think',
#  'In',
#  '-',
#  'The',
#  'And',
#  'The',
#  'Care',
#  'Move',
#  'Level',
#  'Progress',
#  'The',
#  'People',
#  'Cold',
#  'They',
#  'No',
#  'Progress',
#  'She',
#  'A',
#  'Walking',
#  'Game',
#  'Roof',
#  'Vision',
#  'The',
#  'Inside',
#  'Also',
#  'The',
#  'Greedy',
#  'Is',
#  'Safety',
#  'A lot',
#  'Heart',
#  'Listening',
#  'Talk about it.',
#  'And',
#  "Let's go",
#  'More',
#  'Resistance',
#  'Man',
#  'They',
#  'We',
#  'They',
#  'Things',
#  'S & p',
#  'Also',
#  'But',
#  'Hands',
#  'Alas',
#  'Quirks',
#  'Make',
#  'All',
#  'Outstanding',
#  'Depicted',
#  'Go on',
#  'To',
#  'Many',
#  'Cold',
#  'A letter.',
#  'Walk',
#  'Small chair',
#  'Storybook',
#  'She',
#  "It's just",
#  'Church',
#  'Away San',
#  'Also',
#  'The',
#  'No',
#  'Baishi',
#  'Bird',
#  'I',
#  'Inside',
#  'Get up',
#  'Fu',
#  '魈',
#  'To',
#  'Immediately',
#  'And',
#  'To',
#  'Mountain',
#  'The',
#  'Clear',
#  'Draw',
#  'Green',
#  'It',
#  'Poe',
#  'The',
#  'Is',
#  'And',
#  'Northern',
#  'In',
#  'Come on.',
#  'A',
#  'It',
#  'The',
#  'Like',
#  'That',
#  'Immediately',
#  'Yes',
#  'This',
#  'Still',
#  '"',
#  'In the middle',
#  'Poe',
#  'It',
#  'Others',
#  'The',
#  'Hurt',
#  'So',
#  'To',
#  'One',
#  'Far',
#  'That one.',
#  'On the way',
#  'Parts',
#  'Heart',
#  'Need',
#  'Bones',
#  'Alas',
#  'See',
#  'Not sure.',
#  ';',
#  'Sessions',
#  'The',
#  'Opening',
#  'Youth',
#  'Reflected',
#  'Resonance',
#  'Right',
#  ';',
#  'To',
#  'Waved',
#  'Is',
#  'He',
#  'The',
#  'It is',
#  'For',
#  'You',
#  'Moon',
#  'Contour',
#  '"',
#  'No',
#  '"',
#  'Servant',
#  'Merino',
#  'He',
#  'He',
#  'He',
#  '"',
#  'Help',
#  '"',
#  'I',
#  'Just.',
#  'But',
#  "I'm scared.",
#  'Got it',
#  'Is',
#  '"',
#  'Hand',
#  'He',
#  'Hard',
#  'Handed it to',
#  'Fast',
#  'Hind legs',
#  'Heather',
#  'Become',
#  'On the',
#  'I',
#  'Passive',
#  'Have',
#  'Strict',
#  'Way',
#  'Horseshoe Sound',
#  'In',
#  'Qinghui',
#  ';',
#  'Inside',
#  'Fu',
#  'Lonely',
#  'All',
#  'Chains',
#  ...]

# %%
starting_tag_count
# Out:
# Counter({'Half': 1,
#          'Go': 3,
#          'Magic': 1,
#          'No': 10,
#          'Do': 4,
#          'The': 73,
#          'On the': 12,
#          'Progress': 1,
#          'I': 58,
#          'The date': 1,
#          'When': 4,
#          'Walked': 1,
#          'Said': 7,
#          'Bread': 1,
#          "Can't": 3,
#          'Knee': 1,
#          '"': 33,
#          'People': 9,
#          'Despise': 1,
#          'Be sure.': 1,
#          'Also': 10,
#          'Public': 1,
#          'You': 11,
#          'Obvious': 1,
#          'To': 14,
#          'Whole': 1,
#          'Stand': 3,
#          'Horse': 2,
#          'Love': 3,
#          'Go inside.': 1,
#          ';': 4,
#          'Yes': 7,
#          'Charges': 1,
#          'Rewards': 1,
#          'Sink': 1,
#          'She': 17,
#          'Moon': 1,
#          'Recognize it.': 1,
#          'We': 3,
#          'Apartments': 1,
#          'Chair': 1,
#          'Do you?': 3,
#          'Forever': 2,
#          'Girl': 1,
#          'Wife': 4,
#          'But': 13,
#          'Jane': 3,
#          'Fact': 1,
#          'A few minutes.': 1,
#          'Exhausted': 1,
#          'Blindly': 1,
#          'Listen': 1,
#          'Beg': 1,
#          'I will': 1,
#          'Slander': 1,
#          'Say,': 1,
#          'Begin': 3,
#          'Think': 4,
#          'Pull': 1,
#          'Sigh': 1,
#          'Just.': 4,
#          'How': 2,
#          'Has': 2,
#          'Iron': 1,
#          'Wait, wait, wait': 1,
#          'Lack': 1,
#          'Right now': 1,
#          'Food': 1,
#          'Take': 1,
#          'Gentle': 1,
#          'Maybe': 1,
#          'Power': 2,
#          'In': 21,
#          'Flow': 1,
#          'Judge': 1,
#          'Spring': 2,
#          'Nature': 1,
#          '!': 2,
#          'Temple': 3,
#          'Told': 1,
#          'Right': 1,
#          'Miss': 4,
#          'By the door.': 1,
#          'Hear': 3,
#          'One': 9,
#          'A': 5,
#          'It': 2,
#          'Combustion': 1,
#          'He': 7,
#          '·': 1,
#          'Complete clarification': 1,
#          'This way,': 2,
#          'Pay': 1,
#          'And': 18,
#          'Allow': 2,
#          'Hut': 1,
#          'Reverie': 1,
#          'In this way,': 1,
#          'Mature': 1,
#          'Ivy': 1,
#          'Fluent': 1,
#          'Strong': 1,
#          'Head': 1,
#          'Hard': 1,
#          'Raging': 1,
#          'Game': 1,
#          'Than': 2,
#          'Three colors': 1,
#          'Shade': 1,
#          'That': 8,
#          'Until': 1,
#          'Rush': 1,
#          'As for': 1,
#          'Quiet': 1,
#          'Get up': 2,
#          'Male': 1,
#          'Flowered': 1,
#          'Golden': 1,
#          'Always': 2,
#          'Put': 3,
#          'Another thing.': 1,
#          "I've got your": 1,
#          'Girls': 1,
#          'All': 4,
#          'Teachers': 1,
#          'Blanket': 1,
#          'Dean': 1,
#          'Distribution': 1,
#          'such as lin': 1,
#          'Smell': 1,
#          'Wonderful': 1,
#          'Where': 1,
#          'Lowood': 1,
#          'Is': 19,
#          'Less': 1,
#          'These': 1,
#          'Look': 2,
#          'What the': 6,
#          'Harmonious': 1,
#          'Many': 1,
#          'Affection': 1,
#          'School': 4,
#          'Get': 3,
#          'Occasion': 1,
#          'Can not see clearly': 1,
#          'Get it.': 2,
#          'In the forest': 1,
#          'Pony': 1,
#          'Evening': 1,
#          'Dig it.': 1,
#          'A while': 1,
#          'Sky': 2,
#          'Connotation': 1,
#          'Rickety': 1,
#          'Close the door': 1,
#          'Mr': 3,
#          'Doubt': 1,
#          'Sentence': 1,
#          'Drop': 1,
#          'So': 8,
#          'Aisle': 2,
#          'Get close': 1,
#          'Be': 3,
#          'Sound': 1,
#          'From': 2,
#          'Stuffy': 1,
#          'Close': 2,
#          'On': 1,
#          'Body': 1,
#          'Hangings': 1,
#          'Fear': 1,
#          'Calm': 1,
#          'Thin': 1,
#          'Sick.': 1,
#          'Come': 1,
#          'Softly': 1,
#          'Photo': 1,
#          'Go on': 1,
#          'Sad': 1,
#          'Disaster': 1,
#          'Believe': 2,
#          'Creator': 1,
#          'Die': 1,
#          'Oh, God': 1,
#          'After': 1,
#          'Universal': 1,
#          'Ah, yes.': 3,
#          'Have': 4,
#          'The one.': 2,
#          'Shoulder': 2,
#          'Brock': 1,
#          'Marble': 2,
#          '-': 3,
#          'Life': 3,
#          'Only': 2,
#          'Ground': 3,
#          'This': 6,
#          'Benefit': 1,
#          'Make': 3,
#          'Potential': 1,
#          'Compassion': 1,
#          'Happy': 2,
#          'And again': 3,
#          'As': 1,
#          'Communication': 1,
#          'Partner': 1,
#          'Match': 1,
#          'No longer': 2,
#          'Very': 3,
#          'Step in': 1,
#          'Thinking': 1,
#          'Gap': 1,
#          "Let's say": 1,
#          'Feel': 1,
#          'The mountains are up and down': 1,
#          'Mountain': 1,
#          'World': 1,
#          'Know': 2,
#          'Suddenly': 2,
#          'Into': 3,
#          'New': 4,
#          'Available.': 1,
#          'Just': 1,
#          'Twang': 1,
#          'Exempt': 1,
#          'Must': 2,
#          'Because': 2,
#          "It's a waste": 1,
#          'Here': 1,
#          'Found it': 1,
#          'How can I do that': 1,
#          'Had': 2,
#          'Then': 2,
#          'What about?': 1,
#          'Same': 1,
#          'Send to': 1,
#          'Teaching': 1,
#          "It's just": 1,
#          '.': 3,
#          'Principal': 1,
#          'Store': 1,
#          'Week': 1,
#          'Get on the road': 1,
#          'Letter': 2,
#          'Put it on.': 1,
#          'Put it in': 1,
#          'Homework': 1,
#          'Other': 2,
#          'Effect': 1,
#          'Abbreviation': 1,
#          'Please': 1,
#          'Near': 1,
#          "Let's go": 1,
#          'Legitimate': 1,
#          'Old fashioned': 1,
#          'Place': 2,
#          'London': 2,
#          'Kurt': 1,
#          'Better': 1,
#          'Candlestick': 1,
#          'For': 2,
#          'Of course': 1,
#          'Transaction': 1,
#          'Enough': 1,
#          'Rope': 1,
#          'There': 1,
#          'One moment.': 4,
#          'Now': 1,
#          'Quasi -': 1,
#          'Living room': 1,
#          '—': 3,
#          'Hand': 1,
#          'Women': 1,
#          "Happy can't help itself": 1,
#          'Little': 1,
#          'Bobby': 1,
#          'They': 3,
#          'Good': 1,
#          'Too': 1,
#          'Not good': 1,
#          'Dividends': 1,
#          'Lips': 1,
#          'Completely': 2,
#          'Children': 1,
#          'Never.': 1,
#          'Reed': 1,
#          'With': 3,
#          'Pieces': 1,
#          'Pour down': 2,
#          'Foreign': 1,
#          'Later': 1,
#          'Hours': 1,
#          'Hurst': 1,
#          'Imagine': 1,
#          'The same': 2,
#          'By': 3,
#          'Inside': 3,
#          'Clock': 1,
#          'One stop.': 1,
#          'Anxious': 1,
#          'Sang': 5,
#          'Side': 2,
#          'Uneasy': 1,
#          'Call': 3,
#          'Leather hand barrel': 1,
#          'Off': 1,
#          'Carriage': 1,
#          'Fairfax': 1,
#          'End': 1,
#          'Happen': 1,
#          'Put it down': 1,
#          'Quite': 1,
#          'Area': 1,
#          'Field': 3,
#          'Eyes': 1,
#          'One.': 1,
#          'Wearing': 1,
#          'Feet': 1,
#          "Today's people": 1,
#          'Dear': 1,
#          'Sit': 1,
#          'Frozen': 1,
#          'Besides': 1,
#          'Ears': 1,
#          'More': 1,
#          'Teach': 1,
#          'Lonely': 1,
#          'Servant': 1,
#          'Poor': 1,
#          'Day': 1,
#          "It's too late": 1,
#          'Those': 1,
#          'Next': 1,
#          'High': 1,
#          'Church': 1,
#          'Finally': 1,
#          'Efforts': 1,
#          'Room': 2,
#          'Pu': 1,
#          'Small': 1,
#          'Abnormal': 1,
#          'A little bit of a': 1,
#          'Desire': 1,
#          'Instead': 1,
#          'Situation': 1,
#          'Wish': 1,
#          "It's logical.": 1,
#          'Although': 2,
#          'Neat': 1,
#          'Stairs': 1,
#          'Chest care': 1,
#          'Ceiling': 1,
#          'Magnificent': 1,
#          'Battlements': 2,
#          'Dwarf Hedges': 1,
#          'Broad': 1,
#          'Often': 2,
#          'Everyone': 1,
#          'At least': 1,
#          "It's nothing to do with me": 1,
#          'Expect': 1,
#          'Guardian': 1,
#          'Big': 1,
#          'Kind': 1,
#          'Condescension': 1,
#          'Facial features': 1,
#          'But it is.': 1,
#          'French': 1,
#          'Fortunately': 1,
#          'Lady': 2,
#          'Teacher': 1,
#          'Myself': 1,
#          'Road': 2,
#          'OK': 1,
#          'On board': 1,
#          'Days': 1,
#          'Plate': 1,
#          'Go hang out.': 1,
#          'And also': 2,
#          'Mom': 1,
#          'Curls': 1,
#          'Waiter': 1,
#          'Up and up': 1,
#          'Innocent': 1,
#          'Recite': 1,
#          'First': 1,
#          'Experienced': 1,
#          "That's it.": 1,
#          'Above': 1,
#          'Story': 2,
#          'Globe': 1,
#          'Habit': 1,
#          'Purple': 1,
#          'Color': 1,
#          'Spar': 1,
#          'A little.': 2,
#          'Like': 2,
#          'Hanging': 1,
#          'Leaves': 1,
#          'Out': 2,
#          'Material': 1,
#          'Raise': 1,
#          'Long': 1,
#          'See': 1,
#          'Laugh': 1,
#          'Two': 1,
#          'Depicted': 1,
#          "There's nothing else.": 1,
#          'Understand': 1,
#          'Way': 1,
#          'Once': 1,
#          'Projected': 1,
#          'Wear': 1,
#          'Quaint': 1,
#          'Shut down': 1,
#          'Strange': 1,
#          'Things': 1,
#          'Small room': 2,
#          'Wandering': 1,
#          "I've never heard of it.": 1,
#          'Sleep': 1,
#          'Skylight': 1,
#          'Lawn': 1,
#          'Brown': 1,
#          'Blue': 2,
#          'Woods': 1,
#          'Laughter': 3,
#          'Rang': 1,
#          'Poe': 1,
#          'Who': 1,
#          'Shouting': 1,
#          'Thirty': 1,
#          'Remember': 1,
#          'When it was,': 1,
#          'Aspects': 1,
#          'Tame': 1,
#          'Special': 1,
#          'Language': 1,
#          'Maintain': 1,
#          'Even image': 1,
#          'Lie': 1,
#          'Isolated': 1,
#          'Adele': 2,
#          'Any': 1,
#          'At the same time,': 1,
#          'If': 1,
#          'Strict': 1,
#          'Narrow heart': 1,
#          'Beyond': 1,
#          'To this end': 1,
#          'A few': 1,
#          'Cause': 1,
#          'Opening': 1,
#          'On the house': 1,
#          'Narrative': 1,
#          'October': 1,
#          'Lu': 1,
#          'To give': 1,
#          'Taste': 1,
#          'Reply': 1,
#          'Footsteps': 1,
#          'Minutes': 1,
#          'One mile.': 1,
#          'Stay': 1,
#          'Evergreen': 1,
#          'Silent': 1,
#          "It's like.": 1,
#          'Top knot': 1,
#          'Nest': 1,
#          'Go.': 1,
#          'Bright': 1,
#          'Apart': 1,
#          'Too much': 2,
#          'Wind': 1,
#          "It's true.": 1,
#          'Thick ink': 1,
#          'Mountains': 1,
#          "Don't move.": 1,
#          'Memory': 1,
#          'Condensing': 1,
#          'Elves': 1,
#          'Magic Gas': 1,
#          'Cover': 2,
#          'On the way': 1,
#          'Yelling': 1,
#          'Help': 1,
#          'Right away': 1,
#          'Horse hiss': 1,
#          'Bend down.': 1,
#          'Pain': 1,
#          'Falling': 1,
#          'Clear': 1,
#          'About': 1,
#          'Gentleman': 1,
#          'Men': 1,
#          'Avoid': 1,
#          'Let': 1,
#          'That one': 1,
#          'Never': 1,
#          'Tell': 1,
#          'Cloak': 1,
#          'Obey': 1,
#          'Pi': 1,
#          'Mohammed': 1,
#          'Catch': 1,
#          'Show': 1,
#          'Haimura': 1,
#          'Home': 1,
#          'Again': 1,
#          'Threshold': 1,
#          'Throw': 1,
#          'Comparable': 1,
#          'Natural': 1,
#          'Building': 1,
#          'Profound': 1,
#          'Stars': 1,
#          'Light up': 1,
#          'Shoot it out.': 1,
#          'Together.': 1,
#          'Follow': 1,
#          'Fire': 1,
#          'Tone': 1,
#          'Railings': 1})

# %% [markdown]
# Let's convert word frequencies by POS tag to probabilities by dividing by the total number of words per POS tag, yielding the `distribution` of words.
#
# We'll define HMM emission probabilities using that `distribution`.

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    tag_emissions = DiscreteDistribution(distribution)
#     print(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %%
distribution
# Out:
# {'并不需要': 1.0}

# %% [markdown]
# `to_pass_states` yields the probability distribution of words per POS tag:

# %%
# to_pass_states

# %% [markdown]
# Let's add states to our model:

# %%
hmm_model.add_states()

# %% [markdown]
# The start probability for each tag is how many times it is a sentence-starting POS tag divided by its total count. We build the starting transitions for our HMM model:

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %% [markdown]
# The end probability for each tag is how many times it is a sentence-ending POS tag divided by its total count. We build the ending transitions for our HMM model:

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %% [markdown]
# We now add the transition probabilities for our model, which uses our POS bigrams to enumerate what the probabilities are for transiting from one POS tag to another.

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
       if(tag_state.name,next_tag_state.name) in tag_bigrams.keys():
          hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %% [markdown]
# We *bake* our model:

# %%
hmm_model.bake()

# %% [markdown]
# We can now evaluate the accuracy of our HMM model and compare it to our BOW model:

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# training accuracy basic hmm model: 0.12%
# testing accuracy basic hmm model: 0.72%

# %% [markdown]
# Here's a decoding example:

# %%
for key in data.testing_set.keys[1:]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
  #  print(simplify_decoding(data.sentences[key].words, hmm_model))
   # print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: 8980
#
# Sentence: ('手', '叫', '道', '我', '定睛一看', '见', '是', '一个', '少妇', '穿戴', '得', '像', '一个', '衣着', '讲究', '的', '仆人', '一', '付', '已婚')
#
# Predicted labels:
# -----------------
# ('Hand', 'Call', 'Road', 'I', 'A look at it.', 'See', 'Is', 'One', 'Woman', 'Wear', 'Get it.', 'Like', 'One', 'Clothes', 'Pay attention', 'The', 'Servant', 'One', 'Pay', 'Married')
#
#
# Sentence Key: 13780
#
# Sentence: ('另', '一个', '地方', '的', '小', '床上', '它', '像', '个', '架子', '我', '差点', '跌下来', '小姐', '你', '叫', '什么', '名字', '”', '“')
#
# Predicted labels:
# -----------------
# ('Other', 'One', 'Place', 'The', 'Small', 'Bed.', 'It', 'Like', 'A', 'Shelf', 'I', 'Almost', 'Falling down', 'Miss', 'You', 'Call', 'What the', 'Name', '"', '"')
#
#
# Sentence Key: 17860
#
# Sentence: ('城垛', '的', '灰色', '府第', '是', '低', '处', '溪谷', '中', '的', '主要', '景物', '树林', '和', '白', '嘴鸦', '黑', '魈', '魈', '的')
#
# Predicted labels:
# -----------------
# ('Battlements', 'The', 'Grey', 'Fudi', 'Is', 'Low', 'Where', 'Valley', 'In', 'The', 'Main', 'Scenery', 'Woods', 'And', 'White', 'Crow', 'Black', '魈', '魈', 'The')
#
#
# Sentence Key: 8180
#
# Sentence: ('缩写', 'F', '．', '我', '拆开', '信封', '发现', '内容', '十分', '简单', '“', '如', '上周四', '在', '郡', '先驱报', '上', '登广告', '的', 'J')
#
# Predicted labels:
# -----------------
# ('Abbreviation', 'F', '.', 'I', 'Apart', 'Envelope', 'Found', 'Content', 'Very', 'Simple', '"', 'Such as', 'Last Thursday', 'In', 'County', 'Herald', 'On', 'Advertising', 'The', 'J')
#
#
# Sentence Key: 4740
#
# Sentence: ('确实', '存在', '的话', '我', '感到', '一阵', '恐怖', '一种', '今人', '震颤', '的', '悲哀', '随后', '是', '一种', '愿望', '一种', '要', '见', '她')
#
# Predicted labels:
# -----------------
# ('Do', 'Exist', 'Words', 'I', 'Feel', 'A', 'Terror', 'A', "Today's people", 'Tremor', 'The', 'Sad', 'Then', 'Is', 'A', 'Wish', 'A', 'To', 'See', 'She')
#
#
# Sentence Key: 19000
#
# Sentence: ('向', '他', '发问', '但是', '这位', '赶路', '人', '的', '皱眉', '和', '粗犷', '却', '使', '我', '坦然自若', '因此', '当', '他', '挥手', '叫')
#
# Predicted labels:
# -----------------
# ('To', 'He', 'Ask', 'But', 'The', 'On the way', 'People', 'The', 'Frown', 'And', 'Rough', 'But', 'Make', 'I', 'Be open-minded', 'So', 'When', 'He', 'Waved', 'Call')
#
#
# Sentence Key: 17840
#
# Sentence: ('上结', '一层', '薄冰', '这', '是', '寒冷', '的', '明证', '从', '我', '落座', '的', '地方', '外', '以', '俯视', '桑', '菲尔德', '府', '建有')
#
# Predicted labels:
# -----------------
# ('Top knot', 'One floor', 'Thin ice', 'This', 'Is', 'Cold', 'The', 'Evinced', 'From', 'I', 'Seated', 'The', 'Place', 'Outside', 'To', 'Overlooking', 'Sang', 'Field', 'Fu', 'Built with')
#
#
# Sentence Key: 17820
#
# Sentence: ('尽管', '天寒地冻', '却', '并', '不', '觉得', '很', '冷', '几天', '前', '已经', '融化', '泛滥', '的', '小河', '现在', '又', '冻结', '起来', '堤坝')
#
# Predicted labels:
# -----------------
# ('Although', 'Cold', 'But', 'And', 'No', 'Think', 'Is', 'Cold', 'Few days', 'Ago', 'Have', 'Melt', 'Flood', 'The', 'River', 'Right now', 'And again', 'Frozen', 'Get up', 'Dam')
#
#
# Sentence Key: 10900
#
# Sentence: ('菲尔德', '不远', '”', '我', '再次', '往', '外', '眺望', '我们', '正', '经过', '一个', '教堂', '我', '看见', '低矮', '宽阔', '的', '塔', '映着')
#
# Predicted labels:
# -----------------
# ('Field', "It's not far", '"', 'I', 'Again', 'To', 'Outside', 'Look', 'We', 'Is', 'After', 'One', 'Church', 'I', 'See', 'Low', 'Broad', 'The', 'Tower', "It's on.")
#
#
# Sentence Key: 1440
#
# Sentence: ('我会', '写信给', '他', '的', '要是', '他', '的', '答复', '同', '你', '说', '的', '相符', '我们', '会', '公开', '澄清', '对', '你', '的')
#
# Predicted labels:
# -----------------
# ('I will', 'Write to', 'He', 'The', 'If', 'He', 'The', 'Reply', 'With', 'You', 'Said', 'The', 'Match', 'We', 'Yes', 'Public', 'Clarify', 'Right', 'You', 'The')
#
#
# Sentence Key: 16340
#
# Sentence: ('什么', '幽灵', '比', '她', '更', '缺少', '传奇色彩', '更', '不', '像', '鬼魂', '“', '太', '闹', '格雷斯', '”', '费尔法克斯', '太太', '说', '“')
#
# Predicted labels:
# -----------------
# ('What the', 'Ghost', 'Than', 'She', 'More', 'Lack', 'Legendary', 'More', 'No', 'Like', 'Ghost', '"', 'Too', 'Noisy', 'Grace', '"', 'Fairfax', 'Wife', 'Said', '"')
#
#
# Sentence Key: 7620
#
# Sentence: ('寄往', '那里', '邮局', '的', 'J', '.', 'E', '.', '信', '寄出', '后', '一个', '星期', '你', '可以', '去', '查询', '要是', '来', '回音')
#
# Predicted labels:
# -----------------
# ('Send to', 'There', 'Post office', 'The', 'J', '.', 'E', '.', 'Letter', 'Send', 'After', 'One', 'Week', 'You', 'OK', 'To', 'Inquire', 'If', 'To', 'Echo')
#
#
# Sentence Key: 12340
#
# Sentence: ('那', '东西', '不是', '降临', '在', '这', '一天', '或是', '这个', '月', '而是', '在', '不', '确定', '的', '未来', '我', '起身', '小心', '穿戴')
#
# Predicted labels:
# -----------------
# ('That', 'Things', 'No', 'Come', 'In', 'This', 'One day', 'Or', 'This one', 'Month', 'But', 'In', 'No', 'Are you sure', 'The', 'Future', 'I', 'Up', 'Be careful', 'Wear')
#
#
# Sentence Key: 4380
#
# Sentence: ('晚间', '这个', '时候', '请', '贝茨', '先生', '来', '她', '先进', '屋', '我', '在', '外面', '呆', '几分钟', '把', '才', '从', '森林', '里')
#
# Predicted labels:
# -----------------
# ('Evening', 'This one', 'When', 'Please', 'Bates', 'Mr', 'To', 'She', 'Advanced', 'House', 'I', 'In', 'Outside', 'Stay', 'A few minutes.', 'Put', "It's just", 'From', 'Forest', 'Inside')
#
#
# Sentence Key: 18420
#
# Sentence: ('叫喊', '和', '咔啦啦啦', '翻滚', '落地', '的', '声响', '引起', '我', '的', '注意', '人', '和', '马都己', '倒地', '是', '在', '路', '当中', '光滑')
#
# Predicted labels:
# -----------------
# ('Yelling', 'And', "It's clicking.", 'Rolling', 'Landing', 'The', 'Sound', 'Cause', 'I', 'The', 'Attention', 'People', 'And', 'Maduhimi', 'Fell', 'Is', 'In', 'Lu', 'In the middle', 'Smooth')
#
#
# Sentence Key: 8340
#
# Sentence: ('我', '想象', '她', '穿着', '黑色', '的', '长袍', '戴', '着', '寡妇', '帽', '也许', '索然无味', '但', '井', '不失为', '一位', '典型', '的', '英国')
#
# Predicted labels:
# -----------------
# ('I', 'Imagine', 'She', 'Wearing', 'Black', 'The', 'Robe', 'Wear', 'On the', 'Widow', 'Cap', 'Maybe', 'Dull', 'But', 'Well', "It's not a", 'A', 'Typical', 'The', 'United Kingdom')
#
#
# Sentence Key: 12380
#
# Sentence: ('渴求', '整洁', '依然', '是', '我', '的', '天性', '习惯', '上', '我', '并', '不', '无视', '外表', '不', '注意', '自己', '留下', '的', '印象')
#
# Predicted labels:
# -----------------
# ('Desire', 'Neat', 'Still', 'Is', 'I', 'The', 'Nature', 'Habit', 'On', 'I', 'And', 'No', 'Ignore', 'Appearance', 'No', 'Attention', 'Myself', 'Left', 'The', 'Impression')
#
#
# Sentence Key: 8260
#
# Sentence: ('附近', '桑', '菲尔德', '费尔法克斯', '太太', '收', '”', '我', '把', '文件', '细看', '很', '久', '字体', '很', '老式', '笔迹', '不大', '稳', '像是')
#
# Predicted labels:
# -----------------
# ('Near', 'Sang', 'Field', 'Fairfax', 'Wife', 'Receive', '"', 'I', 'Put', 'File', 'Take a closer look', 'Is', 'Long', 'Font', 'Is', 'Old - fashioned', 'Handwriting', 'Little', 'Stability', "It's like.")
#
#
# Sentence Key: 14900
#
# Sentence: ('叶子', '与', '它', '恰', '成', '对比', '的', '是', '天花板', '下', '闪烁着', '绯红', '的', '睡椅', '和', '床榻', '灰白色', '的', '帕', '罗斯岛')
#
# Predicted labels:
# -----------------
# ('Leaves', 'And', 'It', 'Just', 'Yes', 'Contrast', 'The', 'Is', 'Ceiling', 'Next', 'Flashing', 'Crimson', 'The', 'Sleeping chair', 'And', 'Bed', 'Grey-white', 'The', 'Pa', 'Ross Island')
#
#
# Sentence Key: 560
#
# Sentence: ('不会', '没有', '朋友', '”', '“', '不', '我', '明白', '我', '觉得', '自己', '不错', '但', '这', '还', '不够', '要是', '别人', '不', '爱')
#
# Predicted labels:
# -----------------
# ('No', 'No', 'Friends', '"', '"', 'No', 'I', 'Got it', 'I', 'Think', 'Myself', 'Not bad', 'But', 'This', 'Also', 'Enough', 'If', 'Others', 'No', 'Love')
#
#
# Sentence Key: 6640
#
# Sentence: ('但是', '命运', '化作', '牧师', '内史密斯', '把', '我', '和', '坦普尔', '小组', '分开', '我', '见', '她', '身着', '行装', '在', '婚礼', '后', '不久')
#
# Predicted labels:
# -----------------
# ('But', 'Fate', 'Into', 'Priest', 'Naismith', 'Put', 'I', 'And', 'Temple', 'Group', 'Separate', 'I', 'See', 'She', 'Wearing', 'Up', 'In', 'Wedding', 'After', 'Soon')
#
#
# Sentence Key: 1820
#
# Sentence: ('欠缺', '”', '她', '邀', '海伦', '与', '我', '凑近', '桌子', '在', '我们', '俩', '面前', '各', '放', '一杯', '茶', '和', '一小片', '可口')
#
# Predicted labels:
# -----------------
# ('Lack', '"', 'She', 'Invited', 'Helen', 'And', 'I', 'Closer', 'Table', 'In', 'We', 'Two', 'Front', 'Each', 'Put', 'One cup.', 'Tea', 'And', 'A small piece.', 'Delicious')
#
#
# Sentence Key: 14460
#
# Sentence: ('倒', '又', '回去', '我', '从来', '没有', '见', '过', '他', '”', '吃', '早饭', '阿黛勒', '和', '我', '进', '图书室', '罗切斯特', '先生', '好像')
#
# Predicted labels:
# -----------------
# ('Pour down', 'And again', 'Get back', 'I', 'Never', 'No', 'See', 'Too much', 'He', '"', 'Eat', 'Breakfast', 'Adele', 'And', 'I', 'Into', 'Library', 'Rochester', 'Mr', 'It seems like')
#
#
# Sentence Key: 16160
#
# Sentence: ('谁', '呀', '”', '“', '很', '可能', '是', '些', '仆人', '”', '她', '回答', '说', '“', '也许', '是', '格雷斯', '·', '普尔', '”')
#
# Predicted labels:
# -----------------
# ('Who', 'Oh, yes.', '"', '"', 'Is', 'possible', 'Is', 'Some', 'Servant', '"', 'She', 'Reply', 'Said', '"', 'Maybe', 'Is', 'Grace', '·', 'S & p', '"')
#
#
# Sentence Key: 15580
#
# Sentence: ('关闭', '；', '有', '的', '挂', '着', '古老', '的', '英国', '绣花', '帐幔', '上面', '满布', '各类', '绣花', '有', '奇怪', '的', '花', '更')
#
# Predicted labels:
# -----------------
# ('Shut down', ';', 'Yes', 'The', 'Hanging', 'On the', 'Old', 'The', 'United Kingdom', 'Embroidery', 'Accounts', 'Above', 'Full cloth', 'Various', 'Embroidery', 'Yes', 'Strange', 'The', 'Flowered', 'More')
#
#
# Sentence Key: 19060
#
# Sentence: ('我', '而', '在', '这', '之前', '他', '几乎', '没有', '朝', '我', '的', '方向', '看过', '“', '我', '觉得', '你', '自己', '该', '回家')
#
# Predicted labels:
# -----------------
# ('I', 'And', 'In', 'This', 'Before', 'He', 'Almost', 'No', 'Towards', 'I', 'The', 'Direction', "I've seen it", '"', 'I', 'Think', 'You', 'Myself', 'The', 'Go home')
#
#
# Sentence Key: 1720
#
# Sentence: ('“', '不能', '再', '拿', '点', '面包', '和', '黄油', '来', '吗', '这', '不够', '三个', '人', '吃', '呀', '”', '巴巴拉', '走', '出去')
#
# Predicted labels:
# -----------------
# ('"', 'No', 'And again', 'Take', 'Point', 'Bread', 'And', 'Butter', 'To', 'Do you?', 'This', 'Enough', 'Three', 'People', 'Eat', 'Oh, yes.', '"', 'Barbara', 'Go', 'Get out')
#
#
# Sentence Key: 18960
#
# Sentence: ('避', '之', '不迭', '如果', '这位', '陌生人', '在', '我', '同', '他', '说话', '时', '微笑', '一下', '并且', '对', '我', '和和气气', '；', '如果')
#
# Predicted labels:
# -----------------
# ('Avoid', 'The', "It doesn't overlap.", 'If', 'The', 'Stranger', 'In', 'I', 'With', 'He', 'Speak', 'When', 'Smile', 'One moment.', 'And', 'Right', 'I', 'Agreeable', ';', 'If')
#
#
# Sentence Key: 7960
#
# Sentence: ('是', '位', '老妇人', '鼻梁', '上架', '着', '角质', '眼镜', '手上', '戴', '着', '黑色', '露指', '手套', '“', '有', '写给', 'J', '.', 'E')
#
# Predicted labels:
# -----------------
# ('Is', 'Bit', 'Old woman', 'Nose', 'Shelves', 'On the', '角质', 'Glasses', 'Hands.', 'Wear', 'On the', 'Black', 'Dew finger', 'Gloves', '"', 'Yes', 'To', 'J', '.', 'E')
#
#
# Sentence Key: 12260
#
# Sentence: ('小巧', '而', '明亮', '眼前', '的', '情景', '使', '我', '精神', '为之一振', '外在', '的', '东西', '对', '年轻人', '往往', '有', '很大', '影响', '我')
#
# Predicted labels:
# -----------------
# ('Small', 'And', 'Bright', 'Eyes', 'The', 'Scene', 'Make', 'I', 'Spirit', 'For one of the vibration', 'External', 'The', 'Things', 'Right', 'Young man', 'Often', 'Yes', "It's big.", 'Effect', 'I')
#
#
# Sentence Key: 5120
#
# Sentence: ('她', '已', '被叫', '到', '热病', '病室', '看望', '一个', '昏迷不醒', '的', '病人', '我', '往前走', '去', '随后', '在', '小床', '旁边', '停下来', '我')
#
# Predicted labels:
# -----------------
# ('She', 'Has', 'Called', 'To', 'Fever', 'Ward', 'See', 'One', 'Unconscious', 'The', 'Patients', 'I', 'Go ahead.', 'To', 'Then', 'In', 'Small bed', 'Next', 'Stop it', 'I')
#
#
# Sentence Key: 2620
#
# Sentence: ('彻底澄清', '教师', '们', '随后', '同', '我', '握手', '吻', '我', '一阵', '欢悦', '的', '低语', '迥荡', '在', '我', '同伴', '的', '队伍', '之中')
#
# Predicted labels:
# -----------------
# ('Complete clarification', 'Teachers', 'We', 'Then', 'With', 'I', 'Shake hands', 'Kiss', 'I', 'A', 'Joyous', 'The', 'Whisper', "It's very different.", 'In', 'I', 'Companion', 'The', 'Team', 'In the middle')
#
#
# Sentence Key: 13480
#
# Sentence: ('是', '外国人', '吗', '”', '我', '听到', '他们', '讲', '法语', '便', '吃惊', '地', '问道', '“', '保姆', '是', '个', '外国人', '而', '阿德拉')
#
# Predicted labels:
# -----------------
# ('Is', 'Foreigners', 'Do you?', '"', 'I', 'Hear', 'They', 'Speak', 'French', 'Poe', 'Surprised', 'Ground', 'Asked', '"', 'Nanny', 'Is', 'A', 'Foreigners', 'And', 'Adela')
#
#
# Sentence Key: 14860
#
# Sentence: ('但', '它', '不过', '是', '一个', '漂亮', '的', '客厅', '和', '里面', '成套', '的', '一间', '闺房', '两间', '房子', '都', '铺', '着', '白色')
#
# Predicted labels:
# -----------------
# ('But', 'It', 'But', 'Is', 'One', 'Pretty', 'The', 'Living room', 'And', 'Inside', 'Complete sets', 'The', 'One', 'Boudoir', 'Two', 'House', 'All', 'Pu', 'On the', 'White')
#
#
# Sentence Key: 10640
#
# Sentence: ('马车', '上', '一时', '浮想联翩', '“', '我', '估计', '”', '我', '想', '道', '“', '从', '朴实', '的', '仆人', '和', '马车', '来', '判断')
#
# Predicted labels:
# -----------------
# ('Carriage', 'On', 'For a moment', 'Imagination', '"', 'I', 'Estimation', '"', 'I', 'Think', 'Road', '"', 'From', 'Simple', 'The', 'Servant', 'And', 'Carriage', 'To', 'Judge')
#
#
# Sentence Key: 12780
#
# Sentence: ('显得', '很', '凸出', '它', '的', '居住者', '正在', '边房', '呱呱', '叫个不停', '飞越', '草坪', '和', '庭园', '落到', '一块', '大', '草地', '上', '一道')
#
# Predicted labels:
# -----------------
# ('Look', 'Is', 'Protruding', 'It', 'The', 'Occupants', 'Is', 'Side room', 'Quack', 'Call it non-stop.', 'Fly', 'Lawn', 'And', 'Garden', 'Falling to', 'A', 'Big', 'Grass', 'On', 'A')
#
#
# Sentence Key: 9160
#
# Sentence: ('他们', '的', '事情', '统统', '都', '告诉', '我', '贝茜', '不过', '先', '坐下', '来', '还有', '鲍比', '过来', '坐在', '我', '的', '膝头', '上')
#
# Predicted labels:
# -----------------
# ('They', 'The', 'Things', 'All', 'All', 'Tell', 'I', 'Bessie', 'But', 'First', 'Sit down', 'To', 'And also', 'Bobby', 'Come here', 'Sitting in the', 'I', 'The', 'Knees', 'On')
#
#
# Sentence Key: 16620
#
# Sentence: ('语', '她', '想', '讨人喜欢', '的', '努力', '反过来', '也', '多少', '激起', '我', '对', '她', '的', '爱恋', '使', '我们', '两', '人', '之间')
#
# Predicted labels:
# -----------------
# ('Language', 'She', 'Think', "It's pleasing.", 'The', 'Efforts', 'Turn', 'Also', 'How much', 'Stirred', 'I', 'Right', 'She', 'The', 'Love', 'Make', 'We', 'Two', 'People', 'Between')
#
#
# Sentence Key: 220
#
# Sentence: ('走过', '空空荡荡', '的', '长', '房间', '她', '给', '我', '端', '来', '咖啡', '和', '面包', '“', '来', '吃', '点', '东西', '”', '她')
#
# Predicted labels:
# -----------------
# ('Walked', 'Empty', 'The', 'Long', 'Room', 'She', 'To give', 'I', 'End', 'To', 'Coffee', 'And', 'Bread', '"', 'To', 'Eat', 'Point', 'Things', '"', 'She')
#
#
# Sentence Key: 9320
#
# Sentence: ('是', '吵架', '”', '“', '那么', '约翰', '·', '里德', '怎么样', '”', '“', '啊', '他', '辜负', '他', '妈妈', '的', '希望', '表现', '并')
#
# Predicted labels:
# -----------------
# ('Is', 'Fighting', '"', '"', 'So', 'John', '·', 'Reed', 'What do you think', '"', '"', 'Ah, yes.', 'He', 'Failed', 'He', 'Mom', 'The', 'Hope', 'Performance', 'And')
#
#
# Sentence Key: 14660
#
# Sentence: ('太太', '叫住', '我', '“', '我', '想', '你', '上午', '的', '课', '结束', '吧', '”', '她', '说', '她', '正在', '一个', '房间', '里')
#
# Predicted labels:
# -----------------
# ('Wife', 'Stop it.', 'I', '"', 'I', 'Think', 'You', 'Morning', 'The', 'Class', 'End', "Let's do it", '"', 'She', 'Said', 'She', 'Is', 'One', 'Room', 'Inside')
#
#
# Sentence Key: 17380
#
# Sentence: ('开口', '但', '她', '似乎', '是', '个', '少言寡语', '的', '人', '回答', '往往', '只有', '一两个', '字', '终于', '使', '我', '意兴', '全', '无')
#
# Predicted labels:
# -----------------
# ('Opening', 'But', 'She', 'Seems', 'Is', 'A', 'Less talk', 'The', 'People', 'Reply', 'Often', 'Only', 'One or two.', 'Word', 'Finally', 'Make', 'I', 'Yixing', 'All', 'No')
#
#
# Sentence Key: 8380
#
# Sentence: ('地方', '尽管', '我', '无力', '设想', '这幢', '房子', '的', '确切', '结构', '×', '×', '郡', '的', '米尔科', '特', '我', '重温', '记忆', '中')
#
# Predicted labels:
# -----------------
# ('Place', 'Although', 'I', 'Weakness', 'Idea', 'This one', 'House', 'The', 'Exact', 'Structure', 's', 's', 'County', 'The', 'Milko', 'Special', 'I', 'Review', 'Memory', 'In')
#
#
# Sentence Key: 4040
#
# Sentence: ('的', '交往', '感到', '厌倦', '当然', '我', '所', '提及', '的', '玛丽', '·', '安', '·', '威尔逊', '要', '逊于', '我', '的', '第一位', '相识')
#
# Predicted labels:
# -----------------
# ('The', 'Communication', 'Feel', 'Tired', 'Of course', 'I', 'The', 'Mentioned', 'The', 'Mary', '·', 'An', '·', 'Wilson', 'To', 'Inferior to', 'I', 'The', 'First', 'Acquaintance')
#
#
# Sentence Key: 6120
#
# Sentence: ('一生', '的', '最初', '十年', '差不多', '花', '十章', '来', '描写', '但', '这', '不是', '一部', '正', '正规', '规的', '自传', '我', '不过', '是')
#
# Predicted labels:
# -----------------
# ('Life', 'The', 'First', 'Ten years', 'Almost', 'Flowered', 'Ten chapters', 'To', 'Description', 'But', 'This', 'No', 'A', 'Is', 'Formal', 'The rules', 'Autobiography', 'I', 'But', 'Is')
#
#
# Sentence Key: 3340
#
# Sentence: ('总是', '独自一人', '这种', '自由', '与', '乐趣', '所以', '这么', '不同寻常', '是', '有', '其', '原因', '的', '而说', '清楚', '这个', '原委', '就', '成')
#
# Predicted labels:
# -----------------
# ('Always', 'Alone', 'This', 'Free', 'And', 'Fun', 'So', 'So', 'Unusual', 'Is', 'Yes', 'Its', 'Reason', 'The', 'And to say,', 'Clear', 'This one', 'Original commission', 'Just.', 'Yes')
#
#
# Sentence Key: 7020
#
# Sentence: ('世界', '既', '没有', '书信往来', '也', '不通', '消息', '学校', '的', '规定', '任务', '习惯', '观念', '音容', '语言', '服饰', '好恶', '就是', '我', '所')
#
# Predicted labels:
# -----------------
# ('World', 'Both', 'No', 'Correspondence', 'Also', "It doesn't", 'News', 'School', 'The', 'Provisions', 'Task', 'Habit', 'Concept', 'Tone', 'Language', 'Clothing', 'Dislikes', 'It is', 'I', 'The')
#
#
# Sentence Key: 15720
#
# Sentence: ('地', '安息', '在', '坟墓', '中', '的', '原因', '吧', '”', '“', '是', '呀', '‘', '经过', '一场', '人生', '的', '热病', '他们', '现在')
#
# Predicted labels:
# -----------------
# ('Ground', 'Rest', 'In', 'Grave', 'In', 'The', 'Reason', "Let's do it", '"', '"', 'Is', 'Oh, yes.', "'", 'After', 'A', 'Life', 'The', 'Fever', 'They', 'Right now')
#
#
# Sentence Key: 5540
#
# Sentence: ('相信', '我', '有', '信仰', '我', '去', '上帝', '那儿', '”', '“', '上帝', '在', '哪儿', '上帝', '是', '什么', '”', '“', '我', '的')
#
# Predicted labels:
# -----------------
# ('Believe', 'I', 'Yes', 'Belief', 'I', 'To', 'Oh, God', 'There', '"', '"', 'Oh, God', 'In', 'Where', 'Oh, God', 'Is', 'What the', '"', '"', 'I', 'The')
#
#
# Sentence Key: 10700
#
# Sentence: ('还', '算', '得', '上', '有点', '和', '气', '我', '肯定', '能', '同', '她', '好好', '相处', '我会', '尽力而为', '可惜', '竭尽全力', '并', '不')
#
# Predicted labels:
# -----------------
# ('Also', 'Count', 'Get it.', 'On', 'A little bit.', 'And', 'Gas', 'I', 'Sure', 'Yes', 'With', 'She', 'Good', 'Get along', 'I will', 'Best', 'Pity', 'Tried', 'And', 'No')
#
#
# Sentence Key: 2740
#
# Sentence: ('遐想', '中', '准备', '有热', '的', '烤', '土豆', '或', '白', '面包', '与', '新', '鲜牛奶', '的', '巴米', '赛德', '晚餐', '往常', '我', '是')
#
# Predicted labels:
# -----------------
# ('Reverie', 'In', 'Get ready', "It's hot.", 'The', 'Roast', 'Potatoes', 'Or', 'White', 'Bread', 'And', 'New', 'Fresh milk', 'The', 'Bami', 'Said', 'Dinner', 'Usual', 'I', 'Is')
#
#
# Sentence Key: 14980
#
# Sentence: ('”', '“', '唉', '爱', '小姐', '尽管', '罗切斯特', '先生', '很少', '上', '这儿', '来', '但要', '来', '就', '往往', '很', '突然', '料', '也')
#
# Predicted labels:
# -----------------
# ('"', '"', 'Alas', 'Love', 'Miss', 'Although', 'Rochester', 'Mr', 'Rarely', 'On', 'Here', 'To', 'But to', 'To', 'Just.', 'Often', 'Is', 'Suddenly', 'Material', 'Also')
#
#
# Sentence Key: 3980
#
# Sentence: ('什么', '加以', '干涉', '她', '擅长', '叙述', '我', '善于', '分析', '；', '她', '喜欢', '讲', '我', '喜欢', '问', '我们', '两个', '处得', '很')
#
# Predicted labels:
# -----------------
# ('What the', 'Be', 'Interference', 'She', 'Good', 'Narrative', 'I', 'Good', 'Analysis', ';', 'She', 'Like', 'Speak', 'I', 'Like', 'Ask', 'We', 'Two', "Get where you've got to do", 'Is')
#
#
# Sentence Key: 18940
#
# Sentence: ('我', '也', '会', '像', '人们', '躲避', '火灾', '闪电', '或者', '别的', '虽然', '明亮', '却', '今人', '厌恶', '的', '东西', '一样', '对', '它们')
#
# Predicted labels:
# -----------------
# ('I', 'Also', 'Yes', 'Like', 'People', 'Avoid', 'Fire', 'Lightning', 'Or', 'Other', 'Although', 'Bright', 'But', "Today's people", 'Disgust', 'The', 'Things', 'The same', 'Right', 'They')
#
#
# Sentence Key: 13900
#
# Sentence: ('去逛', '一个', '老大', '的', '地方', '种满树', '碧绿', '碧绿', '的', '他们', '管', '它', '叫', '公园', '除', '我', '那里', '还有', '很多', '孩子')
#
# Predicted labels:
# -----------------
# ('Go hang out.', 'One', 'Boss', 'The', 'Place', 'Planting trees', 'Green', 'Green', 'The', 'They', 'Tube', 'It', 'Call', 'Park', 'Except', 'I', 'There', 'And also', 'A lot', 'Children')
#
#
# Sentence Key: 4060
#
# Sentence: ('她', '只不过', '能', '给', '我', '讲', '些', '有趣', '的', '故事', '回对', '一些', '我', '所', '津津乐道', '的', '辛辣', '活泼', '的', '闲聊')
#
# Predicted labels:
# -----------------
# ('She', 'Just', 'Yes', 'To give', 'I', 'Speak', 'Some', 'Interesting', 'The', 'Story', 'Back to pair', 'A few', 'I', 'The', 'Relish', 'The', 'Spicy', 'Lively', 'The', 'Chat')
#
#
# Sentence Key: 3660
#
# Sentence: ('的', '边缘', '装扮', '得', '十分', '鲜艳', '香甜', '的', '欧', '石南', '在', '清晨', '和', '夜间', '散发', '着', '香料', '和', '苹果', '的')
#
# Predicted labels:
# -----------------
# ('The', 'Edge', 'Dress', 'Get it.', 'Very', 'Bright', 'Sweet', 'The', 'Europe', 'Heather', 'In', 'Morning', 'And', 'Night', 'Distribution', 'On the', 'Spices', 'And', 'Apple', 'The')
#
#
# Sentence Key: 18020
#
# Sentence: ('确确实实', '的', '脚步声', '刺耳', '的', '喀嗒', '喀嗒', '声', '盖', '过', '柔和', '的', '波涛起伏', '似的', '声响', '犹如', '在', '一幅', '画', '中')
#
# Predicted labels:
# -----------------
# ("It's true.", 'The', 'Footsteps', 'Harsh', 'The', 'Click', 'Click', 'Sound', 'Cover', 'Too much', 'Soft', 'The', 'Waves ups and downs', "It's like.", 'Sound', 'Like', 'In', 'One', 'Draw', 'In')
#
#
# Sentence Key: 5300
#
# Sentence: ('病得', '很重', '我', '不同', '你', '说句话', '就', '睡不着', '”', '“', '那', '你', '是', '来', '同', '我', '告别', '的', '也许', '许')
#
# Predicted labels:
# -----------------
# ('Sick.', "It's heavy.", 'I', 'Different', 'You', 'Say a word.', 'Just.', "I can't sleep", '"', '"', 'That', 'You', 'Is', 'To', 'With', 'I', 'Farewell', 'The', 'Maybe', 'Xu')
#
#
# Sentence Key: 13260
#
# Sentence: ('指望', '”', '“', '那么', '那位', '小姑娘', '呢', '—', '—', '我', '的', '学生', '”', '“', '她', '是', '罗切斯特', '先生', '的', '受')
#
# Predicted labels:
# -----------------
# ('Expect', '"', '"', 'So', 'The one.', 'Little girl.', 'What about?', '—', '—', 'I', 'The', 'Students', '"', '"', 'She', 'Is', 'Rochester', 'Mr', 'The', 'By')
#
#
# Sentence Key: 6980
#
# Sentence: ('但', '我', '从来', '没有', '离开', '过', '这里', '假期', '都', '是', '在', '学校', '里', '度过', '的', '里德', '太太', '从来', '没有', '把')
#
# Predicted labels:
# -----------------
# ('But', 'I', 'Never', 'No', 'Leave', 'Too much', 'Over here', 'Holiday', 'All', 'Is', 'In', 'School', 'Inside', 'Spend', 'The', 'Reed', 'Wife', 'Never', 'No', 'Put')
#
#
# Sentence Key: 20080
#
# Sentence: ('相媲美', '在', '我', '现在', '这种', '情况', '下', '希望', '走动', '走动', '跟', '他', '在', '那种', '情况', '希望', '走动', '一样', '是', '很')
#
# Predicted labels:
# -----------------
# ('Comparable', 'In', 'I', 'Right now', 'This', 'Situation', 'Next', 'Hope', 'Walk', 'Walk', 'With', 'He', 'In', 'That', 'Situation', 'Hope', 'Walk', 'The same', 'Is', 'Is')
#
#
# Sentence Key: 5220
#
# Sentence: ('我', '想', '“', '她', '不会', '死', '她们', '搞错', '要是', '她', '活', '不', '啦', '她', '的', '言语', '和', '神色', '不会', '那么')
#
# Predicted labels:
# -----------------
# ('I', 'Think', '"', 'She', 'No', 'Die', 'They', 'Wrong', 'If', 'She', 'Live', 'No', "That's it.", 'She', 'The', 'Words', 'And', 'Look', 'No', 'So')
#
#
# Sentence Key: 19020
#
# Sentence: ('我', '走', '的', '时候', '我', '仍然', '坚守阵地', '并且', '宣布', '“', '先生', '没有', '看到', '你', '能够', '骑', '上马', '我', '是', '不能')
#
# Predicted labels:
# -----------------
# ('I', 'Go', 'The', 'When', 'I', 'Still', 'Hold your ground.', 'And', 'Announced', '"', 'Mr', 'No', 'See', 'You', 'Can', 'Ride', 'Launched', 'I', 'Is', 'No')
#
#
# Sentence Key: 7680
#
# Sentence: ('全校', '吵醒', '就', '写', '好', '广告', '封入', '信封', '写', '上', '地址', '信', '上', '说', '“', '现有', '一位', '年轻', '女士', '熟悉')
#
# Predicted labels:
# -----------------
# ('School', 'Wake', 'Just.', 'Write', 'Good', 'Advertising', 'Sealing', 'Envelope', 'Write', 'On', 'Address', 'Letter', 'On', 'Said', '"', 'Existing', 'A', 'Young', 'Lady', 'Familiar with')
#
#
# Sentence Key: 19700
#
# Sentence: ('在', '某种程度', '上', '说', '它', '既', '不', '重要', '也', '不', '浪漫', '又', '不', '有趣', '但', '它', '却', '标志', '着', '单调乏味')
#
# Predicted labels:
# -----------------
# ('In', 'To some extent.', 'On', 'Said', 'It', 'Both', 'No', 'Important', 'Also', 'No', 'Romantic', 'And again', 'No', 'Interesting', 'But', 'It', 'But', 'Sign', 'On the', 'Monotony')
#
#
# Sentence Key: 3960
#
# Sentence: ('的', '东西', '满足', '我', '的', '好奇心', '对', '我', '的', '缺陷', '她', '也', '能', '宽容', '姑息', '从不', '对', '我', '说', '的')
#
# Predicted labels:
# -----------------
# ('The', 'Things', 'Meet', 'I', 'The', 'Curiosity', 'Right', 'I', 'The', 'Defects', 'She', 'Also', 'Yes', 'Tolerance', 'Palliative', 'Never', 'Right', 'I', 'Said', 'The')
#
#
# Sentence Key: 17320
#
# Sentence: ('着', '一个', '脸盆', '或者', '一个', '盘子', '或者', '一个', '托盘', '下楼', '到', '厨房', '去', '并', '很快', '就', '返回', '一般说来', '唉', '浪漫')
#
# Predicted labels:
# -----------------
# ('On the', 'One', 'Basin', 'Or', 'One', 'Plate', 'Or', 'One', 'Tray', 'Downstairs', 'To', 'Kitchen', 'To', 'And', 'Soon', 'Just.', 'Return', 'Generally speaking', 'Alas', 'Romantic')
#
#
# Sentence Key: 16080
#
# Sentence: ('响起', '声音', '越来越', '大', '不依', '才', '起来', '时', '虽然', '清晰', '却', '很', '低沉', '这', '笑声', '震耳欲聋', '般地', '响', '一阵', '以后')
#
# Predicted labels:
# -----------------
# ('Rang', 'Voice', 'Getting', 'Big', 'Not by', "It's just", 'Get up', 'When', 'Although', 'Clear', 'But', 'Is', 'Low', 'This', 'Laughter', 'Deafening', 'like', 'Ring', 'A', 'later')
#
#
# Sentence Key: 3060
#
# Sentence: ('三色', '紫罗兰', '每逢', '星期四', '下午', '半', '假日', '我们', '都', '出去', '散步', '看到', '不少', '更加', '可爱', '的', '花朵', '盛开', '在', '路边')
#
# Predicted labels:
# -----------------
# ('Three colors', 'Violet', 'Every', 'Thursday', 'Afternoon', 'Half', 'Holiday', 'We', 'All', 'Get out', 'Walking', 'See', 'Many', 'More', 'Lovely', 'The', 'Flowers', 'Bloom', 'In', 'Roadside')
#
#
# Sentence Key: 15380
#
# Sentence: ('理解', '我们', '离开', '餐厅', '时', '她', '提议', '带我去', '看看', '房子', '其余', '的', '地方', '我', '跟着', '她', '上楼', '下楼', '一路', '走')
#
# Predicted labels:
# -----------------
# ('Understand', 'We', 'Leave', 'Restaurant', 'When', 'She', 'Proposal', 'Take me.', 'Look', 'House', 'Rest', 'The', 'Place', 'I', 'Follow', 'She', 'Upstairs', 'Downstairs', 'Way', 'Go')
#
#
# Sentence Key: 18300
#
# Sentence: ('有', '几分', '担心', '的', '那样', '停下来', '用', '比狗', '更具', '智想', '的', '奇特', '目光', '抬头', '看', '我', '的', '面孔', '那', '匹')
#
# Predicted labels:
# -----------------
# ('Yes', 'Few', 'Worry', 'The', "That's it.", 'Stop it', 'Use', 'than a dog.', 'More', 'Think of', 'The', 'Peculiar', 'Eyes', 'Rise', 'See', 'I', 'The', 'Face', 'That', 'Pi')
#
#
# Sentence Key: 11440
#
# Sentence: ('况且', '这种', '关心', '来自', '我', '的', '雇主', '和', '上司', '可是', '她', '似乎', '并不认为', '自己', '的', '行动', '有', '什么', '出格', '所以')
#
# Predicted labels:
# -----------------
# ('Besides', 'This', 'Care', 'From', 'I', 'The', 'Employers', 'And', 'Boss', 'But', 'She', 'Seems', "Don't think", 'Myself', 'The', "Let's go", 'Yes', 'What the', 'Special', 'So')
#
#
# Sentence Key: 20400
#
# Sentence: ('盖', '特拉西', '”', '如此', '形神', '毕肖', '我', '禁不住', '走上', '前', '说', '声', '—', '一', '“', '派', '洛特', '”', '那家伙', '一跃而起')
#
# Predicted labels:
# -----------------
# ('Cover', 'Tracy', '"', 'So', 'Shape God', 'Bishoo', 'I', 'Help', 'On', 'Ago', 'Said', 'Sound', '—', 'One', '"', 'Sent', 'Lott', '"', 'That guy.', 'Jumped')
#
#
# Sentence Key: 9080
#
# Sentence: ('小家伙', '穿着', '花格', '呢', '外衣', '和', '裤子', '“', '那', '是', '我', '的', '儿子', '”', '贝茜', '立刻', '说', '“', '这么', '说')
#
# Predicted labels:
# -----------------
# ('Little', 'Wearing', 'Flower', 'What about?', 'Coat', 'And', 'Pants', '"', 'That', 'Is', 'I', 'The', 'Son', '"', 'Bessie', 'Immediately', 'Said', '"', 'So', 'Said')
#
#
# Sentence Key: 10380
#
# Sentence: ('在', '世上', '孑然一身', '一切', '联系', '已', '被', '割断', '能否', '抵达', '目的港', '又', '无把握', '要', '返回', '出发点', '则', '障碍', '重重', '冒险')
#
# Predicted labels:
# -----------------
# ('In', 'World', 'Alone', 'All', 'Contact', 'Has', 'Be', 'Cut', 'Can', 'Arrived', 'Port of Destination', 'And again', 'Uncertain', 'To', 'Return', 'Starting point', 'Then', 'Obstacles', 'Heavy', 'Adventure')
#
#
# Sentence Key: 4580
#
# Sentence: ('摇摇晃晃', '要', '落入', '一片', '混乱', '之中', '便', '不禁', '颤抖', '起来', '我', '正', '细细', '咀嚼', '着', '这个', '新', '想法', '却', '听')
#
# Predicted labels:
# -----------------
# ('Rickety', 'To', 'Fall', 'A', 'Chaos', 'In the middle', 'Poe', "Can't help", 'Trembling', 'Get up', 'I', 'Is', 'Thin', 'Chewing', 'On the', 'This one', 'New', 'Idea', 'But', 'Listen')
#
#
# Sentence Key: 16440
#
# Sentence: ('里', '迎', '着', '我们', '跑过来', '一面', '还', '嚷嚷', '着', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-')
#
# Predicted labels:
# -----------------
# ('Inside', 'Ying', 'On the', 'We', 'Run over.', 'Side', 'Also', 'Yelling', 'On the', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-')
#
#
# Sentence Key: 3560
#
# Sentence: ('在', '学校', '里', '悄悄地', '草草', '埋掉', '算数', '这种', '病', '的', '特性', '决定', '容不得', '半点', '拖延', '就', '这样', '疾病', '在', '罗沃')
#
# Predicted labels:
# -----------------
# ('In', 'School', 'Inside', 'Quietly', 'Grass', 'Bury it.', 'Count', 'This', 'Disease', 'The', 'Characteristics', 'Decided', 'Not allowed', 'Half a point', 'Delay', 'Just.', 'This way,', 'Disease', 'In', 'Rovo')
#
#
# Sentence Key: 18800
#
# Sentence: ('我', '捉摸', '得出', '他', '大体', '中等', '身材', '胸膛', '很', '宽', '他', '的', '脸庞', '黝黑', '面容', '严厉', '眉毛', '浓密', '；', '他')
#
# Predicted labels:
# -----------------
# ('I', 'Fathom', 'The result is', 'He', 'General', 'Medium', 'Figure', 'Chest', 'Is', 'Wide', 'He', 'The', 'Face', 'Dark', 'Countenance', 'Strict', 'Eyebrows', 'Densely', ';', 'He')
#
#
# Sentence Key: 20340
#
# Sentence: ('阿黛勒', '的', '口音', '似乎', '还', '能', '分辩', '得', '出来', '我', '赶到', '费尔法克斯', '太太', '的', '房间', '那儿', '也', '生', '着火', '却')
#
# Predicted labels:
# -----------------
# ('Adele', 'The', 'Accent', 'Seems', 'Also', 'Yes', 'Resolution', 'Get it.', 'Come out', 'I', 'To', 'Fairfax', 'Wife', 'The', 'Room', 'There', 'Also', 'Raw', 'Fire', 'But')
#
#
# Sentence Key: 11760
#
# Sentence: ('着', '我', '真', '感到', '忧伤', '有时', '我', '让', '莉娅', '进来', '读', '些', '东西', '给', '我', '听听', '不过', '我', '想', '这')
#
# Predicted labels:
# -----------------
# ('On the', 'I', 'Really', 'Feel', 'Sad', 'Sometimes', 'I', 'Let', 'Leah', 'In', 'Read', 'Some', 'Things', 'To give', 'I', 'Listen to it.', 'But', 'I', 'Think', 'This')
#
#
# Sentence Key: 11420
#
# Sentence: ('地方', '接着', '她', '亲自', '把', '点心', '递给', '我', '我', '颇', '有些', '受宠若惊', '我', '从来', '没有', '受到', '过', '这样', '的', '关心')
#
# Predicted labels:
# -----------------
# ('Place', 'Then', 'She', 'Personally', 'Put', 'Snacks', 'Handed it to', 'I', 'I', 'Quite', 'Some', 'Flattered', 'I', 'Never', 'No', 'Be', 'Too much', 'This way,', 'The', 'Care')
#
#
# Sentence Key: 1560
#
# Sentence: ('想', '不', '太', '厉害', '小姐', '”', '“', '胸部', '的', '疼痛', '呢', '”', '“', '好', '一点', '”', '坦普尔', '小姐', '站', '起来')
#
# Predicted labels:
# -----------------
# ('Think', 'No', 'Too', "It's awesome.", 'Miss', '"', '"', 'Chest', 'The', 'Pain', 'What about?', '"', '"', 'Good', 'A little.', '"', 'Temple', 'Miss', 'Stand', 'Get up')
#
#
# Sentence Key: 2160
#
# Sentence: ('泉', '么', '这', '就是', '那个', '使', '我', '难以忘怀', '的', '夜晚', '海伦', '谈话', '的', '特色', '她', '的', '心灵', '仿佛', '急于', '要')
#
# Predicted labels:
# -----------------
# ('Spring', 'Is that', 'This', 'It is', 'That one', 'Make', 'I', 'Unforgettable', 'The', 'Night', 'Helen', 'Talk', 'The', 'Characteristics', 'She', 'The', 'Mind', 'Seems', 'Rush', 'To')
#
#
# Sentence Key: 16460
#
# Sentence: ('-', '第十二章', '我', '初到', '桑', '菲尔德', '府', '的', '时候', '一切', '都', '显得', '平平静静', '似乎', '预示', '着', '我', '未来', '的', '经历')
#
# Predicted labels:
# -----------------
# ('-', 'Chapter 12', 'I', 'First to', 'Sang', 'Field', 'Fu', 'The', 'When', 'All', 'All', 'Look', 'Flat and quiet', 'Seems', 'Predict', 'On the', 'I', 'Future', 'The', 'Experience')
#
#
# Sentence Key: 7720
#
# Sentence: ('才', '十八岁', '要', '指导', '一个', '跟', '我', '年龄', '相仿', '的', '人', '是', '断然', '不行', '的', '该', '女士', '能', '胜任', '良好')
#
# Predicted labels:
# -----------------
# ("It's just", 'Eighteen years old.', 'To', 'Guidance', 'One', 'With', 'I', 'Age', 'Similar', 'The', 'People', 'Is', 'Flatly', 'No way', 'The', 'The', 'Lady', 'Yes', 'Competent', 'Good')
#
#
# Sentence Key: 20320
#
# Sentence: ('但', '因为', '关着', '门', '我', '几乎', '没', '能', '看清楚', '他们', '也', '没有', '听', '清楚', '欢乐', '而', '嘈杂', '的', '人声', '不过')
#
# Predicted labels:
# -----------------
# ('But', 'Because', 'Keep on.', 'Door', 'I', 'Almost', "Didn't", 'Yes', 'Look at it.', 'They', 'Also', 'No', 'Listen', 'Clear', 'Joy', 'And', 'Noisy', 'The', 'Vocals', 'But')
#
#
# Sentence Key: 20540
#
# Sentence: ('那', '匹', '马', '是', '在', '海路', '上', '倒下', '的', '吗', '”', '“', '是', '呀', '下山', '的', '时候', '在', '冰上', '滑')
#
# Predicted labels:
# -----------------
# ('That', 'Pi', 'Horse', 'Is', 'In', 'Sea', 'On', 'Fall', 'The', 'Do you?', '"', '"', 'Is', 'Oh, yes.', 'Down', 'The', 'When', 'In', 'On the ice', 'Sliding')
#
#
# Sentence Key: 2560
#
# Sentence: ('我', '心里', '痛苦', '得', '难以忍受', '上述', '事件', '发生', '后', '大约', '一周', '坦普尔', '小姐', '写给', '劳埃德', '先生', '的', '信', '有', '回音')
#
# Predicted labels:
# -----------------
# ('I', 'Heart', 'Pain', 'Get it.', "It's unbearable.", 'Above', 'Event', 'Happen', 'After', 'About', 'One week', 'Temple', 'Miss', 'To', 'Lloyd', 'Mr', 'The', 'Letter', 'Yes', 'Echo')
#
#
# Sentence Key: 20140
#
# Sentence: ('幢', '阴暗', '的', '房子', '从', '在我看来', '是', '满布', '暗室', '的', '灰色', '洞穴', '中', '退缩', '出来', '到达', '展现', '在', '我', '面前')
#
# Predicted labels:
# -----------------
# ('Building', 'Dark', 'The', 'House', 'From', 'In my opinion,', 'Is', 'Full cloth', 'Darkroom', 'The', 'Grey', 'Cave', 'In', 'Retreat', 'Come out', 'Reach', 'Show', 'In', 'I', 'Front')
#
#
# Sentence Key: 3180
#
# Sentence: ('直至', '与', '溪流', '上', '凝结', '的', '水气', '融为一体', '那时', '这', '条', '小溪', '是', '一股', '混浊', '不堪', '势不可挡', '的', '急流', '它')
#
# Predicted labels:
# -----------------
# ('Until', 'And', 'Streams', 'On', 'Condensation', 'The', 'Water', 'Integrated', 'Then', 'This', 'Bar', 'Stream', 'Is', 'One', 'Opacity', "It's unbearable", 'Overwhelming', 'The', 'Rapids', 'It')
#
#
# Sentence Key: 10460
#
# Sentence: ('小姐', '让', '我', '到', '酒', '巴', '去', '打听一下', '吧', '”', '他', '走', '但', '立刻', '又', '回来', '“', '你', '的', '名字')
#
# Predicted labels:
# -----------------
# ('Miss', 'Let', 'I', 'To', 'Wine', 'Ba', 'To', 'Ask me.', "Let's do it", '"', 'He', 'Go', 'But', 'Immediately', 'And again', 'Come back', '"', 'You', 'The', 'Name')
#
#
# Sentence Key: 13240
#
# Sentence: ('与我无关', '我', '把', '自己', '看作', '一个', '普普通通', '的', '管家', '我', '的', '雇主', '总是', '客客气气', '的', '而', '别的', '我', '都', '不')
#
# Predicted labels:
# -----------------
# ("It's nothing to do with me", 'I', 'Put', 'Myself', 'As', 'One', 'Ordinary', 'The', 'Housekeeper', 'I', 'The', 'Employers', 'Always', 'Graciously', 'The', 'And', 'Other', 'I', 'All', 'No')
#
#
# Sentence Key: 12720
#
# Sentence: ('我', '往前', '来到', '草坪', '上', '抬头', '细看', '这', '大厦', '的', '正面', '这', '是', '幢', '三层楼', '屋宇', '虽然', '有', '相当规模', '但')
#
# Predicted labels:
# -----------------
# ('I', 'Forward', 'Came', 'Lawn', 'On', 'Rise', 'Take a closer look', 'This', 'Building', 'The', 'Positive', 'This', 'Is', 'Building', 'Three floors', 'House', 'Although', 'Yes', 'Quite a large scale', 'But')
#
#
# Sentence Key: 16640
#
# Sentence: ('维系', '着', '一种', '彼此', '都', '感到', '满意', '的', '关系', '这些', '话', 'Parparenthese', '会', '被', '某些', '人', '视为', '过于', '冷淡', '这些')
#
# Predicted labels:
# -----------------
# ('Maintain', 'On the', 'A', 'Each other', 'All', 'Feel', 'Satisfaction', 'The', 'Relationship', 'These', 'Words', 'Parparenthese', 'Yes', 'Be', 'Some', 'People', 'As', 'Too', 'Cold', 'These')
#
#
# Sentence Key: 2200
#
# Sentence: ('的', '事情', '谈到', '逝去', '的', '民族', '和', '时代', '谈到', '遥远', '的', '国度', '；', '谈到', '被', '发现', '或', '臆测', '到', '的')
#
# Predicted labels:
# -----------------
# ('The', 'Things', 'Talked about', 'Gone', 'The', 'National', 'And', 'Times', 'Talked about', 'Distant', 'The', 'Country', ';', 'Talked about', 'Be', 'Found', 'Or', 'Speculation', 'To', 'The')
#
#
# Sentence Key: 19880
#
# Sentence: ('我', '只', '听到', '一阵', '微风', '在', '一英里', '开外', '绕', '着', '桑', '菲尔德', '府', '的', '树林', '时', '起', '时落', '；', '当')
#
# Predicted labels:
# -----------------
# ('I', 'Only', 'Hear', 'A', 'Breeze', 'In', 'One mile.', 'Away', 'Around', 'On the', 'Sang', 'Field', 'Fu', 'The', 'Woods', 'When', 'From', 'Time and time drop', ';', 'When')
#
#
# Sentence Key: 5340
#
# Sentence: ('我', '永久', '的', '—', '—', '我', '最后', '的', '家', '”', '“', '不', '不', '海伦', '”', '我', '顿住', '心里', '很', '难过')
#
# Predicted labels:
# -----------------
# ('I', 'Permanent', 'The', '—', '—', 'I', 'At last', 'The', 'Home', '"', '"', 'No', 'No', 'Helen', '"', 'I', 'Stay in.', 'Heart', 'Is', 'Sad')
#
#
# Sentence Key: 2960
#
# Sentence: ('一', '拐', '一', '拐', '的', '可怜', '的', '脚', '已', '开始', '消肿', '和', '痊愈', '夜晚', '和', '清晨', '不再', '出现', '加拿大', '式')
#
# Predicted labels:
# -----------------
# ('One', 'Turn', 'One', 'Turn', 'The', 'Poor', 'The', 'Feet', 'Has', 'Begin', 'Swelling', 'And', 'Heal', 'Night', 'And', 'Morning', 'No longer', 'Appear', 'Canada', 'style')
#
#
# Sentence Key: 2140
#
# Sentence: ('判断', '一个十四岁', '的', '女孩', '有', '这样', '活跃', '这样', '宽大', '的', '胸怀', '装得', '下', '这', '纯洁', '充盈', '炽热', '的', '雄辩', '之')
#
# Predicted labels:
# -----------------
# ('Judge', 'A fourteen-year-old.', 'The', 'Girl', 'Yes', 'This way,', 'Active', 'This way,', 'Wide', 'The', 'Mind', "It's loaded.", 'Next', 'This', 'Pure', 'Filling', 'Hot', 'The', 'Eloquent', 'The')
#
#
# Sentence Key: 9580
#
# Sentence: ('都', '希望', '能', '讨人喜欢', '而', '她们', '相信', '自己', '并', '不', '具备', '有助于', '实现', '这种', '愿望', '的', '外表', '时', '心里', '是')
#
# Predicted labels:
# -----------------
# ('All', 'Hope', 'Yes', "It's pleasing.", 'And', 'They', 'Believe', 'Myself', 'And', 'No', 'Have', 'Help', 'Realize', 'This', 'Wish', 'The', 'Appearance', 'When', 'Heart', 'Is')
#
#
# Sentence Key: 3460
#
# Sentence: ('女生', '中', '四十五', '人', '一下子', '病倒', '班级', '停课', '纪律', '松懈', '少数', '没有', '得病', '的', '几乎', '已', '完全', '放任自流', '因为', '医生')
#
# Predicted labels:
# -----------------
# ('Girls', 'In', 'Forty-five', 'People', 'Suddenly', 'Fell ill', 'Class', 'Closed', 'Discipline', 'Lax', 'Few', 'No', 'Sick', 'The', 'Almost', 'Has', 'Completely', 'Drift', 'Because', 'Doctor')
#
#
# Sentence Key: 12140
#
# Sentence: ('终于', '到达', '一个', '安全', '避风港', '感激', '之', '情', '油然而生', '我', '跪', '在', '床边', '开始', '祈祷', '表示', '理所应当', '的', '感恩', '在')
#
# Predicted labels:
# -----------------
# ('Finally', 'Reach', 'One', 'Safety', 'Haven', 'Grateful', 'The', 'Love', 'Oil is produced', 'I', 'Kneeling', 'In', 'Bedside', 'Begin', 'Pray', 'Said', 'Deserved', 'The', 'Thanksgiving', 'In')
#
#
# Sentence Key: 12860
#
# Sentence: ('桑', '菲尔德', '给', '它', '带来', '一种', '我', '不曾', '料到', '在', '闹', '闹嚷嚷', '的', '米尔科', '特', '地区', '会', '有', '的', '清静')
#
# Predicted labels:
# -----------------
# ('Sang', 'Field', 'To give', 'It', 'Bring', 'A', 'I', 'Never', 'Expect', 'In', 'Noisy', 'Shouting', 'The', 'Milko', 'Special', 'Area', 'Yes', 'Yes', 'The', 'Quiet')
#
#
# Sentence Key: 10060
#
# Sentence: ('赫斯特', '纹章', '旅店', '的', '门边', '分手', '各', '走', '各', '的', '路', '她', '动身', '去', '罗沃德', '山岗', '搭车', '回', '盖茨', '黑德')
#
# Predicted labels:
# -----------------
# ('Hurst', 'Tattoos', 'Hotel', 'The', 'By the door.', 'Break', 'Each', 'Go', 'Each', 'The', 'Lu', 'She', 'Leave', 'To', 'Lowood', 'Hills', 'Ride', 'Back', 'Gates', 'Head')
#
#
# Sentence Key: 19940
#
# Sentence: ('门槛', '就', '意味着', '回到', '一潭死水', '之中', '穿过', '寂静', '的', '大厅', '登上', '暗', '洞洞', '的', '楼梯', '寻找', '我', '那', '孤寂', '的')
#
# Predicted labels:
# -----------------
# ('Threshold', 'Just.', 'It means', 'Back', 'Backwater', 'In the middle', 'Through', 'Silence', 'The', 'Hall', 'Boarded', 'Dark', 'Holes', 'The', 'Stairs', 'Find', 'I', 'That', 'Lonely', 'The')
#
#
# Sentence Key: 8760
#
# Sentence: ('够', '我', '整理', '箱子', '—', '—', '还是', '八年', '前', '从', '盖茨', '黑德', '带来', '的', '那', '一只', '.', '箱子', '已', '用')
#
# Predicted labels:
# -----------------
# ('Enough', 'I', 'Finishing', 'Box', '—', '—', 'Still is', 'Eight years.', 'Ago', 'From', 'Gates', 'Head', 'Bring', 'The', 'That', 'One', '.', 'Box', 'Has', 'Use')
#
#
# Sentence Key: 15080
#
# Sentence: ('啊', '是', '的', '这个', '家族', '在', '这儿', '一向', '受', '人', '尊敬', '很久很久', '以前', '凡是', '你', '望', '得', '见', '的', '附近')
#
# Predicted labels:
# -----------------
# ('Ah, yes.', 'Is', 'The', 'This one', 'Family', 'In', 'Here', 'Always', 'By', 'People', 'Respect', "It's been a long, long", 'before', 'All', 'You', 'Look', 'Get it.', 'See', 'The', 'Near')
#
#
# Sentence Key: 580
#
# Sentence: ('我', '那么', '与其', '活着', '还', '不如', '死去', '—', '—', '我', '受', '不', '孤独', '和', '别人', '的', '厌恶', '海伦', '瞧为', '从')
#
# Predicted labels:
# -----------------
# ('I', 'So', 'With its', 'Live.', 'Also', 'As', 'Die', '—', '—', 'I', 'By', 'No', 'Lonely', 'And', 'Others', 'The', 'Disgust', 'Helen', 'Look for it.', 'From')
#
#
# Sentence Key: 9240
#
# Sentence: ('那么', '阔', '”', '“', '乔治亚', '娜', '想来', '很漂亮', '吧', '贝茜', '”', '“', '很漂亮', '去年', '冬天', '她', '同', '妈妈', '上', '伦敦')
#
# Predicted labels:
# -----------------
# ('So', 'Wide', '"', '"', 'Georgia', 'Na', 'Want', "It's beautiful", "Let's do it", 'Bessie', '"', '"', "It's beautiful", 'Last year', 'Winter', 'She', 'With', 'Mom', 'On', 'London')
#
#
# Sentence Key: 2440
#
# Sentence: ('说', '“', '我', '是', '想', '把', '它们', '放', '整齐', '的', '可', '总是', '忘', '”', '第二', '早上', '斯卡', '查德', '小姐', '在')
#
# Predicted labels:
# -----------------
# ('Said', '"', 'I', 'Is', 'Think', 'Put', 'They', 'Put', 'Neat', 'The', 'Can be', 'Always', 'Forget', '"', 'Second', 'Morning', 'Scar', 'Chad', 'Miss', 'In')
#
#
# Sentence Key: 4660
#
# Sentence: ('什么', '呀', '”', '“', '他', '说', '她', '不会', '在', '这儿', '呆', '很久', '”', '这', '句', '话', '要是', '昨天', '让', '我')
#
# Predicted labels:
# -----------------
# ('What the', 'Oh, yes.', '"', '"', 'He', 'Said', 'She', 'No', 'In', 'Here', 'Stay', "It's been a", '"', 'This', 'Sentence', 'Words', 'If', 'Yesterday', 'Let', 'I')
#
#
# Sentence Key: 5500
#
# Sentence: ('大难', '我', '没有', '会', '使', '自己', '在', '世上', '发迹', '的', '气质', '和', '才能', '要是', '我', '活着', '我会', '一直', '错', '下去')
#
# Predicted labels:
# -----------------
# ('Disaster', 'I', 'No', 'Yes', 'Make', 'Myself', 'In', 'World', 'The trail', 'The', 'Temperament', 'And', 'To', 'If', 'I', 'Live.', 'I will', 'Always', 'Wrong', 'Go down.')
#
#
# Sentence Key: 19480
#
# Sentence: ('它', '的', '前腿', '踩', '着', '这位', '赶路', '人', '等待', '并', '观察', '片刻', '最后', '终于', '笑', '起来', '“', '我', '明白', '”')
#
# Predicted labels:
# -----------------
# ('It', 'The', 'Forelegs', 'Step', 'On the', 'The', 'On the way', 'People', 'Wait', 'And', 'Observation', 'Moment', 'At last', 'Finally', 'Laugh', 'Get up', '"', 'I', 'Got it', '"')
#
#
# Sentence Key: 17540
#
# Sentence: ('着', '去', '邮奇', '于是', '我', '戴', '好', '帽子', '披', '斗篷', '自告奋勇', '把', '信', '送到', '海镇', '去冬', '昌', '下午', '步行', '两英里')
#
# Predicted labels:
# -----------------
# ('On the', 'To', 'Postage', 'So', 'I', 'Wear', 'Good', 'Hat', 'The Beatles', 'Cloak', 'Volunteered', 'Put', 'Letter', 'To', 'Sea Town', 'Last winter', 'Chang', 'Afternoon', 'Walk', 'Two miles.')
#
#
# Sentence Key: 5020
#
# Sentence: ('闷', '人', '的', '病室', '进去', '一点', '新鲜空气', '我', '生性', '讨厌', '犹犹豫豫', '而且', '当时', '急不可耐', '十分', '冲动', '—', '—', '我', '全身心')
#
# Predicted labels:
# -----------------
# ('Stuffy', 'People', 'The', 'Ward', 'Get in', 'A little.', 'Fresh air', 'I', 'Raw', 'Hate', 'Hesitatingly', 'And', 'Was', "It's impatient.", 'Very', 'Impulse', '—', '—', 'I', 'All-in-the')
#
#
# Sentence Key: 9620
#
# Sentence: ('什么', '能', '弹钢琴', '吗', '”', '“', '会', '一点儿', '”', '房内', '有', '一架', '钢琴', '贝茜', '走', '过去', '把', '它', '打开', '随后')
#
# Predicted labels:
# -----------------
# ('What the', 'Yes', 'Piano', 'Do you?', '"', '"', 'Yes', 'A little', '"', 'Inside the room', 'Yes', 'One', 'Piano', 'Bessie', 'Go', 'Past', 'Put', 'It', 'Open it', 'Then')
#
#
# Sentence Key: 12160
#
# Sentence: ('站', '起来', '之前', '并未', '忘记', '祈求', '在', '前', '路上', '赐予', '帮助', '与', '力量', '使', '我', '配得', '上', '还', '没有', '付出')
#
# Predicted labels:
# -----------------
# ('Stand', 'Get up', 'Before', 'Not', 'Forget', 'Pray', 'In', 'Ago', 'Way', 'Give', 'Help', 'And', 'Power', 'Make', 'I', 'It deserves it.', 'On', 'Also', 'No', 'Pay')
#
#
# Sentence Key: 14840
#
# Sentence: ('着', '我', '以为', '自己', '看见', '一个', '仙境', '那', '景象', '使', '我', '这个', '刚', '踏上', '世途', '的', '人', '顿时', '眼目', '清亮')
#
# Predicted labels:
# -----------------
# ('On the', 'I', 'Thought', 'Myself', 'See', 'One', 'Wonderland', 'That', 'Sight', 'Make', 'I', 'This one', 'Just', 'On', 'World Road', 'The', 'People', 'Suddenly', 'Eyes', 'Clear')
#
#
# Sentence Key: 660
#
# Sentence: ('爱', '你', '的', '感情', '太', '冲动', '你', '的', '情绪', '太', '激烈', '一只', '至高无上', '的', '手', '创造', '你', '的', '躯体', '又')
#
# Predicted labels:
# -----------------
# ('Love', 'You', 'The', 'Feelings', 'Too', 'Impulse', 'You', 'The', 'Emotions', 'Too', 'Fierce', 'One', 'Supreme', 'The', 'Hand', 'Create', 'You', 'The', 'Body', 'And again')
#
#
# Sentence Key: 7800
#
# Sentence: ('校长', '请假', '去', '洛顿', '为', '自己', '也', '为', '一', '两位', '共事', '的', '老师', '办', '些', '小事', '她', '欣然', '允诺', '于是')
#
# Predicted labels:
# -----------------
# ('Principal', 'Leave', 'To', 'Lotton', 'For', 'Myself', 'Also', 'For', 'One', 'Two', 'Work', 'The', 'Teacher', 'Do', 'Some', 'Trifle', 'She', 'Readily', 'Promise', 'So')
#
#
# Sentence Key: 6440
#
# Sentence: ('高兴', '这', '一切', '都', '激励', '我', '奋进', '我', '充分利用', '所', '提供', '的', '有利条件', '终于', '一跃而', '成为', '第一班', '的', '第一名', '后来')
#
# Predicted labels:
# -----------------
# ('Happy', 'This', 'All', 'All', 'Incentive', 'I', 'Endeavor', 'I', 'Make the most of', 'The', 'Provide', 'The', 'Favorable conditions', 'Finally', 'Jumping', 'Become', 'Class 1', 'The', '1st', 'Later')
#
#
# Sentence Key: 2480
#
# Sentence: ('在', '海伦', '那', '宽大', '温顺', '聪颖', '一', '付善', '相的', '额头', '上', '她', '那么', '耐心', '而', '毫无', '怨言', '地', '佩戴', '着')
#
# Predicted labels:
# -----------------
# ('In', 'Helen', 'That', 'Wide', 'Docile', 'Intelligent', 'One', 'Pay good', 'Phase', 'Forehead', 'On', 'She', 'So', 'Patience', 'And', 'No', 'Complaints', 'Ground', 'Wear', 'On the')
#
#
# Sentence Key: 13060
#
# Sentence: ('经常', '光顾', '才', '是', '”', '“', '罗切斯特', '先生', '！', '”', '我', '嚷', '道', '“', '他', '是', '谁', '”', '“', '桑')
#
# Predicted labels:
# -----------------
# ('Often', 'Patronize', "It's just", 'Is', '"', '"', 'Rochester', 'Mr', '!', '"', 'I', 'Shouting', 'Road', '"', 'He', 'Is', 'Who', '"', '"', 'Sang')
#
#
# Sentence Key: 5700
#
# Sentence: ('普天下', '共有', '的', '父亲', '所', '接纳', '毫无疑问', '亲爱', '的', '简', '”', '我', '又', '再次', '发问', '不过', '这回', '只是', '想想', '而已')
#
# Predicted labels:
# -----------------
# ('Universal', 'Total', 'The', 'Father', 'The', 'Accepted', 'No doubt', 'Dear', 'The', 'Jane', '"', 'I', 'And again', 'Again', 'Ask', 'But', 'This time.', "It's just that", 'Think about it.', "That's all.")
#
#
# Sentence Key: 17800
#
# Sentence: ('通向', '田野', '的', '台阶', '上', '坐下', '来', '我', '用', '斗篷', '把', '自己', '紧紧', '裹住', '把手', '捂', '在', '皮手筒', '里', '所以')
#
# Predicted labels:
# -----------------
# ('To', 'Field', 'The', 'Steps', 'On', 'Sit down', 'To', 'I', 'Use', 'Cloak', 'Put', 'Myself', 'Tightly', 'Wrap it up.', 'Handle', 'Cover', 'In', 'Leather hand barrel', 'Inside', 'So')
#
#
# Sentence Key: 18840
#
# Sentence: ('大约', '三十五岁', '我', '觉得', '自己', '并', '不怕', '他', '但', '有点儿', '腼腆', '要是', '他', '是', '位', '漂亮', '笑', '俊', '的', '年轻')
#
# Predicted labels:
# -----------------
# ('About', 'Thirty-five years old.', 'I', 'Think', 'Myself', 'And', 'Afraid', 'He', 'But', 'Kinda', 'Shy', 'If', 'He', 'Is', 'Bit', 'Pretty', 'Laugh', 'Jun', 'The', 'Young')
#
#
# Sentence Key: 8600
#
# Sentence: ('向', '布罗克', '赫斯特', '先生', '提出', '这件', '事', '而', '他', '说', '必须', '写信', '通知', '里德', '太太', '因为', '她', '是', '我', '的')
#
# Predicted labels:
# -----------------
# ('To', 'Brock', 'Hurst', 'Mr', 'Presented', 'This one.', 'Things', 'And', 'He', 'Said', 'Have to', 'Write', 'Notice', 'Reed', 'Wife', 'Because', 'She', 'Is', 'I', 'The')
#
#
# Sentence Key: 18600
#
# Sentence: ('马嘶', '脚步', '杂踏', '和', '马蹄', '冲击', '的', '场面', '伴之以', '狗', '的', '狂吠', '结果', '把', '我', '撵', '到', '几码', '远', '之外')
#
# Predicted labels:
# -----------------
# ('Horse hiss', 'Footsteps', 'Miscellaneous', 'And', 'Horseshoe', 'Impact', 'The', 'Scene', 'Accompanying', 'Dog', 'The', 'Barking', 'Results', 'Put', 'I', 'Thrust', 'To', 'A few yards.', 'Far', 'Outside')
#
#
# Sentence Key: 4200
#
# Sentence: ('学校', '的', '医院', '部同', '发烧', '病人', '在', '一起', '因为', '她', '患', '的', '是', '肺病', '不是', '斑疹伤寒', '在', '我', '幼稚', '无知')
#
# Predicted labels:
# -----------------
# ('School', 'The', 'Hospital', 'Department with', 'Fever', 'Patients', 'In', 'Together.', 'Because', 'She', 'Suffering from', 'The', 'Is', 'Lung', 'No', 'Typhus', 'In', 'I', 'Childish', 'Ignorance')
#
#
# Sentence Key: 15920
#
# Sentence: ('我', '转过身', '再次', '经过', '活动', '天窗', '时', '我', '几乎', '看不清', '下', '扶梯', '的', '路', '同', '我', '刚才', '抬头', '观望', '的')
#
# Predicted labels:
# -----------------
# ('I', 'Turn around.', 'Again', 'After', 'Activities', 'Skylight', 'When', 'I', 'Almost', "I can't see clearly.", 'Next', 'Escalator', 'The', 'Lu', 'With', 'I', 'Just now', 'Rise', 'Watching', 'The')
#
#
# Sentence Key: 5720
#
# Sentence: ('“', '这个', '地域', '在', '哪儿', '它', '存在', '不', '存在', '”', '我', '用', '胳膊', '把', '海伦', '楼', '得', '更紧', '她', '对')
#
# Predicted labels:
# -----------------
# ('"', 'This one', 'Regional', 'In', 'Where', 'It', 'Exist', 'No', 'Exist', '"', 'I', 'Use', 'Arm', 'Put', 'Helen', 'Floor', 'Get it.', 'Tighter', 'She', 'Right')
#
#
# Sentence Key: 60
#
# Sentence: ('没有', '东西', '支撑', '我', '孤身', '独处', '我', '难以', '自制', '眼泪', '洒到', '地板', '上', '我', '曾', '打算', '在', '罗沃德', '表现', '那么出色')
#
# Predicted labels:
# ...
#
# Sentence: ('紧靠', '地面', '的', '榛子', '树枝', '下', '悄悄地', '溜出', '一条', '大', '狗', '黑白相间', '的', '毛色', '衬', '着', '树木', '使', '它', '成')
#
# Predicted labels:
# -----------------
# ('Close', 'Ground', 'The', 'Hazelnut', 'Branches', 'Next', 'Quietly', 'Slip out', 'One', 'Big', 'Dog', 'Black and white', 'The', 'Hair', 'Lining', 'On the', 'Trees', 'Make', 'It', 'Yes')
#
#
# Sentence Key: 5080
#
# Sentence: ('的', '轮廓', '但', '脸部', '被', '帷幔', '遮住', '那位', '在', '花园里', '同', '我', '讲', '过', '话', '的', '护士', '坐在', '一把', '安乐椅')
#
# Predicted labels:
# -----------------
# ('The', 'Contour', 'But', 'Face', 'Be', 'Hangings', 'Cover', 'The one.', 'In', 'Garden', 'With', 'I', 'Speak', 'Too much', 'Words', 'The', 'Nurse', 'Sitting in the', 'One.', 'Happy Chair')
#
#
# Sentence Key: 13580
#
# Sentence: ('夫人', '交谈', '此外', '过去', '七年', '来', '还', '坚持', '每天', '背诵', '一段', '法语', '在', '语调', '上', '狠下功夫', '逼真', '地', '模仿', '我')
#
# Predicted labels:
# -----------------
# ('Lady', 'Talk', 'In addition,', 'Past', 'Seven years.', 'To', 'Also', 'Insist', 'Every day', 'Recite', 'A', 'French', 'In', 'Tone', 'On', 'Work hard.', 'Realistic', 'Ground', 'Imitate', 'I')
#
#
# Sentence Key: 2340
#
# Sentence: ('她', '拥抱', '海', '伦比', '拥抱', '我', '要', '长', '些', '更', '不', '情愿', '放', '她', '走', '她', '一直', '目送', '海伦', '到')
#
# Predicted labels:
# -----------------
# ('She', 'Hug', 'Sea', 'Lumby', 'Hug', 'I', 'To', 'Long', 'Some', 'More', 'No', "'d rather", 'Put', 'She', 'Go', 'She', 'Always', 'Watched', 'Helen', 'To')
#
#
# Sentence Key: 12360
#
# Sentence: ('一番', '无奈', '只能', '简朴', '—', '—', '因为', '我', '没有', '一件', '服饰', '不是', '缝制', '得', '极其', '朴实', '的', '—', '—', '但')
#
# Predicted labels:
# -----------------
# ('A little bit of a', 'Helpless', 'Only', 'Simple', '—', '—', 'Because', 'I', 'No', 'A', 'Clothing', 'No', 'Sewing', 'Get it.', 'Extremely', 'Simple', 'The', '—', '—', 'But')
#
#
# Sentence Key: 13420
#
# Sentence: ('五官', '很小', '一头', '累赘', '的', '卷发', '直', '披到', '腰', '上', '“', '早上好', '阿德拉', '小姐', '”', '费尔法克斯', '太太', '说', '“', '过来')
#
# Predicted labels:
# -----------------
# ('Facial features', "It's small.", 'A', 'Burden', 'The', 'Curls', 'Straight', 'Dini to', 'Lumbar', 'On', '"', 'Good morning', 'Adela', 'Miss', '"', 'Fairfax', 'Wife', 'Said', '"', 'Come here')
#
#
# Sentence Key: 16400
#
# Sentence: ('的', '不过', '她', '干', '得', '挺', '好', '顺便', '问', '一下', '早上', '你', '跟', '你', '的', '学生', '相处', '得', '怎么样', '”')
#
# Predicted labels:
# -----------------
# ('The', 'But', 'She', 'Do', 'Get it.', 'Was', 'Good', 'By the way.', 'Ask', 'One moment.', 'Morning', 'You', 'With', 'You', 'The', 'Students', 'Get along', 'Get it.', 'What do you think', '"')
#
#
# Sentence Key: 10120
#
# Sentence: ('的', '一章', '有些', '像', '一出戏', '中', '的', '新', '的', '一场', '这回', '我', '拉开', '幕布', '的', '时候', '读者', '你', '一定', '会')
#
# Predicted labels:
# -----------------
# ('The', 'Chapter', 'Some', 'Like', 'A play.', 'In', 'The', 'New', 'The', 'A', 'This time.', 'I', 'Opened', 'Curtain', 'The', 'When', 'Readers', 'You', 'Must', 'Yes')
#
#
# Sentence Key: 11080
#
# Sentence: ('一张', '圆桌', '一条', '老式', '高', '背', '安乐椅', '上', '坐', '着', '一位', '整洁', '不过', '的', '矮小', '老妇', '人头', '戴', '寡妇', '帽')
#
# Predicted labels:
# -----------------
# ('One.', 'Round', 'One', 'Old - fashioned', 'High', 'Back', 'Happy Chair', 'On', 'Sit', 'On the', 'A', 'Neat', 'But', 'The', 'Short', 'Old woman', 'Head', 'Wear', 'Widow', 'Cap')
#
#
# Sentence Key: 17300
#
# Sentence: ('一些', '日子', '她', '会', '发出', '令人费解', '的', '声音', '有时', '我', '看到', '她', '她', '会', '从', '房间', '里', '出来', '手里', '拿')
#
# Predicted labels:
# -----------------
# ('A few', 'Day', 'She', 'Yes', 'Issued', 'Inexplicable', 'The', 'Voice', 'Sometimes', 'I', 'See', 'She', 'She', 'Yes', 'From', 'Room', 'Inside', 'Come out', 'Hands', 'Take')
#
#
# Sentence Key: 11280
#
# Sentence: ('冻僵', '吧', '莉娅', '调', '点儿', '尼', '格斯', '酒', '切', '一两片', '三明治', '储藏室', '的', '钥匙', '在', '这儿', '”', '她', '从', '口袋')
#
# Predicted labels:
# -----------------
# ('Frozen', "Let's do it", 'Leah', 'Tune', 'Some', 'Ni', 'Gus', 'Wine', 'Cut', 'One or two pieces.', 'Sandwich', 'Storeroom', 'The', 'Key', 'In', 'Here', '"', 'She', 'From', 'Pocket')
#
#
# Sentence Key: 19820
#
# Sentence: ('家', '时', '也', '依然', '看到', '它', '我', '路过', '台阶', '时', '驻足', '片刻', '举目', '四顾', '并', '静听', '着', '心想', '马蹄声', '会')
#
# Predicted labels:
# -----------------
# ('Home', 'When', 'Also', 'Still', 'See', 'It', 'I', 'Passing', 'Steps', 'When', 'Stop', 'Moment', 'Eye-catching', 'Four concerns', 'And', 'Listening', 'On the', 'Thought', 'Horseshoe Sound', 'Yes')
#
#
# Sentence Key: 17340
#
# Sentence: ('的', '读者', '请', '恕我直言', '！', '拿', '着', '一罐', '黑啤酒', '她', '的', '外表', '常常', '会', '消除', '她', '口头', '的', '怪癖', '所')
#
# Predicted labels:
# -----------------
# ('The', 'Readers', 'Please', 'With all due respect,', '!', 'Take', 'On the', 'One can.', 'Guinness', 'She', 'The', 'Appearance', 'Often', 'Yes', 'Eliminate', 'She', 'Oral', 'The', 'Quirks', 'The')
#
#
# Sentence Key: 6580
#
# Sentence: ('和', '联系', '都', '随之', '消失', '我', '从', '她', '那儿', '吸收', '某些', '个性', '和', '很多', '习惯', '比较', '和谐', '的', '思想', '比较')
#
# Predicted labels:
# -----------------
# ('And', 'Contact', 'All', 'With it,', 'Disappear', 'I', 'From', 'She', 'There', 'Absorption', 'Some', 'Personality', 'And', 'A lot', 'Habit', 'Comparison', 'Harmonious', 'The', 'Thought', 'Comparison')
#
#
# Sentence Key: 12200
#
# Sentence: ('房间', '里', '没有', '恐惧', '立刻', '倦意', '与', '满足', '俱', '来', '我', '很快', '便', '沉沉', '睡', '去', '醒来', '的', '时候', '天色')
#
# Predicted labels:
# -----------------
# ('Room', 'Inside', 'No', 'Fear', 'Immediately', 'Tiredness', 'And', 'Meet', 'All', 'To', 'I', 'Soon', 'Poe', 'Sinking', 'Sleep', 'To', 'Wake up', 'The', 'When', 'Sky')
#
#
# Sentence Key: 3760
#
# Sentence: ('罗沃德', '家常事', '也', '无人', '来', '有', '问', '啤气', '急躁', '的', '管家', '己', '逃之夭夭', '生怕', '受到', '传染', '她', '的', '后任', '原本')
#
# Predicted labels:
# -----------------
# ('Lowood', 'Family affairs', 'Also', 'Nobody', 'To', 'Yes', 'Ask', 'Beer', 'Impatience', 'The', 'Housekeeper', "I've got your", 'Run away.', 'Fear', 'Be', 'Infected', 'She', 'The', 'Successor', 'Originally')
#
#
# Sentence Key: 8720
#
# Sentence: ('的', '回复', '说', '是', '对', '我', '感到', '满意', '并', '定于', '两周', '后', '我', '去', '那位', '太太', '家', '担任', '家庭教师', '现在')
#
# Predicted labels:
# -----------------
# ('The', 'Reply', 'Said', 'Is', 'Right', 'I', 'Feel', 'Satisfaction', 'And', 'Scheduled', 'Two weeks.', 'After', 'I', 'To', 'The one.', 'Wife', 'Home', 'As', 'Tutor', 'Right now')
#
#
# Sentence Key: 19140
#
# Sentence: ('就', '住', '在', '下面', '是不是', '指有', '城垛', '的', '那', '幢', '房子', '”', '他', '指着', '桑', '菲尔德', '府', '这时', '月亮', '给')
#
# Predicted labels:
# -----------------
# ('Just.', 'Live', 'In', 'Below', "Isn't it", 'It means there.', 'Battlements', 'The', 'That', 'Building', 'House', '"', 'He', 'Point to', 'Sang', 'Field', 'Fu', 'Then', 'Moon', 'To give')
#
#
# Sentence Key: 16240
#
# Sentence: ('嚷', '道', '我', '其实', '并', '不', '盼望', '哪位', '格雷斯', '来', '回答', '因为', '这', '笑声', '同', '我', '所', '听到', '过', '的')
#
# Predicted labels:
# -----------------
# ('Shouting', 'Road', 'I', 'In fact', 'And', 'No', 'Hope', 'Who is it', 'Grace', 'To', 'Reply', 'Because', 'This', 'Laughter', 'With', 'I', 'The', 'Hear', 'Too much', 'The')
#
#
# Sentence Key: 6420
#
# Sentence: ('喜爱', '某些', '课程', '；', '我', '希望', '超过', '所有人', '；', '我', '很', '乐意', '使', '教师', '尤其', '是', '我', '所爱', '的', '教师')
#
# Predicted labels:
# -----------------
# ('Love', 'Some', 'Course', ';', 'I', 'Hope', 'More than', 'All of them', ';', 'I', 'Is', 'Happy', 'Make', 'Teachers', 'Especially', 'Is', 'I', 'Love', 'The', 'Teachers')
#
#
# Sentence Key: 7980
#
# Sentence: ('.', '的', '信', '吗', '”', '我', '问', '她', '从', '眼镜', '上方', '盯', '着', '我', '随后', '打开', '一个', '抽屉', '在', '里面')
#
# Predicted labels:
# -----------------
# ('.', 'The', 'Letter', 'Do you?', '"', 'I', 'Ask', 'She', 'From', 'Glasses', 'Above', 'Stare at', 'On the', 'I', 'Then', 'Open it', 'One', 'Drawer', 'In', 'Inside')
#
#
# Sentence Key: 1240
#
# Sentence: ('你', '被', '指责', '为', '说谎', '那', '你', '就', '在', '我', '面前', '尽力', '为', '自己', '辩护', '吧', '凡是', '你', '记得', '的')
#
# Predicted labels:
# -----------------
# ('You', 'Be', 'Accused', 'For', 'Lie', 'That', 'You', 'Just.', 'In', 'I', 'Front', 'Try', 'For', 'Myself', 'Defense', "Let's do it", 'All', 'You', 'Remember', 'The')
#
#
# Sentence Key: 17960
#
# Sentence: ('但', '来自', '哪个', '溪谷', '和', '深渊', '却', '无法', '判断', '海村', '那边', '有', '很多', '小山', '无疑', '会', '有', '许多', '山', '溪流')
#
# Predicted labels:
# -----------------
# ('But', 'From', 'Which one', 'Valley', 'And', 'Abyss', 'But', "Can't", 'Judge', 'Haimura', 'Over there', 'Yes', 'A lot', 'Hill', 'Undoubtedly', 'Yes', 'Yes', 'Many', 'Mountain', 'Streams')
#
#
# Sentence Key: 14440
#
# Sentence: ('很', '好', '送', '我', '漂亮', '的', '衣服', '和', '玩具', '可是', '你', '瞧', '他', '说话', '不算数', '把', '我', '带到', '英国', '自己')
#
# Predicted labels:
# -----------------
# ('Is', 'Good', 'Send', 'I', 'Pretty', 'The', 'Clothes', 'And', 'Toys', 'But', 'You', 'Look', 'He', 'Speak', 'Not counting.', 'Put', 'I', 'Bring to', 'United Kingdom', 'Myself')
#
#
# Sentence Key: 11620
#
# Sentence: ('很', '高兴', '你', '来', '现在', '有人', '作伴', '住', '在', '这儿', '是', '很', '愉快', '的', '当然', '什么', '时候', '都', '很', '愉快')
#
# Predicted labels:
# -----------------
# ('Is', 'Happy', 'You', 'To', 'Right now', 'Someone', 'Companion', 'Live', 'In', 'Here', 'Is', 'Is', 'Happy', 'The', 'Of course', 'What the', 'When', 'All', 'Is', 'Happy')
#
#
# Sentence Key: 9400
#
# Sentence: ('嘴唇', '很', '厚', '”', '“', '里德', '太太', '怎么样', '”', '“', '太太', '显得', '有些', '发胖', '外表', '看看', '倒', '不错', '但', '我')
#
# Predicted labels:
# -----------------
# ('Lips', 'Is', 'Thick', '"', '"', 'Reed', 'Wife', 'What do you think', '"', '"', 'Wife', 'Look', 'Some', 'Fat', 'Appearance', 'Look', 'Pour down', 'Not bad', 'But', 'I')
#
#
# Sentence Key: 3520
#
# Sentence: ('教师', '们', '全力以赴', '为', '那些', '幸而', '有', '亲戚朋友', '能够', '并', '愿意', '把', '她们', '从', '传染', '地', '带走', '的', '人', '打')
#
# Predicted labels:
# -----------------
# ('Teachers', 'We', 'Go all out.', 'For', 'Those', 'Fortunately', 'Yes', 'Relatives and friends', 'Can', 'And', 'Would', 'Put', 'They', 'From', 'Infected', 'Ground', 'Take', 'The', 'People', 'Play')
#
#
# Sentence Key: 18200
#
# Sentence: ('的', '道路', '上', '有时', '会', '扑', '向', '迟归', '的', '旅人', '就', '像', '此刻', '这', '匹', '马', '向', '我', '驰来', '一样')
#
# Predicted labels:
# -----------------
# ('The', 'Road', 'On', 'Sometimes', 'Yes', 'Pounce', 'To', 'Late return', 'The', 'Traveler', 'Just.', 'Like', 'Now', 'This', 'Pi', 'Horse', 'To', 'I', 'Come on.', 'The same')
#
#
# Sentence Key: 5420
#
# Sentence: ('继续', '低声', '耳语', '着', '说', '“', '我', '很', '愉快', '简', '你', '听到', '我', '已经', '死', '的', '时候', '你', '可', '千万别')
#
# Predicted labels:
# -----------------
# ('Go on', 'Whispered', 'Whisper', 'On the', 'Said', '"', 'I', 'Is', 'Happy', 'Jane', 'You', 'Hear', 'I', 'Have', 'Die', 'The', 'When', 'You', 'Can be', "Don't do anything about it.")
#
#
# Sentence Key: 20620
#
# Sentence: ('-', '-', '-', '-', '-', '-', '-', '-', '-', '第十三章', '遵照', '医嘱', '罗切斯特', '先生', '那晚', '上床', '很早', '第二天', '早晨', '也')
#
# Predicted labels:
# -----------------
# ('-', '-', '-', '-', '-', '-', '-', '-', '-', 'Chapter 13', 'Follow', 'Orders', 'Rochester', 'Mr', 'That night.', 'Sleep', "It're early.", 'Day 2', 'Morning', 'Also')
#
#
# Sentence Key: 3300
#
# Sentence: ('花', '就', '像', '奇妙', '地', '从', '地上', '升起', '的', '阳光', '我', '在', '林荫', '深处', '曾', '见', '过', '它们', '淡谈', '的')
#
# Predicted labels:
# -----------------
# ('Flowered', 'Just.', 'Like', 'Wonderful', 'Ground', 'From', 'Ground', 'Rises', 'The', 'Sunlight', 'I', 'In', 'Shade', 'Deep', 'Had', 'See', 'Too much', 'They', 'Talk', 'The')
#
#
# Sentence Key: 3400
#
# Sentence: ('另一回事', '罗沃德', '所在', '的', '林间', '山谷', '是', '大雾', '的', '摇篮', '是', '雾气', '诱发', '的', '病疫', '的', '滋生', '地', '时疫', '随着')
#
# Predicted labels:
# -----------------
# ('Another thing.', 'Lowood', 'Where', 'The', 'In the forest', 'Valley', 'Is', 'Fog', 'The', 'Cradle', 'Is', 'Mist', 'Induced', 'The', 'Epidemic', 'The', 'Breeding', 'Ground', 'Time epidemic', 'With')
#
#
# Sentence Key: 700
#
# Sentence: ('你', '提供', '别的', '财富', '在', '地球', '和', '人类', '之外', '还有', '一个', '看不见', '的', '世界', '一个', '精灵', '王国', '这个', '世界', '包围')
#
# Predicted labels:
# -----------------
# ('You', 'Provide', 'Other', 'Wealth', 'In', 'Earth', 'And', 'Human', 'Outside', 'And also', 'One', 'Unseen', 'The', 'World', 'One', 'Elves', 'Kingdom', 'This one', 'World', 'Surrounded')
#
#
# Sentence Key: 7860
#
# Sentence: ('星期', '似乎', '很', '长', '然而', '它', '像', '世间', '的', '万物', '一样', '终于', '到', '尽头', '一个', '秋高气爽', '的', '傍晚', '我', '再次')
#
# Predicted labels:
# -----------------
# ('Week', 'Seems', 'Is', 'Long', 'However', 'It', 'Like', 'World', 'The', 'Everything', 'The same', 'Finally', 'To', 'End', 'One', 'Autumn', 'The', 'Evening', 'I', 'Again')
#
#
# Sentence Key: 8620
#
# Sentence: ('当然', '监护人', '结果', '便', '向', '那位', '太太', '发封', '简函', '她', '回信', '说', '一切', '悉听尊便', '她', '已久', '不', '干预', '我', '的')
#
# Predicted labels:
# -----------------
# ('Of course', 'Guardian', 'Results', 'Poe', 'To', 'The one.', 'Wife', 'Issued', 'Letter', 'She', 'Reply', 'Said', 'All', 'Listen to the mercy', 'She', "It's been a long time.", 'No', 'Intervention', 'I', 'The')
#
#
# Sentence Key: 9280
#
# Sentence: ('你', '认为', '怎么样', '—', '—', '他', '和', '乔治亚', '娜', '小姐', '决定', '私奔', '于是', '让', '人', '发现', '受到', '阻止', '发现', '他们')
#
# Predicted labels:
# -----------------
# ('You', 'Think', 'What do you think', '—', '—', 'He', 'And', 'Georgia', 'Na', 'Miss', 'Decided', 'Elope', 'So', 'Let', 'People', 'Found', 'Be', 'Stop', 'Found', 'They')
#
#
# Sentence Key: 1080
#
# Sentence: ('永远', '做', '不到', '”', '“', '为什么', '”', '“', '因为', '我', '被', '冤枉', '小姐', '你', '还有', '所有', '其他人', '都', '会', '认为')
#
# Predicted labels:
# -----------------
# ('Forever', 'Do', 'Less than', '"', '"', 'Why', '"', '"', 'Because', 'I', 'Be', 'Wronged', 'Miss', 'You', 'And also', 'All', 'The others.', 'All', 'Yes', 'Think')
#
#
# Sentence Key: 7420
#
# Sentence: ('怎样才能', '找到', '一个', '新', '工作', '呢', '我', '猜想', '他们', '求助于', '朋友', '但', '我', '没有', '朋友', '很多', '没有', '朋友', '的', '人')
#
# Predicted labels:
# -----------------
# ('How can I do that', 'Found it', 'One', 'New', 'Job', 'What about?', 'I', 'Guess', 'They', 'Turn to', 'Friends', 'But', 'I', 'No', 'Friends', 'A lot', 'No', 'Friends', 'The', 'People')
#
#
# Sentence Key: 2780
#
# Sentence: ('的', '画作', '都', '是', '出自', '我', '的', '手笔', '潇洒自如', '的', '房屋', '树木', '铅笔画', '别致', '的', '岩石', '和', '废墟', '克伊', '普式')
#
# Predicted labels:
# -----------------
# ('The', 'Paintings', 'All', 'Is', 'From', 'I', 'The', 'Hand', "It's easy to be smart.", 'The', 'Housing', 'Trees', 'Pencil drawing', 'Chic', 'The', 'Rock', 'And', 'Ruins', 'Kei', 'Popular')
#
#
# Sentence Key: 16360
#
# Sentence: ('记住', '对', '你', '的', '吩咐', '！', '”', '格雷斯', '默默地', '行', '个', '屈膝', '礼', '走进', '去', '“', '她', '是', '我们', '雇来')
#
# Predicted labels:
# -----------------
# ('Remember', 'Right', 'You', 'The', 'Told', '!', '"', 'Grace', 'Silently', 'Yes', 'A', 'Knees', 'Ceremony', 'Into', 'To', '"', 'She', 'Is', 'We', 'Hired.')
#
#
# Sentence Key: 2920
#
# Sentence: ('艰辛', '有所', '好转', '春天', '即将来临', '实际上', '已经', '到来', '冬季', '的', '严寒', '过去', '积雪', '已', '融化', '刺骨', '的', '寒风', '不再', '那般')
#
# Predicted labels:
# -----------------
# ('Hard', 'There are some', 'Improved', 'Spring', "It's coming.", 'As a matter of fact', 'Have', 'Come', 'Winter', 'The', 'Cold', 'Past', 'Snow', 'Has', 'Melt', 'Biting', 'The', 'Wind', 'No longer', 'As')
#
#
# Sentence Key: 15460
#
# Sentence: ('投射', '进来', '的', '斑驳', '光影', '映照', '出', '有', '上百年', '历史', '的', '床架', '；', '映照', '出', '橡树', '或', '胡桃', '树', '做')
#
# Predicted labels:
# -----------------
# ('Projected', 'In', 'The', 'Mottled', 'Light', 'Mapping', 'Out', 'Yes', 'Hundreds of years.', 'History', 'The', 'Bedstead', ';', 'Mapping', 'Out', 'Oak', 'Or', 'Walnut', 'Tree', 'Do')
#
#
# Sentence Key: 6340
#
# Sentence: ('怎样', '把', '理智', '与', '严格', '舒适', '与', '经济', '怜悯', '与', '正直', '结合', '起来', '学校', '因此', '大', '有', '改进', '到时候', '成')
#
# Predicted labels:
# -----------------
# ('How', 'Put', 'Reason', 'And', 'Strict', 'Comfortable', 'And', 'Economic', 'Mercy', 'And', 'Integrity', 'Combine', 'Get up', 'School', 'So', 'Big', 'Yes', 'Improved', 'When the time comes,', 'Yes')
#
#
# Sentence Key: 1060
#
# Sentence: ('吗', '”', '她', '俯身', '瞧', '着', '我', '的', '脸', '问', '“', '把', '伤心', '都', '哭', '光', '”', '“', '恐怕', '我')
#
# Predicted labels:
# -----------------
# ('Do you?', '"', 'She', 'Leaned', 'Look', 'On the', 'I', 'The', 'Face', 'Ask', '"', 'Put', 'Sad', 'All', 'Cry', 'Light', '"', '"', "'m afraid", 'I')
